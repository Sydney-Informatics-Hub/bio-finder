# %%
from pathlib import Path

from bio_mcp.cache.load import load_biotools, load_galaxy_singularity
from bio_mcp.mcp.server import _search_containers, _describe_container

# %% [markdown]
# ## Loading snapshots
#
# Galaxy containers from the CVMFS and tool metadata from e.g. biotools are indexed by lowercased tool names so they can be mapped together.

# %%
bt = load_biotools(Path("/home/ubuntu/bio-mcp/data/toolfinder_meta.yaml"))
gx = load_galaxy_singularity(
    Path("/home/ubuntu/bio-mcp/data/galaxy_singularity_cache.json")
)

# %% [markdown]
# ## `search_containers`

# %%
_search_containers("samtools", gx)
# Out:
# [{'found': True,
#   'tool_id': 'samtools',
#   'containers': [{'entry_name': 'samtools:1.3--1',
#     'tool_name': 'samtools',
#     'tag': '1.3--1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--1',
#     'size_bytes': 5083136,
#     'mtime': 1567233286.0},
#    {'entry_name': 'samtools:0.1.19--2',
#     'tool_name': 'samtools',
#     'tag': '0.1.19--2',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--2',
#     'size_bytes': 8941568,
#     'mtime': 1567233201.0},
#    {'entry_name': 'samtools:0.1.15--0',
#     'tool_name': 'samtools',
#     'tag': '0.1.15--0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.15--0',
#     'size_bytes': 15171584,
#     'mtime': 1566672582.0},
#    {'entry_name': 'samtools:1.7--0',
#     'tool_name': 'samtools',
#     'tag': '1.7--0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.7--0',
#     'size_bytes': 24928256,
#     'mtime': 1567233243.0},
#    {'entry_name': 'samtools:1.5--2',
#     'tool_name': 'samtools',
#     'tag': '1.5--2',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.5--2',
#     'size_bytes': 16613376,
#     'mtime': 1566672724.0},
#    {'entry_name': 'samtools:1.2.rglab--0',
#     'tool_name': 'samtools',
#     'tag': '1.2.rglab--0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.2.rglab--0',
#     'size_bytes': 15081472,
#     'mtime': 1566672663.0},
#    {'entry_name': 'samtools:1.9--h91753b0_4',
#     'tool_name': 'samtools',
#     'tag': '1.9--h91753b0_4',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h91753b0_4',
#     'size_bytes': 26267648,
#     'mtime': 1567233524.0},
#    {'entry_name': 'samtools:1.6--0',
#     'tool_name': 'samtools',
#     'tag': '1.6--0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--0',
#     'size_bytes': 24866816,
#     'mtime': 1566672741.0},
#    {'entry_name': 'samtools:1.4--0',
#     'tool_name': 'samtools',
#     'tag': '1.4--0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.4--0',
#     'size_bytes': 10760192,
#     'mtime': 1566672698.0},
#    {'entry_name': 'samtools:1.9--h8571acd_11',
#     'tool_name': 'samtools',
#     'tag': '1.9--h8571acd_11',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h8571acd_11',
#     'size_bytes': 27271168,
#     'mtime': 1566672911.0},
#    {'entry_name': 'samtools:1.9--h8571acd_10',
#     'tool_name': 'samtools',
#     'tag': '1.9--h8571acd_10',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h8571acd_10',
#     'size_bytes': 27267072,
#     'mtime': 1567233320.0},
#    {'entry_name': 'samtools:1.3--2',
#     'tool_name': 'samtools',
#     'tag': '1.3--2',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--2',
#     'size_bytes': 6459392,
#     'mtime': 1566672674.0},
#    {'entry_name': 'samtools:0.1.12--0',
#     'tool_name': 'samtools',
#     'tag': '0.1.12--0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.12--0',
#     'size_bytes': 15060992,
#     'mtime': 1567233334.0},
#    {'entry_name': 'samtools:1.8--h46bd0b3_5',
#     'tool_name': 'samtools',
#     'tag': '1.8--h46bd0b3_5',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.8--h46bd0b3_5',
#     'size_bytes': 23281664,
#     'mtime': 1566672843.0},
#    {'entry_name': 'samtools:1.9--h91753b0_8',
#     'tool_name': 'samtools',
#     'tag': '1.9--h91753b0_8',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h91753b0_8',
#     'size_bytes': 26439680,
#     'mtime': 1566672944.0},
#    {'entry_name': 'samtools:0.1.19--h94a8ba4_6',
#     'tool_name': 'samtools',
#     'tag': '0.1.19--h94a8ba4_6',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h94a8ba4_6',
#     'size_bytes': 19910656,
#     'mtime': 1566672611.0},
#    {'entry_name': 'samtools:1.6--he673b24_3',
#     'tool_name': 'samtools',
#     'tag': '1.6--he673b24_3',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--he673b24_3',
#     'size_bytes': 27086848,
#     'mtime': 1566672790.0},
#    {'entry_name': 'samtools:1.9--h10a08f8_12',
#     'tool_name': 'samtools',
#     'tag': '1.9--h10a08f8_12',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h10a08f8_12',
#     'size_bytes': 30167040,
#     'mtime': 1567745001.0},
#    {'entry_name': 'samtools:1.6--h02bfda8_2',
#     'tool_name': 'samtools',
#     'tag': '1.6--h02bfda8_2',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h02bfda8_2',
#     'size_bytes': 26087424,
#     'mtime': 1566672757.0},
#    {'entry_name': 'samtools:1.1--hf89b575_4',
#     'tool_name': 'samtools',
#     'tag': '1.1--hf89b575_4',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--hf89b575_4',
#     'size_bytes': 18546688,
#     'mtime': 1567233430.0},
#    {'entry_name': 'samtools:1.1--h94a8ba4_3',
#     'tool_name': 'samtools',
#     'tag': '1.1--h94a8ba4_3',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--h94a8ba4_3',
#     'size_bytes': 16830464,
#     'mtime': 1566672650.0},
#    {'entry_name': 'samtools:1.5--1',
#     'tool_name': 'samtools',
#     'tag': '1.5--1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.5--1',
#     'size_bytes': 16617472,
#     'mtime': 1567233548.0},
#    {'entry_name': 'samtools:1.7--2',
#     'tool_name': 'samtools',
#     'tag': '1.7--2',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.7--2',
#     'size_bytes': 27439104,
#     'mtime': 1566672807.0},
#    {'entry_name': 'samtools:1.0--hdd8ed8b_2',
#     'tool_name': 'samtools',
#     'tag': '1.0--hdd8ed8b_2',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.0--hdd8ed8b_2',
#     'size_bytes': 12582912,
#     'mtime': 1566672636.0},
#    {'entry_name': 'samtools:0.1.14--1',
#     'tool_name': 'samtools',
#     'tag': '0.1.14--1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.14--1',
#     'size_bytes': 15147008,
#     'mtime': 1566672568.0},
#    {'entry_name': 'samtools:1.9--h91753b0_3',
#     'tool_name': 'samtools',
#     'tag': '1.9--h91753b0_3',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h91753b0_3',
#     'size_bytes': 26267648,
#     'mtime': 1567233567.0},
#    {'entry_name': 'samtools:0.1.19--3',
#     'tool_name': 'samtools',
#     'tag': '0.1.19--3',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--3',
#     'size_bytes': 17596416,
#     'mtime': 1566672596.0},
#    {'entry_name': 'samtools:1.9--h91753b0_5',
#     'tool_name': 'samtools',
#     'tag': '1.9--h91753b0_5',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h91753b0_5',
#     'size_bytes': 26267648,
#     'mtime': 1567233504.0},
#    {'entry_name': 'samtools:1.9--h43f6869_9',
#     'tool_name': 'samtools',
#     'tag': '1.9--h43f6869_9',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h43f6869_9',
#     'size_bytes': 26439680,
#     'mtime': 1566672860.0},
#    {'entry_name': 'samtools:1.9--h91753b0_2',
#     'tool_name': 'samtools',
#     'tag': '1.9--h91753b0_2',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h91753b0_2',
#     'size_bytes': 26267648,
#     'mtime': 1567233589.0},
#    {'entry_name': 'samtools:1.0--0',
#     'tool_name': 'samtools',
#     'tag': '1.0--0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.0--0',
#     'size_bytes': 4820992,
#     'mtime': 1567233382.0},
#    {'entry_name': 'samtools:1.9--h57cc563_6',
#     'tool_name': 'samtools',
#     'tag': '1.9--h57cc563_6',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h57cc563_6',
#     'size_bytes': 26267648,
#     'mtime': 1567233220.0},
#    {'entry_name': 'samtools:0.1.12--2',
#     'tool_name': 'samtools',
#     'tag': '0.1.12--2',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.12--2',
#     'size_bytes': 15990784,
#     'mtime': 1566672541.0},
#    {'entry_name': 'samtools:0.1.13--0',
#     'tool_name': 'samtools',
#     'tag': '0.1.13--0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.13--0',
#     'size_bytes': 15122432,
#     'mtime': 1567233279.0},
#    {'entry_name': 'samtools:1.5--0',
#     'tool_name': 'samtools',
#     'tag': '1.5--0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.5--0',
#     'size_bytes': 11829248,
#     'mtime': 1567233535.0},
#    {'entry_name': 'samtools:1.3.1--3',
#     'tool_name': 'samtools',
#     'tag': '1.3.1--3',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--3',
#     'size_bytes': 10768384,
#     'mtime': 1567233404.0},
#    {'entry_name': 'samtools:0.1.14--0',
#     'tool_name': 'samtools',
#     'tag': '0.1.14--0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.14--0',
#     'size_bytes': 15138816,
#     'mtime': 1567233485.0},
#    {'entry_name': 'samtools:1.3.1--2',
#     'tool_name': 'samtools',
#     'tag': '1.3.1--2',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--2',
#     'size_bytes': 11583488,
#     'mtime': 1567233415.0},
#    {'entry_name': 'samtools:1.9--h46bd0b3_0',
#     'tool_name': 'samtools',
#     'tag': '1.9--h46bd0b3_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h46bd0b3_0',
#     'size_bytes': 23293952,
#     'mtime': 1566672876.0},
#    {'entry_name': 'samtools:1.4.1--0',
#     'tool_name': 'samtools',
#     'tag': '1.4.1--0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.4.1--0',
#     'size_bytes': 10764288,
#     'mtime': 1566672709.0},
#    {'entry_name': 'samtools:0.1.13--1',
#     'tool_name': 'samtools',
#     'tag': '0.1.13--1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.13--1',
#     'size_bytes': 15130624,
#     'mtime': 1566672555.0},
#    {'entry_name': 'samtools:0.1.19--h94a8ba4_5',
#     'tool_name': 'samtools',
#     'tag': '0.1.19--h94a8ba4_5',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h94a8ba4_5',
#     'size_bytes': 17698816,
#     'mtime': 1567233300.0},
#    {'entry_name': 'samtools:1.3.1--5',
#     'tool_name': 'samtools',
#     'tag': '1.3.1--5',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--5',
#     'size_bytes': 10108928,
#     'mtime': 1566672686.0},
#    {'entry_name': 'samtools:1.3.1--4',
#     'tool_name': 'samtools',
#     'tag': '1.3.1--4',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--4',
#     'size_bytes': 10768384,
#     'mtime': 1567233393.0},
#    {'entry_name': 'samtools:1.0--1',
#     'tool_name': 'samtools',
#     'tag': '1.0--1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.0--1',
#     'size_bytes': 6144000,
#     'mtime': 1566672622.0},
#    {'entry_name': 'samtools:1.6--h4da6232_1',
#     'tool_name': 'samtools',
#     'tag': '1.6--h4da6232_1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h4da6232_1',
#     'size_bytes': 21774336,
#     'mtime': 1566672772.0},
#    {'entry_name': 'samtools:1.6--h244ad75_4',
#     'tool_name': 'samtools',
#     'tag': '1.6--h244ad75_4',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h244ad75_4',
#     'size_bytes': 28876800,
#     'mtime': 1567233453.0},
#    {'entry_name': 'samtools:1.7--1',
#     'tool_name': 'samtools',
#     'tag': '1.7--1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.7--1',
#     'size_bytes': 25194496,
#     'mtime': 1567233266.0},
#    {'entry_name': 'samtools:1.8--4',
#     'tool_name': 'samtools',
#     'tag': '1.8--4',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.8--4',
#     'size_bytes': 27516928,
#     'mtime': 1566672825.0},
#    {'entry_name': 'samtools:1.9--h8ee4bcc_1',
#     'tool_name': 'samtools',
#     'tag': '1.9--h8ee4bcc_1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h8ee4bcc_1',
#     'size_bytes': 25468928,
#     'mtime': 1566672928.0},
#    {'entry_name': 'samtools:1.9--h57cc563_7',
#     'tool_name': 'samtools',
#     'tag': '1.9--h57cc563_7',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h57cc563_7',
#     'size_bytes': 26439680,
#     'mtime': 1566672894.0},
#    {'entry_name': 'samtools:1.8--3',
#     'tool_name': 'samtools',
#     'tag': '1.8--3',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.8--3',
#     'size_bytes': 27443200,
#     'mtime': 1567233355.0},
#    {'entry_name': 'samtools:1.8--2',
#     'tool_name': 'samtools',
#     'tag': '1.8--2',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.8--2',
#     'size_bytes': 27410432,
#     'mtime': 1567233376.0},
#    {'entry_name': 'samtools:0.1.12--1',
#     'tool_name': 'samtools',
#     'tag': '0.1.12--1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.12--1',
#     'size_bytes': 15982592,
#     'mtime': 1567233469.0},
#    {'entry_name': 'samtools:1.2-0',
#     'tool_name': 'samtools',
#     'tag': '1.2-0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.2-0',
#     'size_bytes': 15081472,
#     'mtime': 1578458984.0},
#    {'entry_name': 'samtools:1.3--h0592bc0_3',
#     'tool_name': 'samtools',
#     'tag': '1.3--h0592bc0_3',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h0592bc0_3',
#     'size_bytes': 28184576,
#     'mtime': 1587102580.0},
#    {'entry_name': 'samtools:1.6--h244ad75_5',
#     'tool_name': 'samtools',
#     'tag': '1.6--h244ad75_5',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h244ad75_5',
#     'size_bytes': 28868608,
#     'mtime': 1572240316.0},
#    {'entry_name': 'samtools:1.10--h9402c20_0',
#     'tool_name': 'samtools',
#     'tag': '1.10--h9402c20_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.10--h9402c20_0',
#     'size_bytes': 30883840,
#     'mtime': 1575780266.0},
#    {'entry_name': 'samtools:1.2',
#     'tool_name': 'samtools',
#     'tag': '1.2',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.2',
#     'size_bytes': 4673567,
#     'mtime': 1580725809.0},
#    {'entry_name': 'samtools:1.3.1--h0592bc0_6',
#     'tool_name': 'samtools',
#     'tag': '1.3.1--h0592bc0_6',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h0592bc0_6',
#     'size_bytes': 28028928,
#     'mtime': 1573620952.0},
#    {'entry_name': 'samtools:1.10--h9402c20_2',
#     'tool_name': 'samtools',
#     'tag': '1.10--h9402c20_2',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.10--h9402c20_2',
#     'size_bytes': 30732288,
#     'mtime': 1577335041.0},
#    {'entry_name': 'samtools:1.10--h9402c20_1',
#     'tool_name': 'samtools',
#     'tag': '1.10--h9402c20_1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.10--h9402c20_1',
#     'size_bytes': 30748672,
#     'mtime': 1576385579.0},
#    {'entry_name': 'samtools:1.6--h9dace67_6',
#     'tool_name': 'samtools',
#     'tag': '1.6--h9dace67_6',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h9dace67_6',
#     'size_bytes': 29175808,
#     'mtime': 1593840974.0},
#    {'entry_name': 'samtools:0.1.19--hf89b575_7',
#     'tool_name': 'samtools',
#     'tag': '0.1.19--hf89b575_7',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--hf89b575_7',
#     'size_bytes': 21643264,
#     'mtime': 1593840928.0},
#    {'entry_name': 'samtools:1.3.1--h80b0bb3_7',
#     'tool_name': 'samtools',
#     'tag': '1.3.1--h80b0bb3_7',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h80b0bb3_7',
#     'size_bytes': 28295168,
#     'mtime': 1593840958.0},
#    {'entry_name': 'samtools:1.3--h80b0bb3_4',
#     'tool_name': 'samtools',
#     'tag': '1.3--h80b0bb3_4',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h80b0bb3_4',
#     'size_bytes': 28282880,
#     'mtime': 1593840943.0},
#    {'entry_name': 'samtools:1.11--h6270b1f_0',
#     'tool_name': 'samtools',
#     'tag': '1.11--h6270b1f_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.11--h6270b1f_0',
#     'size_bytes': 30932992,
#     'mtime': 1601962088.0},
#    {'entry_name': 'samtools:1.1--hfb9b9cc_5',
#     'tool_name': 'samtools',
#     'tag': '1.1--hfb9b9cc_5',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--hfb9b9cc_5',
#     'size_bytes': 18018304,
#     'mtime': 1598945503.0},
#    {'entry_name': 'samtools:0.1.19--hfb9b9cc_8',
#     'tool_name': 'samtools',
#     'tag': '0.1.19--hfb9b9cc_8',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--hfb9b9cc_8',
#     'size_bytes': 21094400,
#     'mtime': 1598945491.0},
#    {'entry_name': 'samtools:0.1.18--hfb9b9cc_10',
#     'tool_name': 'samtools',
#     'tag': '0.1.18--hfb9b9cc_10',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.18--hfb9b9cc_10',
#     'size_bytes': 13987840,
#     'mtime': 1606105551.0},
#    {'entry_name': 'samtools:1.10--h2e538c0_3',
#     'tool_name': 'samtools',
#     'tag': '1.10--h2e538c0_3',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.10--h2e538c0_3',
#     'size_bytes': 30826496,
#     'mtime': 1598945521.0},
#    {'entry_name': 'samtools:0.1.16',
#     'tool_name': 'samtools',
#     'tag': '0.1.16',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.16',
#     'size_bytes': 4284447,
#     'mtime': 1611774443.0},
#    {'entry_name': 'samtools:1.12--hd5e65b6_0',
#     'tool_name': 'samtools',
#     'tag': '1.12--hd5e65b6_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.12--hd5e65b6_0',
#     'size_bytes': 31371264,
#     'mtime': 1616020387.0},
#    {'entry_name': 'samtools:1.6--hb116620_7',
#     'tool_name': 'samtools',
#     'tag': '1.6--hb116620_7',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--hb116620_7',
#     'size_bytes': 30642176,
#     'mtime': 1616939365.0},
#    {'entry_name': 'samtools:1.12--h9aed4be_1',
#     'tool_name': 'samtools',
#     'tag': '1.12--h9aed4be_1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.12--h9aed4be_1',
#     'size_bytes': 32980992,
#     'mtime': 1616939316.0},
#    {'entry_name': 'samtools:0.1.18--h270b39a_11',
#     'tool_name': 'samtools',
#     'tag': '0.1.18--h270b39a_11',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.18--h270b39a_11',
#     'size_bytes': 15671296,
#     'mtime': 1616939277.0},
#    {'entry_name': 'samtools:1.1--h270b39a_6',
#     'tool_name': 'samtools',
#     'tag': '1.1--h270b39a_6',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--h270b39a_6',
#     'size_bytes': 15421440,
#     'mtime': 1616939299.0},
#    {'entry_name': 'samtools:1.3.1--h1b8c3c0_8',
#     'tool_name': 'samtools',
#     'tag': '1.3.1--h1b8c3c0_8',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h1b8c3c0_8',
#     'size_bytes': 29818880,
#     'mtime': 1616939348.0},
#    {'entry_name': 'samtools:0.1.19--h270b39a_9',
#     'tool_name': 'samtools',
#     'tag': '0.1.19--h270b39a_9',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h270b39a_9',
#     'size_bytes': 18968576,
#     'mtime': 1616939289.0},
#    {'entry_name': 'samtools:1.3--h1b8c3c0_5',
#     'tool_name': 'samtools',
#     'tag': '1.3--h1b8c3c0_5',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h1b8c3c0_5',
#     'size_bytes': 29806592,
#     'mtime': 1616939332.0},
#    {'entry_name': 'samtools:1.13--h8c37831_0',
#     'tool_name': 'samtools',
#     'tag': '1.13--h8c37831_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.13--h8c37831_0',
#     'size_bytes': 33050624,
#     'mtime': 1625893518.0},
#    {'entry_name': 'samtools:1.2--0',
#     'tool_name': 'samtools',
#     'tag': '1.2--0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.2--0',
#     'size_bytes': 15081472,
#     'mtime': 1630560056.0},
#    {'entry_name': 'samtools:1.14--hb421002_0',
#     'tool_name': 'samtools',
#     'tag': '1.14--hb421002_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.14--hb421002_0',
#     'size_bytes': 25956352,
#     'mtime': 1635222951.0},
#    {'entry_name': 'samtools:1.15--h3843a85_0',
#     'tool_name': 'samtools',
#     'tag': '1.15--h3843a85_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.15--h3843a85_0',
#     'size_bytes': 25894912,
#     'mtime': 1645591369.0},
#    {'entry_name': 'samtools:1.6--h3f2fef4_8',
#     'tool_name': 'samtools',
#     'tag': '1.6--h3f2fef4_8',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h3f2fef4_8',
#     'size_bytes': 24383488,
#     'mtime': 1645591414.0},
#    {'entry_name': 'samtools:1.1--h20b1175_7',
#     'tool_name': 'samtools',
#     'tag': '1.1--h20b1175_7',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--h20b1175_7',
#     'size_bytes': 8036352,
#     'mtime': 1645591355.0},
#    {'entry_name': 'samtools:1.3--h41a57b0_6',
#     'tool_name': 'samtools',
#     'tag': '1.3--h41a57b0_6',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h41a57b0_6',
#     'size_bytes': 23552000,
#     'mtime': 1645591384.0},
#    {'entry_name': 'samtools:1.3.1--h41a57b0_9',
#     'tool_name': 'samtools',
#     'tag': '1.3.1--h41a57b0_9',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h41a57b0_9',
#     'size_bytes': 23564288,
#     'mtime': 1645591398.0},
#    {'entry_name': 'samtools:1.3.1--h9071d68_10',
#     'tool_name': 'samtools',
#     'tag': '1.3.1--h9071d68_10',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h9071d68_10',
#     'size_bytes': 22724608,
#     'mtime': 1645849601.0},
#    {'entry_name': 'samtools:1.6--hcd7b337_9',
#     'tool_name': 'samtools',
#     'tag': '1.6--hcd7b337_9',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--hcd7b337_9',
#     'size_bytes': 23539712,
#     'mtime': 1645849616.0},
#    {'entry_name': 'samtools:1.3--h9071d68_7',
#     'tool_name': 'samtools',
#     'tag': '1.3--h9071d68_7',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h9071d68_7',
#     'size_bytes': 22712320,
#     'mtime': 1645849587.0},
#    {'entry_name': 'samtools:1.15--h1170115_1',
#     'tool_name': 'samtools',
#     'tag': '1.15--h1170115_1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.15--h1170115_1',
#     'size_bytes': 25931776,
#     'mtime': 1645849573.0},
#    {'entry_name': 'samtools:0.1.19--h20b1175_10',
#     'tool_name': 'samtools',
#     'tag': '0.1.19--h20b1175_10',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h20b1175_10',
#     'size_bytes': 11431936,
#     'mtime': 1646281497.0},
#    {'entry_name': 'samtools:0.1.18--h20b1175_12',
#     'tool_name': 'samtools',
#     'tag': '0.1.18--h20b1175_12',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.18--h20b1175_12',
#     'size_bytes': 8241152,
#     'mtime': 1646281490.0},
#    {'entry_name': 'samtools:1.15.1--h1170115_0',
#     'tool_name': 'samtools',
#     'tag': '1.15.1--h1170115_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.15.1--h1170115_0',
#     'size_bytes': 22114304,
#     'mtime': 1649394526.0},
#    {'entry_name': 'samtools:1.15.1--h6899075_1',
#     'tool_name': 'samtools',
#     'tag': '1.15.1--h6899075_1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.15.1--h6899075_1',
#     'size_bytes': 22642688,
#     'mtime': 1663479189.0},
#    {'entry_name': 'samtools:1.16.1--h6899075_0',
#     'tool_name': 'samtools',
#     'tag': '1.16.1--h6899075_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.16.1--h6899075_0',
#     'size_bytes': 22659072,
#     'mtime': 1664862117.0},
#    {'entry_name': 'samtools:1.16.1--h6899075_1',
#     'tool_name': 'samtools',
#     'tag': '1.16.1--h6899075_1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.16.1--h6899075_1',
#     'size_bytes': 22667264,
#     'mtime': 1665466977.0},
#    {'entry_name': 'samtools:1.16.1--h00cdaf9_2',
#     'tool_name': 'samtools',
#     'tag': '1.16.1--h00cdaf9_2',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.16.1--h00cdaf9_2',
#     'size_bytes': 22605824,
#     'mtime': 1678241797.0},
#    {'entry_name': 'samtools:1.17--h00cdaf9_0',
#     'tool_name': 'samtools',
#     'tag': '1.17--h00cdaf9_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.17--h00cdaf9_0',
#     'size_bytes': 22634496,
#     'mtime': 1680973648.0},
#    {'entry_name': 'samtools:1.1--h50ea8bc_8',
#     'tool_name': 'samtools',
#     'tag': '1.1--h50ea8bc_8',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--h50ea8bc_8',
#     'size_bytes': 8138752,
#     'mtime': 1684329537.0},
#    {'entry_name': 'samtools:0.1.19--h50ea8bc_11',
#     'tool_name': 'samtools',
#     'tag': '0.1.19--h50ea8bc_11',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h50ea8bc_11',
#     'size_bytes': 11509760,
#     'mtime': 1684329532.0},
#    {'entry_name': 'samtools:1.3.1--h0cf4675_11',
#     'tool_name': 'samtools',
#     'tag': '1.3.1--h0cf4675_11',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h0cf4675_11',
#     'size_bytes': 20373504,
#     'mtime': 1684329568.0},
#    {'entry_name': 'samtools:1.17--hd87286a_1',
#     'tool_name': 'samtools',
#     'tag': '1.17--hd87286a_1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.17--hd87286a_1',
#     'size_bytes': 24088576,
#     'mtime': 1684329547.0},
#    {'entry_name': 'samtools:0.1.18--h50ea8bc_13',
#     'tool_name': 'samtools',
#     'tag': '0.1.18--h50ea8bc_13',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.18--h50ea8bc_13',
#     'size_bytes': 8347648,
#     'mtime': 1684329525.0},
#    {'entry_name': 'samtools:1.3--h0cf4675_8',
#     'tool_name': 'samtools',
#     'tag': '1.3--h0cf4675_8',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h0cf4675_8',
#     'size_bytes': 20361216,
#     'mtime': 1684329558.0},
#    {'entry_name': 'samtools:1.6--hc3601fc_10',
#     'tool_name': 'samtools',
#     'tag': '1.6--hc3601fc_10',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--hc3601fc_10',
#     'size_bytes': 21295104,
#     'mtime': 1684329578.0},
#    {'entry_name': 'samtools:1.17--hd87286a_2',
#     'tool_name': 'samtools',
#     'tag': '1.17--hd87286a_2',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.17--hd87286a_2',
#     'size_bytes': 24993792,
#     'mtime': 1695796914.0},
#    {'entry_name': 'samtools:1.18--hd87286a_0',
#     'tool_name': 'samtools',
#     'tag': '1.18--hd87286a_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.18--hd87286a_0',
#     'size_bytes': 25001984,
#     'mtime': 1696489712.0},
#    {'entry_name': 'samtools:1.18--h50ea8bc_1',
#     'tool_name': 'samtools',
#     'tag': '1.18--h50ea8bc_1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.18--h50ea8bc_1',
#     'size_bytes': 25010176,
#     'mtime': 1696575535.0},
#    {'entry_name': 'samtools:1.19--h50ea8bc_0',
#     'tool_name': 'samtools',
#     'tag': '1.19--h50ea8bc_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.19--h50ea8bc_0',
#     'size_bytes': 25284608,
#     'mtime': 1702449613.0},
#    {'entry_name': 'samtools:1.19.1--h50ea8bc_0',
#     'tool_name': 'samtools',
#     'tag': '1.19.1--h50ea8bc_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.19.1--h50ea8bc_0',
#     'size_bytes': 25288704,
#     'mtime': 1705973293.0},
#    {'entry_name': 'samtools:1.19.2--h50ea8bc_0',
#     'tool_name': 'samtools',
#     'tag': '1.19.2--h50ea8bc_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.19.2--h50ea8bc_0',
#     'size_bytes': 25288704,
#     'mtime': 1706697298.0},
#    {'entry_name': 'samtools:1.19.2--h50ea8bc_1',
#     'tool_name': 'samtools',
#     'tag': '1.19.2--h50ea8bc_1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.19.2--h50ea8bc_1',
#     'size_bytes': 25300992,
#     'mtime': 1709688756.0},
#    {'entry_name': 'samtools:1.20--h50ea8bc_0',
#     'tool_name': 'samtools',
#     'tag': '1.20--h50ea8bc_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.20--h50ea8bc_0',
#     'size_bytes': 25362432,
#     'mtime': 1713230880.0},
#    {'entry_name': 'samtools:1.20--h50ea8bc_1',
#     'tool_name': 'samtools',
#     'tag': '1.20--h50ea8bc_1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.20--h50ea8bc_1',
#     'size_bytes': 25563136,
#     'mtime': 1720661568.0},
#    {'entry_name': 'samtools:1.21--h50ea8bc_0',
#     'tool_name': 'samtools',
#     'tag': '1.21--h50ea8bc_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.21--h50ea8bc_0',
#     'size_bytes': 25726976,
#     'mtime': 1726192714.0},
#    {'entry_name': 'samtools:0.1.18--h96c455f_14',
#     'tool_name': 'samtools',
#     'tag': '0.1.18--h96c455f_14',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.18--h96c455f_14',
#     'size_bytes': 8093696,
#     'mtime': 1733317525.0},
#    {'entry_name': 'samtools:0.1.19--h96c455f_12',
#     'tool_name': 'samtools',
#     'tag': '0.1.19--h96c455f_12',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h96c455f_12',
#     'size_bytes': 11276288,
#     'mtime': 1733317535.0},
#    {'entry_name': 'samtools:0.1.19--h96c455f_13',
#     'tool_name': 'samtools',
#     'tag': '0.1.19--h96c455f_13',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h96c455f_13',
#     'size_bytes': 11264000,
#     'mtime': 1733404440.0},
#    {'entry_name': 'samtools:1.3.1--h60f3df9_12',
#     'tool_name': 'samtools',
#     'tag': '1.3.1--h60f3df9_12',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h60f3df9_12',
#     'size_bytes': 21680128,
#     'mtime': 1734542986.0},
#    {'entry_name': 'samtools:1.3--h60f3df9_9',
#     'tool_name': 'samtools',
#     'tag': '1.3--h60f3df9_9',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h60f3df9_9',
#     'size_bytes': 21671936,
#     'mtime': 1734542973.0},
#    {'entry_name': 'samtools:1.6--h5fe306e_11',
#     'tool_name': 'samtools',
#     'tag': '1.6--h5fe306e_11',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h5fe306e_11',
#     'size_bytes': 22810624,
#     'mtime': 1734543000.0},
#    {'entry_name': 'samtools:1.21--h96c455f_1',
#     'tool_name': 'samtools',
#     'tag': '1.21--h96c455f_1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.21--h96c455f_1',
#     'size_bytes': 25513984,
#     'mtime': 1734542957.0},
#    {'entry_name': 'samtools:1.1--h96c455f_9',
#     'tool_name': 'samtools',
#     'tag': '1.1--h96c455f_9',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--h96c455f_9',
#     'size_bytes': 7876608,
#     'mtime': 1734542942.0},
#    {'entry_name': 'samtools:1.6--h5fe306e_12',
#     'tool_name': 'samtools',
#     'tag': '1.6--h5fe306e_12',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h5fe306e_12',
#     'size_bytes': 23175168,
#     'mtime': 1747070874.0},
#    {'entry_name': 'samtools:1.22--h96c455f_0',
#     'tool_name': 'samtools',
#     'tag': '1.22--h96c455f_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.22--h96c455f_0',
#     'size_bytes': 25956352,
#     'mtime': 1748917695.0},
#    {'entry_name': 'samtools:1.22.1--h96c455f_0',
#     'tool_name': 'samtools',
#     'tag': '1.22.1--h96c455f_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.22.1--h96c455f_0',
#     'size_bytes': 25968640,
#     'mtime': 1752544645.0},
#    {'entry_name': 'samtools:0.1.16--1',
#     'tool_name': 'samtools',
#     'tag': '0.1.16--1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.16--1',
#     'size_bytes': 9445376,
#     'mtime': 1752570120.0},
#    {'entry_name': 'samtools:1.2--1',
#     'tool_name': 'samtools',
#     'tag': '1.2--1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.2--1',
#     'size_bytes': 9842688,
#     'mtime': 1752578804.0},
#    {'entry_name': 'samtools:0.1.16--2',
#     'tool_name': 'samtools',
#     'tag': '0.1.16--2',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.16--2',
#     'size_bytes': 5496832,
#     'mtime': 1752856458.0},
#    {'entry_name': 'samtools:1.2--0--1',
#     'tool_name': 'samtools',
#     'tag': '1.2--0--1',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.2--0--1',
#     'size_bytes': 16252928,
#     'mtime': 1752895373.0},
#    {'entry_name': 'samtools:0.1.19--h96c455f_14',
#     'tool_name': 'samtools',
#     'tag': '0.1.19--h96c455f_14',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h96c455f_14',
#     'size_bytes': 12816384,
#     'mtime': 1754098487.0},
#    {'entry_name': 'samtools:1.6--h5fe306e_13',
#     'tool_name': 'samtools',
#     'tag': '1.6--h5fe306e_13',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h5fe306e_13',
#     'size_bytes': 22544384,
#     'mtime': 1758595447.0},
#    {'entry_name': 'samtools:1.23--h96c455f_0',
#     'tool_name': 'samtools',
#     'tag': '1.23--h96c455f_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.23--h96c455f_0',
#     'size_bytes': 29085696,
#     'mtime': 1765939608.0}]}]

# %%
_search_containers(["fakebot", "ggplot"], gx)
# Out:
# [{'found': False, 'tool_id': 'fakebot', 'containers': []},
#  {'found': True,
#   'tool_id': 'ggplot',
#   'containers': [{'entry_name': 'ggplot:0.6.8--py36_0',
#     'tool_name': 'ggplot',
#     'tag': '0.6.8--py36_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/ggplot:0.6.8--py36_0',
#     'size_bytes': 477306880,
#     'mtime': 1565920723.0}]}]

# %% [markdown]
# ## `describe_container()`

# %%
_describe_container(gx, bt, "ggplot")
# Out:
# {'found': True,
#  'tool_id': 'ggplot',
#  'containers': [{'entry_name': 'ggplot:0.6.8--py36_0',
#    'tool_name': 'ggplot',
#    'tag': '0.6.8--py36_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/ggplot:0.6.8--py36_0',
#    'size_bytes': 477306880,
#    'mtime': 1565920723.0}],
#  'metadata': {},
#  'versions': [{'tag': '0.6.8--py36_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/ggplot:0.6.8--py36_0',
#    'size_bytes': 477306880,
#    'mtime': 1565920723.0,
#    'entry_name': 'ggplot:0.6.8--py36_0'}]}

# %%
_describe_container(gx, bt, "samtools")
# Out:
# {'found': True,
#  'tool_id': 'samtools',
#  'containers': [{'entry_name': 'samtools:1.3--1',
#    'tool_name': 'samtools',
#    'tag': '1.3--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--1',
#    'size_bytes': 5083136,
#    'mtime': 1567233286.0},
#   {'entry_name': 'samtools:0.1.19--2',
#    'tool_name': 'samtools',
#    'tag': '0.1.19--2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--2',
#    'size_bytes': 8941568,
#    'mtime': 1567233201.0},
#   {'entry_name': 'samtools:0.1.15--0',
#    'tool_name': 'samtools',
#    'tag': '0.1.15--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.15--0',
#    'size_bytes': 15171584,
#    'mtime': 1566672582.0},
#   {'entry_name': 'samtools:1.7--0',
#    'tool_name': 'samtools',
#    'tag': '1.7--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.7--0',
#    'size_bytes': 24928256,
#    'mtime': 1567233243.0},
#   {'entry_name': 'samtools:1.5--2',
#    'tool_name': 'samtools',
#    'tag': '1.5--2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.5--2',
#    'size_bytes': 16613376,
#    'mtime': 1566672724.0},
#   {'entry_name': 'samtools:1.2.rglab--0',
#    'tool_name': 'samtools',
#    'tag': '1.2.rglab--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.2.rglab--0',
#    'size_bytes': 15081472,
#    'mtime': 1566672663.0},
#   {'entry_name': 'samtools:1.9--h91753b0_4',
#    'tool_name': 'samtools',
#    'tag': '1.9--h91753b0_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h91753b0_4',
#    'size_bytes': 26267648,
#    'mtime': 1567233524.0},
#   {'entry_name': 'samtools:1.6--0',
#    'tool_name': 'samtools',
#    'tag': '1.6--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--0',
#    'size_bytes': 24866816,
#    'mtime': 1566672741.0},
#   {'entry_name': 'samtools:1.4--0',
#    'tool_name': 'samtools',
#    'tag': '1.4--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.4--0',
#    'size_bytes': 10760192,
#    'mtime': 1566672698.0},
#   {'entry_name': 'samtools:1.9--h8571acd_11',
#    'tool_name': 'samtools',
#    'tag': '1.9--h8571acd_11',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h8571acd_11',
#    'size_bytes': 27271168,
#    'mtime': 1566672911.0},
#   {'entry_name': 'samtools:1.9--h8571acd_10',
#    'tool_name': 'samtools',
#    'tag': '1.9--h8571acd_10',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h8571acd_10',
#    'size_bytes': 27267072,
#    'mtime': 1567233320.0},
#   {'entry_name': 'samtools:1.3--2',
#    'tool_name': 'samtools',
#    'tag': '1.3--2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--2',
#    'size_bytes': 6459392,
#    'mtime': 1566672674.0},
#   {'entry_name': 'samtools:0.1.12--0',
#    'tool_name': 'samtools',
#    'tag': '0.1.12--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.12--0',
#    'size_bytes': 15060992,
#    'mtime': 1567233334.0},
#   {'entry_name': 'samtools:1.8--h46bd0b3_5',
#    'tool_name': 'samtools',
#    'tag': '1.8--h46bd0b3_5',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.8--h46bd0b3_5',
#    'size_bytes': 23281664,
#    'mtime': 1566672843.0},
#   {'entry_name': 'samtools:1.9--h91753b0_8',
#    'tool_name': 'samtools',
#    'tag': '1.9--h91753b0_8',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h91753b0_8',
#    'size_bytes': 26439680,
#    'mtime': 1566672944.0},
#   {'entry_name': 'samtools:0.1.19--h94a8ba4_6',
#    'tool_name': 'samtools',
#    'tag': '0.1.19--h94a8ba4_6',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h94a8ba4_6',
#    'size_bytes': 19910656,
#    'mtime': 1566672611.0},
#   {'entry_name': 'samtools:1.6--he673b24_3',
#    'tool_name': 'samtools',
#    'tag': '1.6--he673b24_3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--he673b24_3',
#    'size_bytes': 27086848,
#    'mtime': 1566672790.0},
#   {'entry_name': 'samtools:1.9--h10a08f8_12',
#    'tool_name': 'samtools',
#    'tag': '1.9--h10a08f8_12',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h10a08f8_12',
#    'size_bytes': 30167040,
#    'mtime': 1567745001.0},
#   {'entry_name': 'samtools:1.6--h02bfda8_2',
#    'tool_name': 'samtools',
#    'tag': '1.6--h02bfda8_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h02bfda8_2',
#    'size_bytes': 26087424,
#    'mtime': 1566672757.0},
#   {'entry_name': 'samtools:1.1--hf89b575_4',
#    'tool_name': 'samtools',
#    'tag': '1.1--hf89b575_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--hf89b575_4',
#    'size_bytes': 18546688,
#    'mtime': 1567233430.0},
#   {'entry_name': 'samtools:1.1--h94a8ba4_3',
#    'tool_name': 'samtools',
#    'tag': '1.1--h94a8ba4_3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--h94a8ba4_3',
#    'size_bytes': 16830464,
#    'mtime': 1566672650.0},
#   {'entry_name': 'samtools:1.5--1',
#    'tool_name': 'samtools',
#    'tag': '1.5--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.5--1',
#    'size_bytes': 16617472,
#    'mtime': 1567233548.0},
#   {'entry_name': 'samtools:1.7--2',
#    'tool_name': 'samtools',
#    'tag': '1.7--2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.7--2',
#    'size_bytes': 27439104,
#    'mtime': 1566672807.0},
#   {'entry_name': 'samtools:1.0--hdd8ed8b_2',
#    'tool_name': 'samtools',
#    'tag': '1.0--hdd8ed8b_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.0--hdd8ed8b_2',
#    'size_bytes': 12582912,
#    'mtime': 1566672636.0},
#   {'entry_name': 'samtools:0.1.14--1',
#    'tool_name': 'samtools',
#    'tag': '0.1.14--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.14--1',
#    'size_bytes': 15147008,
#    'mtime': 1566672568.0},
#   {'entry_name': 'samtools:1.9--h91753b0_3',
#    'tool_name': 'samtools',
#    'tag': '1.9--h91753b0_3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h91753b0_3',
#    'size_bytes': 26267648,
#    'mtime': 1567233567.0},
#   {'entry_name': 'samtools:0.1.19--3',
#    'tool_name': 'samtools',
#    'tag': '0.1.19--3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--3',
#    'size_bytes': 17596416,
#    'mtime': 1566672596.0},
#   {'entry_name': 'samtools:1.9--h91753b0_5',
#    'tool_name': 'samtools',
#    'tag': '1.9--h91753b0_5',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h91753b0_5',
#    'size_bytes': 26267648,
#    'mtime': 1567233504.0},
#   {'entry_name': 'samtools:1.9--h43f6869_9',
#    'tool_name': 'samtools',
#    'tag': '1.9--h43f6869_9',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h43f6869_9',
#    'size_bytes': 26439680,
#    'mtime': 1566672860.0},
#   {'entry_name': 'samtools:1.9--h91753b0_2',
#    'tool_name': 'samtools',
#    'tag': '1.9--h91753b0_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h91753b0_2',
#    'size_bytes': 26267648,
#    'mtime': 1567233589.0},
#   {'entry_name': 'samtools:1.0--0',
#    'tool_name': 'samtools',
#    'tag': '1.0--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.0--0',
#    'size_bytes': 4820992,
#    'mtime': 1567233382.0},
#   {'entry_name': 'samtools:1.9--h57cc563_6',
#    'tool_name': 'samtools',
#    'tag': '1.9--h57cc563_6',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h57cc563_6',
#    'size_bytes': 26267648,
#    'mtime': 1567233220.0},
#   {'entry_name': 'samtools:0.1.12--2',
#    'tool_name': 'samtools',
#    'tag': '0.1.12--2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.12--2',
#    'size_bytes': 15990784,
#    'mtime': 1566672541.0},
#   {'entry_name': 'samtools:0.1.13--0',
#    'tool_name': 'samtools',
#    'tag': '0.1.13--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.13--0',
#    'size_bytes': 15122432,
#    'mtime': 1567233279.0},
#   {'entry_name': 'samtools:1.5--0',
#    'tool_name': 'samtools',
#    'tag': '1.5--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.5--0',
#    'size_bytes': 11829248,
#    'mtime': 1567233535.0},
#   {'entry_name': 'samtools:1.3.1--3',
#    'tool_name': 'samtools',
#    'tag': '1.3.1--3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--3',
#    'size_bytes': 10768384,
#    'mtime': 1567233404.0},
#   {'entry_name': 'samtools:0.1.14--0',
#    'tool_name': 'samtools',
#    'tag': '0.1.14--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.14--0',
#    'size_bytes': 15138816,
#    'mtime': 1567233485.0},
#   {'entry_name': 'samtools:1.3.1--2',
#    'tool_name': 'samtools',
#    'tag': '1.3.1--2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--2',
#    'size_bytes': 11583488,
#    'mtime': 1567233415.0},
#   {'entry_name': 'samtools:1.9--h46bd0b3_0',
#    'tool_name': 'samtools',
#    'tag': '1.9--h46bd0b3_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h46bd0b3_0',
#    'size_bytes': 23293952,
#    'mtime': 1566672876.0},
#   {'entry_name': 'samtools:1.4.1--0',
#    'tool_name': 'samtools',
#    'tag': '1.4.1--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.4.1--0',
#    'size_bytes': 10764288,
#    'mtime': 1566672709.0},
#   {'entry_name': 'samtools:0.1.13--1',
#    'tool_name': 'samtools',
#    'tag': '0.1.13--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.13--1',
#    'size_bytes': 15130624,
#    'mtime': 1566672555.0},
#   {'entry_name': 'samtools:0.1.19--h94a8ba4_5',
#    'tool_name': 'samtools',
#    'tag': '0.1.19--h94a8ba4_5',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h94a8ba4_5',
#    'size_bytes': 17698816,
#    'mtime': 1567233300.0},
#   {'entry_name': 'samtools:1.3.1--5',
#    'tool_name': 'samtools',
#    'tag': '1.3.1--5',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--5',
#    'size_bytes': 10108928,
#    'mtime': 1566672686.0},
#   {'entry_name': 'samtools:1.3.1--4',
#    'tool_name': 'samtools',
#    'tag': '1.3.1--4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--4',
#    'size_bytes': 10768384,
#    'mtime': 1567233393.0},
#   {'entry_name': 'samtools:1.0--1',
#    'tool_name': 'samtools',
#    'tag': '1.0--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.0--1',
#    'size_bytes': 6144000,
#    'mtime': 1566672622.0},
#   {'entry_name': 'samtools:1.6--h4da6232_1',
#    'tool_name': 'samtools',
#    'tag': '1.6--h4da6232_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h4da6232_1',
#    'size_bytes': 21774336,
#    'mtime': 1566672772.0},
#   {'entry_name': 'samtools:1.6--h244ad75_4',
#    'tool_name': 'samtools',
#    'tag': '1.6--h244ad75_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h244ad75_4',
#    'size_bytes': 28876800,
#    'mtime': 1567233453.0},
#   {'entry_name': 'samtools:1.7--1',
#    'tool_name': 'samtools',
#    'tag': '1.7--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.7--1',
#    'size_bytes': 25194496,
#    'mtime': 1567233266.0},
#   {'entry_name': 'samtools:1.8--4',
#    'tool_name': 'samtools',
#    'tag': '1.8--4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.8--4',
#    'size_bytes': 27516928,
#    'mtime': 1566672825.0},
#   {'entry_name': 'samtools:1.9--h8ee4bcc_1',
#    'tool_name': 'samtools',
#    'tag': '1.9--h8ee4bcc_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h8ee4bcc_1',
#    'size_bytes': 25468928,
#    'mtime': 1566672928.0},
#   {'entry_name': 'samtools:1.9--h57cc563_7',
#    'tool_name': 'samtools',
#    'tag': '1.9--h57cc563_7',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h57cc563_7',
#    'size_bytes': 26439680,
#    'mtime': 1566672894.0},
#   {'entry_name': 'samtools:1.8--3',
#    'tool_name': 'samtools',
#    'tag': '1.8--3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.8--3',
#    'size_bytes': 27443200,
#    'mtime': 1567233355.0},
#   {'entry_name': 'samtools:1.8--2',
#    'tool_name': 'samtools',
#    'tag': '1.8--2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.8--2',
#    'size_bytes': 27410432,
#    'mtime': 1567233376.0},
#   {'entry_name': 'samtools:0.1.12--1',
#    'tool_name': 'samtools',
#    'tag': '0.1.12--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.12--1',
#    'size_bytes': 15982592,
#    'mtime': 1567233469.0},
#   {'entry_name': 'samtools:1.2-0',
#    'tool_name': 'samtools',
#    'tag': '1.2-0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.2-0',
#    'size_bytes': 15081472,
#    'mtime': 1578458984.0},
#   {'entry_name': 'samtools:1.3--h0592bc0_3',
#    'tool_name': 'samtools',
#    'tag': '1.3--h0592bc0_3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h0592bc0_3',
#    'size_bytes': 28184576,
#    'mtime': 1587102580.0},
#   {'entry_name': 'samtools:1.6--h244ad75_5',
#    'tool_name': 'samtools',
#    'tag': '1.6--h244ad75_5',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h244ad75_5',
#    'size_bytes': 28868608,
#    'mtime': 1572240316.0},
#   {'entry_name': 'samtools:1.10--h9402c20_0',
#    'tool_name': 'samtools',
#    'tag': '1.10--h9402c20_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.10--h9402c20_0',
#    'size_bytes': 30883840,
#    'mtime': 1575780266.0},
#   {'entry_name': 'samtools:1.2',
#    'tool_name': 'samtools',
#    'tag': '1.2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.2',
#    'size_bytes': 4673567,
#    'mtime': 1580725809.0},
#   {'entry_name': 'samtools:1.3.1--h0592bc0_6',
#    'tool_name': 'samtools',
#    'tag': '1.3.1--h0592bc0_6',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h0592bc0_6',
#    'size_bytes': 28028928,
#    'mtime': 1573620952.0},
#   {'entry_name': 'samtools:1.10--h9402c20_2',
#    'tool_name': 'samtools',
#    'tag': '1.10--h9402c20_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.10--h9402c20_2',
#    'size_bytes': 30732288,
#    'mtime': 1577335041.0},
#   {'entry_name': 'samtools:1.10--h9402c20_1',
#    'tool_name': 'samtools',
#    'tag': '1.10--h9402c20_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.10--h9402c20_1',
#    'size_bytes': 30748672,
#    'mtime': 1576385579.0},
#   {'entry_name': 'samtools:1.6--h9dace67_6',
#    'tool_name': 'samtools',
#    'tag': '1.6--h9dace67_6',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h9dace67_6',
#    'size_bytes': 29175808,
#    'mtime': 1593840974.0},
#   {'entry_name': 'samtools:0.1.19--hf89b575_7',
#    'tool_name': 'samtools',
#    'tag': '0.1.19--hf89b575_7',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--hf89b575_7',
#    'size_bytes': 21643264,
#    'mtime': 1593840928.0},
#   {'entry_name': 'samtools:1.3.1--h80b0bb3_7',
#    'tool_name': 'samtools',
#    'tag': '1.3.1--h80b0bb3_7',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h80b0bb3_7',
#    'size_bytes': 28295168,
#    'mtime': 1593840958.0},
#   {'entry_name': 'samtools:1.3--h80b0bb3_4',
#    'tool_name': 'samtools',
#    'tag': '1.3--h80b0bb3_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h80b0bb3_4',
#    'size_bytes': 28282880,
#    'mtime': 1593840943.0},
#   {'entry_name': 'samtools:1.11--h6270b1f_0',
#    'tool_name': 'samtools',
#    'tag': '1.11--h6270b1f_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.11--h6270b1f_0',
#    'size_bytes': 30932992,
#    'mtime': 1601962088.0},
#   {'entry_name': 'samtools:1.1--hfb9b9cc_5',
#    'tool_name': 'samtools',
#    'tag': '1.1--hfb9b9cc_5',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--hfb9b9cc_5',
#    'size_bytes': 18018304,
#    'mtime': 1598945503.0},
#   {'entry_name': 'samtools:0.1.19--hfb9b9cc_8',
#    'tool_name': 'samtools',
#    'tag': '0.1.19--hfb9b9cc_8',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--hfb9b9cc_8',
#    'size_bytes': 21094400,
#    'mtime': 1598945491.0},
#   {'entry_name': 'samtools:0.1.18--hfb9b9cc_10',
#    'tool_name': 'samtools',
#    'tag': '0.1.18--hfb9b9cc_10',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.18--hfb9b9cc_10',
#    'size_bytes': 13987840,
#    'mtime': 1606105551.0},
#   {'entry_name': 'samtools:1.10--h2e538c0_3',
#    'tool_name': 'samtools',
#    'tag': '1.10--h2e538c0_3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.10--h2e538c0_3',
#    'size_bytes': 30826496,
#    'mtime': 1598945521.0},
#   {'entry_name': 'samtools:0.1.16',
#    'tool_name': 'samtools',
#    'tag': '0.1.16',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.16',
#    'size_bytes': 4284447,
#    'mtime': 1611774443.0},
#   {'entry_name': 'samtools:1.12--hd5e65b6_0',
#    'tool_name': 'samtools',
#    'tag': '1.12--hd5e65b6_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.12--hd5e65b6_0',
#    'size_bytes': 31371264,
#    'mtime': 1616020387.0},
#   {'entry_name': 'samtools:1.6--hb116620_7',
#    'tool_name': 'samtools',
#    'tag': '1.6--hb116620_7',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--hb116620_7',
#    'size_bytes': 30642176,
#    'mtime': 1616939365.0},
#   {'entry_name': 'samtools:1.12--h9aed4be_1',
#    'tool_name': 'samtools',
#    'tag': '1.12--h9aed4be_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.12--h9aed4be_1',
#    'size_bytes': 32980992,
#    'mtime': 1616939316.0},
#   {'entry_name': 'samtools:0.1.18--h270b39a_11',
#    'tool_name': 'samtools',
#    'tag': '0.1.18--h270b39a_11',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.18--h270b39a_11',
#    'size_bytes': 15671296,
#    'mtime': 1616939277.0},
#   {'entry_name': 'samtools:1.1--h270b39a_6',
#    'tool_name': 'samtools',
#    'tag': '1.1--h270b39a_6',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--h270b39a_6',
#    'size_bytes': 15421440,
#    'mtime': 1616939299.0},
#   {'entry_name': 'samtools:1.3.1--h1b8c3c0_8',
#    'tool_name': 'samtools',
#    'tag': '1.3.1--h1b8c3c0_8',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h1b8c3c0_8',
#    'size_bytes': 29818880,
#    'mtime': 1616939348.0},
#   {'entry_name': 'samtools:0.1.19--h270b39a_9',
#    'tool_name': 'samtools',
#    'tag': '0.1.19--h270b39a_9',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h270b39a_9',
#    'size_bytes': 18968576,
#    'mtime': 1616939289.0},
#   {'entry_name': 'samtools:1.3--h1b8c3c0_5',
#    'tool_name': 'samtools',
#    'tag': '1.3--h1b8c3c0_5',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h1b8c3c0_5',
#    'size_bytes': 29806592,
#    'mtime': 1616939332.0},
#   {'entry_name': 'samtools:1.13--h8c37831_0',
#    'tool_name': 'samtools',
#    'tag': '1.13--h8c37831_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.13--h8c37831_0',
#    'size_bytes': 33050624,
#    'mtime': 1625893518.0},
#   {'entry_name': 'samtools:1.2--0',
#    'tool_name': 'samtools',
#    'tag': '1.2--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.2--0',
#    'size_bytes': 15081472,
#    'mtime': 1630560056.0},
#   {'entry_name': 'samtools:1.14--hb421002_0',
#    'tool_name': 'samtools',
#    'tag': '1.14--hb421002_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.14--hb421002_0',
#    'size_bytes': 25956352,
#    'mtime': 1635222951.0},
#   {'entry_name': 'samtools:1.15--h3843a85_0',
#    'tool_name': 'samtools',
#    'tag': '1.15--h3843a85_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.15--h3843a85_0',
#    'size_bytes': 25894912,
#    'mtime': 1645591369.0},
#   {'entry_name': 'samtools:1.6--h3f2fef4_8',
#    'tool_name': 'samtools',
#    'tag': '1.6--h3f2fef4_8',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h3f2fef4_8',
#    'size_bytes': 24383488,
#    'mtime': 1645591414.0},
#   {'entry_name': 'samtools:1.1--h20b1175_7',
#    'tool_name': 'samtools',
#    'tag': '1.1--h20b1175_7',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--h20b1175_7',
#    'size_bytes': 8036352,
#    'mtime': 1645591355.0},
#   {'entry_name': 'samtools:1.3--h41a57b0_6',
#    'tool_name': 'samtools',
#    'tag': '1.3--h41a57b0_6',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h41a57b0_6',
#    'size_bytes': 23552000,
#    'mtime': 1645591384.0},
#   {'entry_name': 'samtools:1.3.1--h41a57b0_9',
#    'tool_name': 'samtools',
#    'tag': '1.3.1--h41a57b0_9',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h41a57b0_9',
#    'size_bytes': 23564288,
#    'mtime': 1645591398.0},
#   {'entry_name': 'samtools:1.3.1--h9071d68_10',
#    'tool_name': 'samtools',
#    'tag': '1.3.1--h9071d68_10',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h9071d68_10',
#    'size_bytes': 22724608,
#    'mtime': 1645849601.0},
#   {'entry_name': 'samtools:1.6--hcd7b337_9',
#    'tool_name': 'samtools',
#    'tag': '1.6--hcd7b337_9',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--hcd7b337_9',
#    'size_bytes': 23539712,
#    'mtime': 1645849616.0},
#   {'entry_name': 'samtools:1.3--h9071d68_7',
#    'tool_name': 'samtools',
#    'tag': '1.3--h9071d68_7',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h9071d68_7',
#    'size_bytes': 22712320,
#    'mtime': 1645849587.0},
#   {'entry_name': 'samtools:1.15--h1170115_1',
#    'tool_name': 'samtools',
#    'tag': '1.15--h1170115_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.15--h1170115_1',
#    'size_bytes': 25931776,
#    'mtime': 1645849573.0},
#   {'entry_name': 'samtools:0.1.19--h20b1175_10',
#    'tool_name': 'samtools',
#    'tag': '0.1.19--h20b1175_10',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h20b1175_10',
#    'size_bytes': 11431936,
#    'mtime': 1646281497.0},
#   {'entry_name': 'samtools:0.1.18--h20b1175_12',
#    'tool_name': 'samtools',
#    'tag': '0.1.18--h20b1175_12',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.18--h20b1175_12',
#    'size_bytes': 8241152,
#    'mtime': 1646281490.0},
#   {'entry_name': 'samtools:1.15.1--h1170115_0',
#    'tool_name': 'samtools',
#    'tag': '1.15.1--h1170115_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.15.1--h1170115_0',
#    'size_bytes': 22114304,
#    'mtime': 1649394526.0},
#   {'entry_name': 'samtools:1.15.1--h6899075_1',
#    'tool_name': 'samtools',
#    'tag': '1.15.1--h6899075_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.15.1--h6899075_1',
#    'size_bytes': 22642688,
#    'mtime': 1663479189.0},
#   {'entry_name': 'samtools:1.16.1--h6899075_0',
#    'tool_name': 'samtools',
#    'tag': '1.16.1--h6899075_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.16.1--h6899075_0',
#    'size_bytes': 22659072,
#    'mtime': 1664862117.0},
#   {'entry_name': 'samtools:1.16.1--h6899075_1',
#    'tool_name': 'samtools',
#    'tag': '1.16.1--h6899075_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.16.1--h6899075_1',
#    'size_bytes': 22667264,
#    'mtime': 1665466977.0},
#   {'entry_name': 'samtools:1.16.1--h00cdaf9_2',
#    'tool_name': 'samtools',
#    'tag': '1.16.1--h00cdaf9_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.16.1--h00cdaf9_2',
#    'size_bytes': 22605824,
#    'mtime': 1678241797.0},
#   {'entry_name': 'samtools:1.17--h00cdaf9_0',
#    'tool_name': 'samtools',
#    'tag': '1.17--h00cdaf9_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.17--h00cdaf9_0',
#    'size_bytes': 22634496,
#    'mtime': 1680973648.0},
#   {'entry_name': 'samtools:1.1--h50ea8bc_8',
#    'tool_name': 'samtools',
#    'tag': '1.1--h50ea8bc_8',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--h50ea8bc_8',
#    'size_bytes': 8138752,
#    'mtime': 1684329537.0},
#   {'entry_name': 'samtools:0.1.19--h50ea8bc_11',
#    'tool_name': 'samtools',
#    'tag': '0.1.19--h50ea8bc_11',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h50ea8bc_11',
#    'size_bytes': 11509760,
#    'mtime': 1684329532.0},
#   {'entry_name': 'samtools:1.3.1--h0cf4675_11',
#    'tool_name': 'samtools',
#    'tag': '1.3.1--h0cf4675_11',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h0cf4675_11',
#    'size_bytes': 20373504,
#    'mtime': 1684329568.0},
#   {'entry_name': 'samtools:1.17--hd87286a_1',
#    'tool_name': 'samtools',
#    'tag': '1.17--hd87286a_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.17--hd87286a_1',
#    'size_bytes': 24088576,
#    'mtime': 1684329547.0},
#   {'entry_name': 'samtools:0.1.18--h50ea8bc_13',
#    'tool_name': 'samtools',
#    'tag': '0.1.18--h50ea8bc_13',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.18--h50ea8bc_13',
#    'size_bytes': 8347648,
#    'mtime': 1684329525.0},
#   {'entry_name': 'samtools:1.3--h0cf4675_8',
#    'tool_name': 'samtools',
#    'tag': '1.3--h0cf4675_8',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h0cf4675_8',
#    'size_bytes': 20361216,
#    'mtime': 1684329558.0},
#   {'entry_name': 'samtools:1.6--hc3601fc_10',
#    'tool_name': 'samtools',
#    'tag': '1.6--hc3601fc_10',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--hc3601fc_10',
#    'size_bytes': 21295104,
#    'mtime': 1684329578.0},
#   {'entry_name': 'samtools:1.17--hd87286a_2',
#    'tool_name': 'samtools',
#    'tag': '1.17--hd87286a_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.17--hd87286a_2',
#    'size_bytes': 24993792,
#    'mtime': 1695796914.0},
#   {'entry_name': 'samtools:1.18--hd87286a_0',
#    'tool_name': 'samtools',
#    'tag': '1.18--hd87286a_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.18--hd87286a_0',
#    'size_bytes': 25001984,
#    'mtime': 1696489712.0},
#   {'entry_name': 'samtools:1.18--h50ea8bc_1',
#    'tool_name': 'samtools',
#    'tag': '1.18--h50ea8bc_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.18--h50ea8bc_1',
#    'size_bytes': 25010176,
#    'mtime': 1696575535.0},
#   {'entry_name': 'samtools:1.19--h50ea8bc_0',
#    'tool_name': 'samtools',
#    'tag': '1.19--h50ea8bc_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.19--h50ea8bc_0',
#    'size_bytes': 25284608,
#    'mtime': 1702449613.0},
#   {'entry_name': 'samtools:1.19.1--h50ea8bc_0',
#    'tool_name': 'samtools',
#    'tag': '1.19.1--h50ea8bc_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.19.1--h50ea8bc_0',
#    'size_bytes': 25288704,
#    'mtime': 1705973293.0},
#   {'entry_name': 'samtools:1.19.2--h50ea8bc_0',
#    'tool_name': 'samtools',
#    'tag': '1.19.2--h50ea8bc_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.19.2--h50ea8bc_0',
#    'size_bytes': 25288704,
#    'mtime': 1706697298.0},
#   {'entry_name': 'samtools:1.19.2--h50ea8bc_1',
#    'tool_name': 'samtools',
#    'tag': '1.19.2--h50ea8bc_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.19.2--h50ea8bc_1',
#    'size_bytes': 25300992,
#    'mtime': 1709688756.0},
#   {'entry_name': 'samtools:1.20--h50ea8bc_0',
#    'tool_name': 'samtools',
#    'tag': '1.20--h50ea8bc_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.20--h50ea8bc_0',
#    'size_bytes': 25362432,
#    'mtime': 1713230880.0},
#   {'entry_name': 'samtools:1.20--h50ea8bc_1',
#    'tool_name': 'samtools',
#    'tag': '1.20--h50ea8bc_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.20--h50ea8bc_1',
#    'size_bytes': 25563136,
#    'mtime': 1720661568.0},
#   {'entry_name': 'samtools:1.21--h50ea8bc_0',
#    'tool_name': 'samtools',
#    'tag': '1.21--h50ea8bc_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.21--h50ea8bc_0',
#    'size_bytes': 25726976,
#    'mtime': 1726192714.0},
#   {'entry_name': 'samtools:0.1.18--h96c455f_14',
#    'tool_name': 'samtools',
#    'tag': '0.1.18--h96c455f_14',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.18--h96c455f_14',
#    'size_bytes': 8093696,
#    'mtime': 1733317525.0},
#   {'entry_name': 'samtools:0.1.19--h96c455f_12',
#    'tool_name': 'samtools',
#    'tag': '0.1.19--h96c455f_12',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h96c455f_12',
#    'size_bytes': 11276288,
#    'mtime': 1733317535.0},
#   {'entry_name': 'samtools:0.1.19--h96c455f_13',
#    'tool_name': 'samtools',
#    'tag': '0.1.19--h96c455f_13',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h96c455f_13',
#    'size_bytes': 11264000,
#    'mtime': 1733404440.0},
#   {'entry_name': 'samtools:1.3.1--h60f3df9_12',
#    'tool_name': 'samtools',
#    'tag': '1.3.1--h60f3df9_12',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h60f3df9_12',
#    'size_bytes': 21680128,
#    'mtime': 1734542986.0},
#   {'entry_name': 'samtools:1.3--h60f3df9_9',
#    'tool_name': 'samtools',
#    'tag': '1.3--h60f3df9_9',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h60f3df9_9',
#    'size_bytes': 21671936,
#    'mtime': 1734542973.0},
#   {'entry_name': 'samtools:1.6--h5fe306e_11',
#    'tool_name': 'samtools',
#    'tag': '1.6--h5fe306e_11',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h5fe306e_11',
#    'size_bytes': 22810624,
#    'mtime': 1734543000.0},
#   {'entry_name': 'samtools:1.21--h96c455f_1',
#    'tool_name': 'samtools',
#    'tag': '1.21--h96c455f_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.21--h96c455f_1',
#    'size_bytes': 25513984,
#    'mtime': 1734542957.0},
#   {'entry_name': 'samtools:1.1--h96c455f_9',
#    'tool_name': 'samtools',
#    'tag': '1.1--h96c455f_9',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--h96c455f_9',
#    'size_bytes': 7876608,
#    'mtime': 1734542942.0},
#   {'entry_name': 'samtools:1.6--h5fe306e_12',
#    'tool_name': 'samtools',
#    'tag': '1.6--h5fe306e_12',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h5fe306e_12',
#    'size_bytes': 23175168,
#    'mtime': 1747070874.0},
#   {'entry_name': 'samtools:1.22--h96c455f_0',
#    'tool_name': 'samtools',
#    'tag': '1.22--h96c455f_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.22--h96c455f_0',
#    'size_bytes': 25956352,
#    'mtime': 1748917695.0},
#   {'entry_name': 'samtools:1.22.1--h96c455f_0',
#    'tool_name': 'samtools',
#    'tag': '1.22.1--h96c455f_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.22.1--h96c455f_0',
#    'size_bytes': 25968640,
#    'mtime': 1752544645.0},
#   {'entry_name': 'samtools:0.1.16--1',
#    'tool_name': 'samtools',
#    'tag': '0.1.16--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.16--1',
#    'size_bytes': 9445376,
#    'mtime': 1752570120.0},
#   {'entry_name': 'samtools:1.2--1',
#    'tool_name': 'samtools',
#    'tag': '1.2--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.2--1',
#    'size_bytes': 9842688,
#    'mtime': 1752578804.0},
#   {'entry_name': 'samtools:0.1.16--2',
#    'tool_name': 'samtools',
#    'tag': '0.1.16--2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.16--2',
#    'size_bytes': 5496832,
#    'mtime': 1752856458.0},
#   {'entry_name': 'samtools:1.2--0--1',
#    'tool_name': 'samtools',
#    'tag': '1.2--0--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.2--0--1',
#    'size_bytes': 16252928,
#    'mtime': 1752895373.0},
#   {'entry_name': 'samtools:0.1.19--h96c455f_14',
#    'tool_name': 'samtools',
#    'tag': '0.1.19--h96c455f_14',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h96c455f_14',
#    'size_bytes': 12816384,
#    'mtime': 1754098487.0},
#   {'entry_name': 'samtools:1.6--h5fe306e_13',
#    'tool_name': 'samtools',
#    'tag': '1.6--h5fe306e_13',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h5fe306e_13',
#    'size_bytes': 22544384,
#    'mtime': 1758595447.0},
#   {'entry_name': 'samtools:1.23--h96c455f_0',
#    'tool_name': 'samtools',
#    'tag': '1.23--h96c455f_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.23--h96c455f_0',
#    'size_bytes': 29085696,
#    'mtime': 1765939608.0}],
#  'metadata': {'biocontainers': 'samtools',
#   'biotools': 'samtools',
#   'bunya': ['1.13-gcc-10.3.0',
#    '1.13-gcc-11.3.0',
#    '1.16.1-gcc-11.3.0',
#    '1.18-gcc-12.3.0                  (D)'],
#   'description': 'SAMtools and BCFtools are widely used programs for processing and analysing high-throughput sequencing data. They include tools for file format conversion and manipulation, sorting, querying, statistics, variant calling, and effect analysis amongst other methods.',
#   'edam-inputs': [{'formats': ['CRAM', 'SAM', 'BAM'], 'term': 'BAM'}],
#   'edam-operations': ['Data filtering',
#    'Visualisation',
#    'Data formatting',
#    'Indexing',
#    'Data parsing',
#    'Data sorting',
#    'Data editing'],
#   'edam-outputs': [{'formats': ['CRAM', 'SAM', 'BAM'], 'term': 'BAM'}],
#   'edam-topics': ['Mapping',
#    'Sequence analysis',
#    'Sequencing',
#    'Rare diseases'],
#   'galaxy': [{'description': 'Samtools markdup: marks duplicate alignments',
#     'title': 'Samtools markdup 1.22+galaxy1',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fsamtools_markdup%2Fsamtools_markdup%2F1.22%2Bgalaxy1'},
#    {'description': 'Samtools view: - reformat, filter, or subsample SAM, BAM or CRAM',
#     'title': 'Samtools view 1.22+galaxy1',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fsamtools_view%2Fsamtools_view%2F1.22%2Bgalaxy1'},
#    {'description': 'Samtools split: BAM dataset on readgroups',
#     'title': 'Samtools split 1.22+galaxy1',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_split%2Fsamtools_split%2F1.22%2Bgalaxy1'},
#    {'description': 'Slice: BAM by genomic regions',
#     'title': 'Slice 2.0.6',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_slice_bam%2Fsamtools_slice_bam%2F2.0.6'},
#    {'description': 'Samtools reheader: copy SAM/BAM header between datasets',
#     'title': 'Samtools reheader 2.0.6',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_reheader%2Fsamtools_reheader%2F2.0.6'},
#    {'description': 'Samtools phase: call and phase heterozygous SNPs',
#     'title': 'Samtools phase 2.0.2',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_phase%2Fsamtools_phase%2F2.0.2'},
#    {'description': 'Samtools mpileup: multi-way pileup of variants',
#     'title': 'Samtools mpileup 2.2.0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_mpileup%2Fsamtools_mpileup%2F2.2.0'},
#    {'description': 'Samtools merge: merge multiple sorted alignment files',
#     'title': 'Samtools merge 1.22+galaxy1',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fsamtools_merge%2Fsamtools_merge%2F1.22%2Bgalaxy1'},
#    {'description': 'Samtools idxstats: reports stats of the BAM index file',
#     'title': 'Samtools idxstats 2.0.8',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_idxstats%2Fsamtools_idxstats%2F2.0.8'},
#    {'description': 'Samtools fastx: extract FASTA or FASTQ from alignment files',
#     'title': 'Samtools fastx 1.22+galaxy1',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fsamtools_fastx%2Fsamtools_fastx%2F1.22%2Bgalaxy1'},
#    {'description': 'Samtools depth: compute the depth at each position or region',
#     'title': 'Samtools depth 1.22+galaxy1',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fsamtools_depth%2Fsamtools_depth%2F1.22%2Bgalaxy1'},
#    {'description': 'Samtools coverage: Produces a histogram or table of coverage per chromosome',
#     'title': 'Samtools coverage 1.22+galaxy3',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fsamtools_coverage%2Fsamtools_coverage%2F1.22%2Bgalaxy3'},
#    {'description': 'Samtools calmd: recalculate MD/NM tags',
#     'title': 'Samtools calmd 2.0.7',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_calmd%2Fsamtools_calmd%2F2.0.7'},
#    {'description': 'Samtools bedcov: calculate read depth for a set of genomic intervals',
#     'title': 'Samtools bedcov 2.0.7',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_bedcov%2Fsamtools_bedcov%2F2.0.7'},
#    {'description': 'BAM-to-SAM: convert BAM to SAM',
#     'title': 'BAM-to-SAM 2.0.7',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fbam_to_sam%2Fbam_to_sam%2F2.0.7'},
#    {'description': 'Samtools stats: generate statistics for BAM dataset',
#     'title': 'Samtools stats 2.0.8',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_stats%2Fsamtools_stats%2F2.0.8'},
#    {'description': 'Samtools sort: order of storing aligned sequences',
#     'title': 'Samtools sort 2.0.8',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_sort%2Fsamtools_sort%2F2.0.8'},
#    {'description': 'SAM-to-BAM: convert SAM to BAM',
#     'title': 'SAM-to-BAM 2.1.5',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsam_to_bam%2Fsam_to_bam%2F2.1.5'},
#    {'description': 'Samtools flagstat: tabulate descriptive stats for BAM datset',
#     'title': 'Samtools flagstat 2.0.8',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_flagstat%2Fsamtools_flagstat%2F2.0.8'},
#    {'description': 'Samtools fixmate: fill mate coordinates, ISIZE and mate related flags',
#     'title': 'Samtools fixmate 1.22+galaxy1',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fsamtools_fixmate%2Fsamtools_fixmate%2F1.22%2Bgalaxy1'},
#    {'description': 'Filter SAM or BAM, output SAM or BAM: files on FLAG MAPQ RG LN or by region',
#     'title': 'Filter SAM or BAM, output SAM or BAM 1.8+galaxy1',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtool_filter2%2Fsamtool_filter2%2F1.8%2Bgalaxy1'},
#    {'description': 'RmDup: remove PCR duplicates',
#     'title': 'RmDup 2.0.1',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_rmdup%2Fsamtools_rmdup%2F2.0.1'},
#    {'description': 'samtools BAM to CRAM: convert BAM alignments to CRAM format',
#     'title': 'samtools BAM to CRAM 1.22+galaxy1',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fsamtools_bam_to_cram%2Fsamtools_bam_to_cram%2F1.22%2Bgalaxy1'}],
#   'homepage': 'http://www.htslib.org/',
#   'id': 'samtools',
#   'license': 'MIT',
#   'name': 'SAMTools',
#   'nci-gadi': None,
#   'nci-if89': ['1.18', '1.19.2'],
#   'pawsey': ['1.15--h3843a85_0'],
#   'publications': [{'title': 'The Sequence Alignment/Map format and SAMtools',
#     'url': 'https://doi.org/10.1093/bioinformatics/btp352'},
#    {'title': 'Twelve years of SAMtools and BCFtools',
#     'url': 'https://doi.org/10.1093/gigascience/giab008'},
#    {'title': 'A statistical framework for SNP calling, mutation discovery, association mapping and population genetical parameter estimation from sequencing data',
#     'url': 'https://doi.org/10.1093/bioinformatics/btr509'}],
#   'resources': [{'title': nan, 'url': nan}]},
#  'versions': [{'tag': '1.3--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--1',
#    'size_bytes': 5083136,
#    'mtime': 1567233286.0,
#    'entry_name': 'samtools:1.3--1'},
#   {'tag': '0.1.19--2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--2',
#    'size_bytes': 8941568,
#    'mtime': 1567233201.0,
#    'entry_name': 'samtools:0.1.19--2'},
#   {'tag': '0.1.15--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.15--0',
#    'size_bytes': 15171584,
#    'mtime': 1566672582.0,
#    'entry_name': 'samtools:0.1.15--0'},
#   {'tag': '1.7--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.7--0',
#    'size_bytes': 24928256,
#    'mtime': 1567233243.0,
#    'entry_name': 'samtools:1.7--0'},
#   {'tag': '1.5--2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.5--2',
#    'size_bytes': 16613376,
#    'mtime': 1566672724.0,
#    'entry_name': 'samtools:1.5--2'},
#   {'tag': '1.2.rglab--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.2.rglab--0',
#    'size_bytes': 15081472,
#    'mtime': 1566672663.0,
#    'entry_name': 'samtools:1.2.rglab--0'},
#   {'tag': '1.9--h91753b0_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h91753b0_4',
#    'size_bytes': 26267648,
#    'mtime': 1567233524.0,
#    'entry_name': 'samtools:1.9--h91753b0_4'},
#   {'tag': '1.6--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--0',
#    'size_bytes': 24866816,
#    'mtime': 1566672741.0,
#    'entry_name': 'samtools:1.6--0'},
#   {'tag': '1.4--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.4--0',
#    'size_bytes': 10760192,
#    'mtime': 1566672698.0,
#    'entry_name': 'samtools:1.4--0'},
#   {'tag': '1.9--h8571acd_11',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h8571acd_11',
#    'size_bytes': 27271168,
#    'mtime': 1566672911.0,
#    'entry_name': 'samtools:1.9--h8571acd_11'},
#   {'tag': '1.9--h8571acd_10',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h8571acd_10',
#    'size_bytes': 27267072,
#    'mtime': 1567233320.0,
#    'entry_name': 'samtools:1.9--h8571acd_10'},
#   {'tag': '1.3--2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--2',
#    'size_bytes': 6459392,
#    'mtime': 1566672674.0,
#    'entry_name': 'samtools:1.3--2'},
#   {'tag': '0.1.12--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.12--0',
#    'size_bytes': 15060992,
#    'mtime': 1567233334.0,
#    'entry_name': 'samtools:0.1.12--0'},
#   {'tag': '1.8--h46bd0b3_5',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.8--h46bd0b3_5',
#    'size_bytes': 23281664,
#    'mtime': 1566672843.0,
#    'entry_name': 'samtools:1.8--h46bd0b3_5'},
#   {'tag': '1.9--h91753b0_8',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h91753b0_8',
#    'size_bytes': 26439680,
#    'mtime': 1566672944.0,
#    'entry_name': 'samtools:1.9--h91753b0_8'},
#   {'tag': '0.1.19--h94a8ba4_6',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h94a8ba4_6',
#    'size_bytes': 19910656,
#    'mtime': 1566672611.0,
#    'entry_name': 'samtools:0.1.19--h94a8ba4_6'},
#   {'tag': '1.6--he673b24_3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--he673b24_3',
#    'size_bytes': 27086848,
#    'mtime': 1566672790.0,
#    'entry_name': 'samtools:1.6--he673b24_3'},
#   {'tag': '1.9--h10a08f8_12',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h10a08f8_12',
#    'size_bytes': 30167040,
#    'mtime': 1567745001.0,
#    'entry_name': 'samtools:1.9--h10a08f8_12'},
#   {'tag': '1.6--h02bfda8_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h02bfda8_2',
#    'size_bytes': 26087424,
#    'mtime': 1566672757.0,
#    'entry_name': 'samtools:1.6--h02bfda8_2'},
#   {'tag': '1.1--hf89b575_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--hf89b575_4',
#    'size_bytes': 18546688,
#    'mtime': 1567233430.0,
#    'entry_name': 'samtools:1.1--hf89b575_4'},
#   {'tag': '1.1--h94a8ba4_3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--h94a8ba4_3',
#    'size_bytes': 16830464,
#    'mtime': 1566672650.0,
#    'entry_name': 'samtools:1.1--h94a8ba4_3'},
#   {'tag': '1.5--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.5--1',
#    'size_bytes': 16617472,
#    'mtime': 1567233548.0,
#    'entry_name': 'samtools:1.5--1'},
#   {'tag': '1.7--2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.7--2',
#    'size_bytes': 27439104,
#    'mtime': 1566672807.0,
#    'entry_name': 'samtools:1.7--2'},
#   {'tag': '1.0--hdd8ed8b_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.0--hdd8ed8b_2',
#    'size_bytes': 12582912,
#    'mtime': 1566672636.0,
#    'entry_name': 'samtools:1.0--hdd8ed8b_2'},
#   {'tag': '0.1.14--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.14--1',
#    'size_bytes': 15147008,
#    'mtime': 1566672568.0,
#    'entry_name': 'samtools:0.1.14--1'},
#   {'tag': '1.9--h91753b0_3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h91753b0_3',
#    'size_bytes': 26267648,
#    'mtime': 1567233567.0,
#    'entry_name': 'samtools:1.9--h91753b0_3'},
#   {'tag': '0.1.19--3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--3',
#    'size_bytes': 17596416,
#    'mtime': 1566672596.0,
#    'entry_name': 'samtools:0.1.19--3'},
#   {'tag': '1.9--h91753b0_5',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h91753b0_5',
#    'size_bytes': 26267648,
#    'mtime': 1567233504.0,
#    'entry_name': 'samtools:1.9--h91753b0_5'},
#   {'tag': '1.9--h43f6869_9',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h43f6869_9',
#    'size_bytes': 26439680,
#    'mtime': 1566672860.0,
#    'entry_name': 'samtools:1.9--h43f6869_9'},
#   {'tag': '1.9--h91753b0_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h91753b0_2',
#    'size_bytes': 26267648,
#    'mtime': 1567233589.0,
#    'entry_name': 'samtools:1.9--h91753b0_2'},
#   {'tag': '1.0--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.0--0',
#    'size_bytes': 4820992,
#    'mtime': 1567233382.0,
#    'entry_name': 'samtools:1.0--0'},
#   {'tag': '1.9--h57cc563_6',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h57cc563_6',
#    'size_bytes': 26267648,
#    'mtime': 1567233220.0,
#    'entry_name': 'samtools:1.9--h57cc563_6'},
#   {'tag': '0.1.12--2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.12--2',
#    'size_bytes': 15990784,
#    'mtime': 1566672541.0,
#    'entry_name': 'samtools:0.1.12--2'},
#   {'tag': '0.1.13--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.13--0',
#    'size_bytes': 15122432,
#    'mtime': 1567233279.0,
#    'entry_name': 'samtools:0.1.13--0'},
#   {'tag': '1.5--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.5--0',
#    'size_bytes': 11829248,
#    'mtime': 1567233535.0,
#    'entry_name': 'samtools:1.5--0'},
#   {'tag': '1.3.1--3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--3',
#    'size_bytes': 10768384,
#    'mtime': 1567233404.0,
#    'entry_name': 'samtools:1.3.1--3'},
#   {'tag': '0.1.14--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.14--0',
#    'size_bytes': 15138816,
#    'mtime': 1567233485.0,
#    'entry_name': 'samtools:0.1.14--0'},
#   {'tag': '1.3.1--2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--2',
#    'size_bytes': 11583488,
#    'mtime': 1567233415.0,
#    'entry_name': 'samtools:1.3.1--2'},
#   {'tag': '1.9--h46bd0b3_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.9--h46bd0b3_0',
#    'size_bytes': 23293952,
#    'mtime': 1566672876.0,
#    'entry_name': 'samtools:1.9--h46bd0b3_0'},
#   {'tag': '1.4.1--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.4.1--0',
#    'size_bytes': 10764288,
#    'mtime': 1566672709.0,
#    'entry_name': 'samtools:1.4.1--0'},
#   {'tag': '0.1.13--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.13--1',
#    'size_bytes': 15130624,
#    'mtime': 1566672555.0,
#    'entry_name': 'samtools:0.1.13--1'},
#   {'tag': '0.1.19--h94a8ba4_5',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h94a8ba4_5',
#    'size_bytes': 17698816,
#    'mtime': 1567233300.0,
#    'entry_name': 'samtools:0.1.19--h94a8ba4_5'},
#   {'tag': '1.3.1--5',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--5',
#    'size_bytes': 10108928,
#    'mtime': 1566672686.0,
#    'entry_name': 'samtools:1.3.1--5'},
#   {'tag': '1.3.1--4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--4',
#    'size_bytes': 10768384,
#    'mtime': 1567233393.0,
#    'entry_name': 'samtools:1.3.1--4'},
#   {'tag': '1.0--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.0--1',
#    'size_bytes': 6144000,
#    'mtime': 1566672622.0,
#    'entry_name': 'samtools:1.0--1'},
#   {'tag': '1.6--h4da6232_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h4da6232_1',
#    'size_bytes': 21774336,
#    'mtime': 1566672772.0,
#    'entry_name': 'samtools:1.6--h4da6232_1'},
#   {'tag': '1.6--h244ad75_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h244ad75_4',
# ...
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h0592bc0_6',
#    'size_bytes': 28028928,
#    'mtime': 1573620952.0,
#    'entry_name': 'samtools:1.3.1--h0592bc0_6'},
#   {'tag': '1.10--h9402c20_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.10--h9402c20_2',
#    'size_bytes': 30732288,
#    'mtime': 1577335041.0,
#    'entry_name': 'samtools:1.10--h9402c20_2'},
#   {'tag': '1.10--h9402c20_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.10--h9402c20_1',
#    'size_bytes': 30748672,
#    'mtime': 1576385579.0,
#    'entry_name': 'samtools:1.10--h9402c20_1'},
#   {'tag': '1.6--h9dace67_6',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h9dace67_6',
#    'size_bytes': 29175808,
#    'mtime': 1593840974.0,
#    'entry_name': 'samtools:1.6--h9dace67_6'},
#   {'tag': '0.1.19--hf89b575_7',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--hf89b575_7',
#    'size_bytes': 21643264,
#    'mtime': 1593840928.0,
#    'entry_name': 'samtools:0.1.19--hf89b575_7'},
#   {'tag': '1.3.1--h80b0bb3_7',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h80b0bb3_7',
#    'size_bytes': 28295168,
#    'mtime': 1593840958.0,
#    'entry_name': 'samtools:1.3.1--h80b0bb3_7'},
#   {'tag': '1.3--h80b0bb3_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h80b0bb3_4',
#    'size_bytes': 28282880,
#    'mtime': 1593840943.0,
#    'entry_name': 'samtools:1.3--h80b0bb3_4'},
#   {'tag': '1.11--h6270b1f_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.11--h6270b1f_0',
#    'size_bytes': 30932992,
#    'mtime': 1601962088.0,
#    'entry_name': 'samtools:1.11--h6270b1f_0'},
#   {'tag': '1.1--hfb9b9cc_5',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--hfb9b9cc_5',
#    'size_bytes': 18018304,
#    'mtime': 1598945503.0,
#    'entry_name': 'samtools:1.1--hfb9b9cc_5'},
#   {'tag': '0.1.19--hfb9b9cc_8',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--hfb9b9cc_8',
#    'size_bytes': 21094400,
#    'mtime': 1598945491.0,
#    'entry_name': 'samtools:0.1.19--hfb9b9cc_8'},
#   {'tag': '0.1.18--hfb9b9cc_10',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.18--hfb9b9cc_10',
#    'size_bytes': 13987840,
#    'mtime': 1606105551.0,
#    'entry_name': 'samtools:0.1.18--hfb9b9cc_10'},
#   {'tag': '1.10--h2e538c0_3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.10--h2e538c0_3',
#    'size_bytes': 30826496,
#    'mtime': 1598945521.0,
#    'entry_name': 'samtools:1.10--h2e538c0_3'},
#   {'tag': '0.1.16',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.16',
#    'size_bytes': 4284447,
#    'mtime': 1611774443.0,
#    'entry_name': 'samtools:0.1.16'},
#   {'tag': '1.12--hd5e65b6_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.12--hd5e65b6_0',
#    'size_bytes': 31371264,
#    'mtime': 1616020387.0,
#    'entry_name': 'samtools:1.12--hd5e65b6_0'},
#   {'tag': '1.6--hb116620_7',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--hb116620_7',
#    'size_bytes': 30642176,
#    'mtime': 1616939365.0,
#    'entry_name': 'samtools:1.6--hb116620_7'},
#   {'tag': '1.12--h9aed4be_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.12--h9aed4be_1',
#    'size_bytes': 32980992,
#    'mtime': 1616939316.0,
#    'entry_name': 'samtools:1.12--h9aed4be_1'},
#   {'tag': '0.1.18--h270b39a_11',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.18--h270b39a_11',
#    'size_bytes': 15671296,
#    'mtime': 1616939277.0,
#    'entry_name': 'samtools:0.1.18--h270b39a_11'},
#   {'tag': '1.1--h270b39a_6',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--h270b39a_6',
#    'size_bytes': 15421440,
#    'mtime': 1616939299.0,
#    'entry_name': 'samtools:1.1--h270b39a_6'},
#   {'tag': '1.3.1--h1b8c3c0_8',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h1b8c3c0_8',
#    'size_bytes': 29818880,
#    'mtime': 1616939348.0,
#    'entry_name': 'samtools:1.3.1--h1b8c3c0_8'},
#   {'tag': '0.1.19--h270b39a_9',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h270b39a_9',
#    'size_bytes': 18968576,
#    'mtime': 1616939289.0,
#    'entry_name': 'samtools:0.1.19--h270b39a_9'},
#   {'tag': '1.3--h1b8c3c0_5',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h1b8c3c0_5',
#    'size_bytes': 29806592,
#    'mtime': 1616939332.0,
#    'entry_name': 'samtools:1.3--h1b8c3c0_5'},
#   {'tag': '1.13--h8c37831_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.13--h8c37831_0',
#    'size_bytes': 33050624,
#    'mtime': 1625893518.0,
#    'entry_name': 'samtools:1.13--h8c37831_0'},
#   {'tag': '1.2--0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.2--0',
#    'size_bytes': 15081472,
#    'mtime': 1630560056.0,
#    'entry_name': 'samtools:1.2--0'},
#   {'tag': '1.14--hb421002_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.14--hb421002_0',
#    'size_bytes': 25956352,
#    'mtime': 1635222951.0,
#    'entry_name': 'samtools:1.14--hb421002_0'},
#   {'tag': '1.15--h3843a85_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.15--h3843a85_0',
#    'size_bytes': 25894912,
#    'mtime': 1645591369.0,
#    'entry_name': 'samtools:1.15--h3843a85_0'},
#   {'tag': '1.6--h3f2fef4_8',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h3f2fef4_8',
#    'size_bytes': 24383488,
#    'mtime': 1645591414.0,
#    'entry_name': 'samtools:1.6--h3f2fef4_8'},
#   {'tag': '1.1--h20b1175_7',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--h20b1175_7',
#    'size_bytes': 8036352,
#    'mtime': 1645591355.0,
#    'entry_name': 'samtools:1.1--h20b1175_7'},
#   {'tag': '1.3--h41a57b0_6',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h41a57b0_6',
#    'size_bytes': 23552000,
#    'mtime': 1645591384.0,
#    'entry_name': 'samtools:1.3--h41a57b0_6'},
#   {'tag': '1.3.1--h41a57b0_9',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h41a57b0_9',
#    'size_bytes': 23564288,
#    'mtime': 1645591398.0,
#    'entry_name': 'samtools:1.3.1--h41a57b0_9'},
#   {'tag': '1.3.1--h9071d68_10',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h9071d68_10',
#    'size_bytes': 22724608,
#    'mtime': 1645849601.0,
#    'entry_name': 'samtools:1.3.1--h9071d68_10'},
#   {'tag': '1.6--hcd7b337_9',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--hcd7b337_9',
#    'size_bytes': 23539712,
#    'mtime': 1645849616.0,
#    'entry_name': 'samtools:1.6--hcd7b337_9'},
#   {'tag': '1.3--h9071d68_7',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h9071d68_7',
#    'size_bytes': 22712320,
#    'mtime': 1645849587.0,
#    'entry_name': 'samtools:1.3--h9071d68_7'},
#   {'tag': '1.15--h1170115_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.15--h1170115_1',
#    'size_bytes': 25931776,
#    'mtime': 1645849573.0,
#    'entry_name': 'samtools:1.15--h1170115_1'},
#   {'tag': '0.1.19--h20b1175_10',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h20b1175_10',
#    'size_bytes': 11431936,
#    'mtime': 1646281497.0,
#    'entry_name': 'samtools:0.1.19--h20b1175_10'},
#   {'tag': '0.1.18--h20b1175_12',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.18--h20b1175_12',
#    'size_bytes': 8241152,
#    'mtime': 1646281490.0,
#    'entry_name': 'samtools:0.1.18--h20b1175_12'},
#   {'tag': '1.15.1--h1170115_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.15.1--h1170115_0',
#    'size_bytes': 22114304,
#    'mtime': 1649394526.0,
#    'entry_name': 'samtools:1.15.1--h1170115_0'},
#   {'tag': '1.15.1--h6899075_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.15.1--h6899075_1',
#    'size_bytes': 22642688,
#    'mtime': 1663479189.0,
#    'entry_name': 'samtools:1.15.1--h6899075_1'},
#   {'tag': '1.16.1--h6899075_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.16.1--h6899075_0',
#    'size_bytes': 22659072,
#    'mtime': 1664862117.0,
#    'entry_name': 'samtools:1.16.1--h6899075_0'},
#   {'tag': '1.16.1--h6899075_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.16.1--h6899075_1',
#    'size_bytes': 22667264,
#    'mtime': 1665466977.0,
#    'entry_name': 'samtools:1.16.1--h6899075_1'},
#   {'tag': '1.16.1--h00cdaf9_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.16.1--h00cdaf9_2',
#    'size_bytes': 22605824,
#    'mtime': 1678241797.0,
#    'entry_name': 'samtools:1.16.1--h00cdaf9_2'},
#   {'tag': '1.17--h00cdaf9_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.17--h00cdaf9_0',
#    'size_bytes': 22634496,
#    'mtime': 1680973648.0,
#    'entry_name': 'samtools:1.17--h00cdaf9_0'},
#   {'tag': '1.1--h50ea8bc_8',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--h50ea8bc_8',
#    'size_bytes': 8138752,
#    'mtime': 1684329537.0,
#    'entry_name': 'samtools:1.1--h50ea8bc_8'},
#   {'tag': '0.1.19--h50ea8bc_11',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h50ea8bc_11',
#    'size_bytes': 11509760,
#    'mtime': 1684329532.0,
#    'entry_name': 'samtools:0.1.19--h50ea8bc_11'},
#   {'tag': '1.3.1--h0cf4675_11',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h0cf4675_11',
#    'size_bytes': 20373504,
#    'mtime': 1684329568.0,
#    'entry_name': 'samtools:1.3.1--h0cf4675_11'},
#   {'tag': '1.17--hd87286a_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.17--hd87286a_1',
#    'size_bytes': 24088576,
#    'mtime': 1684329547.0,
#    'entry_name': 'samtools:1.17--hd87286a_1'},
#   {'tag': '0.1.18--h50ea8bc_13',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.18--h50ea8bc_13',
#    'size_bytes': 8347648,
#    'mtime': 1684329525.0,
#    'entry_name': 'samtools:0.1.18--h50ea8bc_13'},
#   {'tag': '1.3--h0cf4675_8',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h0cf4675_8',
#    'size_bytes': 20361216,
#    'mtime': 1684329558.0,
#    'entry_name': 'samtools:1.3--h0cf4675_8'},
#   {'tag': '1.6--hc3601fc_10',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--hc3601fc_10',
#    'size_bytes': 21295104,
#    'mtime': 1684329578.0,
#    'entry_name': 'samtools:1.6--hc3601fc_10'},
#   {'tag': '1.17--hd87286a_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.17--hd87286a_2',
#    'size_bytes': 24993792,
#    'mtime': 1695796914.0,
#    'entry_name': 'samtools:1.17--hd87286a_2'},
#   {'tag': '1.18--hd87286a_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.18--hd87286a_0',
#    'size_bytes': 25001984,
#    'mtime': 1696489712.0,
#    'entry_name': 'samtools:1.18--hd87286a_0'},
#   {'tag': '1.18--h50ea8bc_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.18--h50ea8bc_1',
#    'size_bytes': 25010176,
#    'mtime': 1696575535.0,
#    'entry_name': 'samtools:1.18--h50ea8bc_1'},
#   {'tag': '1.19--h50ea8bc_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.19--h50ea8bc_0',
#    'size_bytes': 25284608,
#    'mtime': 1702449613.0,
#    'entry_name': 'samtools:1.19--h50ea8bc_0'},
#   {'tag': '1.19.1--h50ea8bc_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.19.1--h50ea8bc_0',
#    'size_bytes': 25288704,
#    'mtime': 1705973293.0,
#    'entry_name': 'samtools:1.19.1--h50ea8bc_0'},
#   {'tag': '1.19.2--h50ea8bc_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.19.2--h50ea8bc_0',
#    'size_bytes': 25288704,
#    'mtime': 1706697298.0,
#    'entry_name': 'samtools:1.19.2--h50ea8bc_0'},
#   {'tag': '1.19.2--h50ea8bc_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.19.2--h50ea8bc_1',
#    'size_bytes': 25300992,
#    'mtime': 1709688756.0,
#    'entry_name': 'samtools:1.19.2--h50ea8bc_1'},
#   {'tag': '1.20--h50ea8bc_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.20--h50ea8bc_0',
#    'size_bytes': 25362432,
#    'mtime': 1713230880.0,
#    'entry_name': 'samtools:1.20--h50ea8bc_0'},
#   {'tag': '1.20--h50ea8bc_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.20--h50ea8bc_1',
#    'size_bytes': 25563136,
#    'mtime': 1720661568.0,
#    'entry_name': 'samtools:1.20--h50ea8bc_1'},
#   {'tag': '1.21--h50ea8bc_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.21--h50ea8bc_0',
#    'size_bytes': 25726976,
#    'mtime': 1726192714.0,
#    'entry_name': 'samtools:1.21--h50ea8bc_0'},
#   {'tag': '0.1.18--h96c455f_14',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.18--h96c455f_14',
#    'size_bytes': 8093696,
#    'mtime': 1733317525.0,
#    'entry_name': 'samtools:0.1.18--h96c455f_14'},
#   {'tag': '0.1.19--h96c455f_12',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h96c455f_12',
#    'size_bytes': 11276288,
#    'mtime': 1733317535.0,
#    'entry_name': 'samtools:0.1.19--h96c455f_12'},
#   {'tag': '0.1.19--h96c455f_13',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h96c455f_13',
#    'size_bytes': 11264000,
#    'mtime': 1733404440.0,
#    'entry_name': 'samtools:0.1.19--h96c455f_13'},
#   {'tag': '1.3.1--h60f3df9_12',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3.1--h60f3df9_12',
#    'size_bytes': 21680128,
#    'mtime': 1734542986.0,
#    'entry_name': 'samtools:1.3.1--h60f3df9_12'},
#   {'tag': '1.3--h60f3df9_9',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.3--h60f3df9_9',
#    'size_bytes': 21671936,
#    'mtime': 1734542973.0,
#    'entry_name': 'samtools:1.3--h60f3df9_9'},
#   {'tag': '1.6--h5fe306e_11',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h5fe306e_11',
#    'size_bytes': 22810624,
#    'mtime': 1734543000.0,
#    'entry_name': 'samtools:1.6--h5fe306e_11'},
#   {'tag': '1.21--h96c455f_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.21--h96c455f_1',
#    'size_bytes': 25513984,
#    'mtime': 1734542957.0,
#    'entry_name': 'samtools:1.21--h96c455f_1'},
#   {'tag': '1.1--h96c455f_9',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.1--h96c455f_9',
#    'size_bytes': 7876608,
#    'mtime': 1734542942.0,
#    'entry_name': 'samtools:1.1--h96c455f_9'},
#   {'tag': '1.6--h5fe306e_12',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h5fe306e_12',
#    'size_bytes': 23175168,
#    'mtime': 1747070874.0,
#    'entry_name': 'samtools:1.6--h5fe306e_12'},
#   {'tag': '1.22--h96c455f_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.22--h96c455f_0',
#    'size_bytes': 25956352,
#    'mtime': 1748917695.0,
#    'entry_name': 'samtools:1.22--h96c455f_0'},
#   {'tag': '1.22.1--h96c455f_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.22.1--h96c455f_0',
#    'size_bytes': 25968640,
#    'mtime': 1752544645.0,
#    'entry_name': 'samtools:1.22.1--h96c455f_0'},
#   {'tag': '0.1.16--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.16--1',
#    'size_bytes': 9445376,
#    'mtime': 1752570120.0,
#    'entry_name': 'samtools:0.1.16--1'},
#   {'tag': '1.2--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.2--1',
#    'size_bytes': 9842688,
#    'mtime': 1752578804.0,
#    'entry_name': 'samtools:1.2--1'},
#   {'tag': '0.1.16--2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.16--2',
#    'size_bytes': 5496832,
#    'mtime': 1752856458.0,
#    'entry_name': 'samtools:0.1.16--2'},
#   {'tag': '1.2--0--1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.2--0--1',
#    'size_bytes': 16252928,
#    'mtime': 1752895373.0,
#    'entry_name': 'samtools:1.2--0--1'},
#   {'tag': '0.1.19--h96c455f_14',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:0.1.19--h96c455f_14',
#    'size_bytes': 12816384,
#    'mtime': 1754098487.0,
#    'entry_name': 'samtools:0.1.19--h96c455f_14'},
#   {'tag': '1.6--h5fe306e_13',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.6--h5fe306e_13',
#    'size_bytes': 22544384,
#    'mtime': 1758595447.0,
#    'entry_name': 'samtools:1.6--h5fe306e_13'},
#   {'tag': '1.23--h96c455f_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/samtools:1.23--h96c455f_0',
#    'size_bytes': 29085696,
#    'mtime': 1765939608.0,
#    'entry_name': 'samtools:1.23--h96c455f_0'}]}

# %%
_describe_container(gx, bt, ["fakebot", "ggplot"])
# Out:
# [{'found': False,
#   'tool_id': 'fakebot',
#   'containers': [],
#   'metadata': {},
#   'versions': []},
#  {'found': True,
#   'tool_id': 'ggplot',
#   'containers': [{'entry_name': 'ggplot:0.6.8--py36_0',
#     'tool_name': 'ggplot',
#     'tag': '0.6.8--py36_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/ggplot:0.6.8--py36_0',
#     'size_bytes': 477306880,
#     'mtime': 1565920723.0}],
#   'metadata': {},
#   'versions': [{'tag': '0.6.8--py36_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/ggplot:0.6.8--py36_0',
#     'size_bytes': 477306880,
#     'mtime': 1565920723.0,
#     'entry_name': 'ggplot:0.6.8--py36_0'}]}]

# %% [markdown]
# ## Create metadata embeddings

# %%
from sentence_transformers.cross_encoder import CrossEncoder
from bio_mcp.cache.embeddings import *

# %%
# Load a pretrained ST model
model = CrossEncoder("cross-encoder/stsb-distilroberta-base")

# %%
example_queries = [
    "I have fastq files from a single cell sequencing experiment, what is the first step i can do?",
    "How do I qc, clustering and integration of my pre-processed scrna data?",
    "what tools are available for scrna analysis",
    "How can I remove technical artifacts (e.g. identify and remove doublets from my data)",
    "I have just generated scrna data, how do I analyse it for publication?"
]

# %%
# Create corpus of tool metadata
meta_text = []
for tool, _ in bt.items():
    text = make_embedding_text(bt.get(tool))
    meta_text.append(text)

# %%
meta_text

# %%
# Rank all 
ranks = model.rank(example_queries[0], meta_text)

# %%
print(f"Query: {example_queries[0]}")
for rank in ranks:
    print(f"{rank['score']:.2f}\t{meta_text[rank['corpus_id']]}")

# %%
rank2 = model.rank("What should I use for phylogenetics", meta_text)

# %%
for rank in rank2:
    print(f"{rank['score']:.2f}\t{meta_text[rank['corpus_id']]}")

# %% [markdown]
# ## Aliasing edams

# %%
all_yaml = load_biotools(Path("/home/ubuntu/cache/johan.yaml"))

# %%
all_yaml.get("samtools")
# Out:
# {'biocontainers': 'samtools',
#  'biotools': 'samtools',
#  'bunya': ['1.13-gcc-10.3.0',
#   '1.13-gcc-11.3.0',
#   '1.16.1-gcc-11.3.0',
#   '1.18-gcc-12.3.0                  (D)'],
#  'description': 'SAMtools and BCFtools are widely used programs for processing and analysing high-throughput sequencing data. They include tools for file format conversion and manipulation, sorting, querying, statistics, variant calling, and effect analysis amongst other methods.',
#  'edam-inputs': [{'formats': ['CRAM', 'SAM', 'BAM'], 'term': 'BAM'}],
#  'edam-operations': ['Data filtering',
#   'Visualisation',
#   'Data formatting',
#   'Indexing',
#   'Data parsing',
#   'Data sorting',
#   'Data editing'],
#  'edam-outputs': [{'formats': ['CRAM', 'SAM', 'BAM'], 'term': 'BAM'}],
#  'edam-topics': ['Mapping',
#   'Sequence analysis',
#   'Sequencing',
#   'Rare diseases'],
#  'galaxy': [{'description': 'Samtools markdup: marks duplicate alignments',
#    'title': 'Samtools markdup 1.22+galaxy1',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fsamtools_markdup%2Fsamtools_markdup%2F1.22%2Bgalaxy1'},
#   {'description': 'Samtools view: - reformat, filter, or subsample SAM, BAM or CRAM',
#    'title': 'Samtools view 1.22+galaxy1',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fsamtools_view%2Fsamtools_view%2F1.22%2Bgalaxy1'},
#   {'description': 'Samtools split: BAM dataset on readgroups',
#    'title': 'Samtools split 1.22+galaxy1',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_split%2Fsamtools_split%2F1.22%2Bgalaxy1'},
#   {'description': 'Slice: BAM by genomic regions',
#    'title': 'Slice 2.0.6',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_slice_bam%2Fsamtools_slice_bam%2F2.0.6'},
#   {'description': 'Samtools reheader: copy SAM/BAM header between datasets',
#    'title': 'Samtools reheader 2.0.6',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_reheader%2Fsamtools_reheader%2F2.0.6'},
#   {'description': 'Samtools phase: call and phase heterozygous SNPs',
#    'title': 'Samtools phase 2.0.2',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_phase%2Fsamtools_phase%2F2.0.2'},
#   {'description': 'Samtools mpileup: multi-way pileup of variants',
#    'title': 'Samtools mpileup 2.2.0',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_mpileup%2Fsamtools_mpileup%2F2.2.0'},
#   {'description': 'Samtools merge: merge multiple sorted alignment files',
#    'title': 'Samtools merge 1.22+galaxy1',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fsamtools_merge%2Fsamtools_merge%2F1.22%2Bgalaxy1'},
#   {'description': 'Samtools idxstats: reports stats of the BAM index file',
#    'title': 'Samtools idxstats 2.0.8',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_idxstats%2Fsamtools_idxstats%2F2.0.8'},
#   {'description': 'Samtools fastx: extract FASTA or FASTQ from alignment files',
#    'title': 'Samtools fastx 1.22+galaxy1',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fsamtools_fastx%2Fsamtools_fastx%2F1.22%2Bgalaxy1'},
#   {'description': 'Samtools depth: compute the depth at each position or region',
#    'title': 'Samtools depth 1.22+galaxy1',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fsamtools_depth%2Fsamtools_depth%2F1.22%2Bgalaxy1'},
#   {'description': 'Samtools coverage: Produces a histogram or table of coverage per chromosome',
#    'title': 'Samtools coverage 1.22+galaxy3',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fsamtools_coverage%2Fsamtools_coverage%2F1.22%2Bgalaxy3'},
#   {'description': 'Samtools calmd: recalculate MD/NM tags',
#    'title': 'Samtools calmd 2.0.7',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_calmd%2Fsamtools_calmd%2F2.0.7'},
#   {'description': 'Samtools bedcov: calculate read depth for a set of genomic intervals',
#    'title': 'Samtools bedcov 2.0.7',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_bedcov%2Fsamtools_bedcov%2F2.0.7'},
#   {'description': 'BAM-to-SAM: convert BAM to SAM',
#    'title': 'BAM-to-SAM 2.0.7',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fbam_to_sam%2Fbam_to_sam%2F2.0.7'},
#   {'description': 'Samtools stats: generate statistics for BAM dataset',
#    'title': 'Samtools stats 2.0.8',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_stats%2Fsamtools_stats%2F2.0.8'},
#   {'description': 'Samtools sort: order of storing aligned sequences',
#    'title': 'Samtools sort 2.0.8',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_sort%2Fsamtools_sort%2F2.0.8'},
#   {'description': 'SAM-to-BAM: convert SAM to BAM',
#    'title': 'SAM-to-BAM 2.1.5',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsam_to_bam%2Fsam_to_bam%2F2.1.5'},
#   {'description': 'Samtools flagstat: tabulate descriptive stats for BAM datset',
#    'title': 'Samtools flagstat 2.0.8',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_flagstat%2Fsamtools_flagstat%2F2.0.8'},
#   {'description': 'Samtools fixmate: fill mate coordinates, ISIZE and mate related flags',
#    'title': 'Samtools fixmate 1.22+galaxy1',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fsamtools_fixmate%2Fsamtools_fixmate%2F1.22%2Bgalaxy1'},
#   {'description': 'Filter SAM or BAM, output SAM or BAM: files on FLAG MAPQ RG LN or by region',
#    'title': 'Filter SAM or BAM, output SAM or BAM 1.8+galaxy1',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtool_filter2%2Fsamtool_filter2%2F1.8%2Bgalaxy1'},
#   {'description': 'RmDup: remove PCR duplicates',
#    'title': 'RmDup 2.0.1',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Fsamtools_rmdup%2Fsamtools_rmdup%2F2.0.1'},
#   {'description': 'samtools BAM to CRAM: convert BAM alignments to CRAM format',
#    'title': 'samtools BAM to CRAM 1.22+galaxy1',
#    'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fsamtools_bam_to_cram%2Fsamtools_bam_to_cram%2F1.22%2Bgalaxy1'}],
#  'homepage': 'http://www.htslib.org/',
#  'id': 'samtools',
#  'license': 'MIT',
#  'name': 'SAMTools',
#  'nci-gadi': None,
#  'nci-if89': ['1.18', '1.19.2'],
#  'pawsey': ['1.15--h3843a85_0'],
#  'publications': [{'title': 'The Sequence Alignment/Map format and SAMtools',
#    'url': 'https://doi.org/10.1093/bioinformatics/btp352'},
#   {'title': 'Twelve years of SAMtools and BCFtools',
#    'url': 'https://doi.org/10.1093/gigascience/giab008'},
#   {'title': 'A statistical framework for SNP calling, mutation discovery, association mapping and population genetical parameter estimation from sequencing data',
#    'url': 'https://doi.org/10.1093/bioinformatics/btr509'}],
#  'resources': [{'title': nan, 'url': nan}]}

# %%
collected_data = []
for tool_id, tool_data in all_yaml.items():
    entry = {
        "id": tool_id,
        "description": tool_data.get("description", ""),
        "edam_inputs": tool_data.get("edam-inputs", []),
        "edam_outputs": tool_data.get("edam-outputs", []),
        "edam_operations": tool_data.get("edam-operations", []),
        "edam_topics": tool_data.get("edam-topics", []),
    }
    collected_data.append(entry)

# %%
collected_data
# Out:
# [{'id': '3d-dna',
#   'description': '3D de novo assembly (3D-DNA) is a pipeline for de novo assembly using HiC.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Scaffolding', 'De-novo assembly', 'Genome assembly'],
#   'edam_topics': ['Sequence assembly', 'Mapping', 'DNA']},
#  {'id': 'abricate',
#   'description': 'Mass screening of contigs for antimicrobial resistance or virulence genes.',
#   'edam_inputs': [{'formats': ['EMBL format', 'GenBank format', 'FASTA'],
#     'term': 'FASTA'},
#    {'formats': ['FASTA'], 'term': 'FASTA'}],
#   'edam_outputs': [{'formats': ['TSV'], 'term': 'TSV'}],
#   'edam_operations': ['Antimicrobial resistance prediction'],
#   'edam_topics': ['Genomics', 'Microbiology']},
#  {'id': 'abritamr',
#   'description': 'an AMR gene detection pipeline that runs AMRFinderPlus on a single (or list ) of given isolates and collates the results into a table, separating genes identified into functionally relevant groups.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Antimicrobial resistance prediction'],
#   'edam_topics': ['Microbiology',
#    'Public health and epidemiology',
#    'Infectious disease',
#    'Antimicrobial resistance']},
#  {'id': 'abyss',
#   'description': 'De novo genome sequence assembler using short reads.',
#   'edam_inputs': [{'formats': ['FASTQ', 'FASTA'], 'term': 'FASTA'}],
#   'edam_outputs': [{'formats': ['FASTA'], 'term': 'FASTA'}],
#   'edam_operations': ['Genome assembly', 'De-novo assembly', 'Scaffolding'],
#   'edam_topics': ['Sequence assembly']},
#  {'id': 'agat',
#   'description': 'Another Gff Analysis Toolkit (AGAT)\nSuite of tools to handle gene annotations in any GTF/GFF format.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Data handling', 'Genome annotation'],
#   'edam_topics': ['Genomics']},
#  {'id': 'alignit',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'alphafold_2',
#   'description': "AI-guided 3D structure prediction of novel proteins. AlphaFold uses neural networks to predict the tertiary (3D) structure of proteins. AlphaFold accepts an amino acid sequence as an input, which it will then will 'fold' into a 3D model.",
#   'edam_inputs': [{'formats': ['FASTA-like (text)',
#      'plain text format (unformatted)'],
#     'term': 'plain text format (unformatted)'}],
#   'edam_outputs': [{'formats': [], 'term': 'Protein structure'}],
#   'edam_operations': ['Protein folding analysis',
#    'Backbone modelling',
#    'Loop modelling',
#    'Side chain modelling'],
#   'edam_topics': ['Protein folding, stability and design']},
#  {'id': 'alphapickle',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'amber',
#   'description': 'The Assisted Model Building with Energy Refinement tool refers to two things: a set of molecular mechanical force fields for the simulation of biomolecules (which are in the public domain, and are used in a variety of simulation programs); and a package of molecular simulation programs which includes source code and demos.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Modelling and simulation'],
#   'edam_topics': ['Molecular modelling', 'Computational biology']},
#  {'id': 'ambertools',
#   'description': 'Consists of several independently developed packages that work well by themselves, and with Amber (Assisted Model Building with Energy Refinement) itself. The suite can also be used to carry out complete (non-periodic) molecular dynamics simulations (using NAB), with generalized Born solvent models.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Molecular dynamics simulation'],
#   'edam_topics': ['Molecular modelling', 'Molecular dynamics']},
#  {'id': 'anaconda',
#   'description': 'Software package specially developed for the study of genes’ primary structure. It uses gene sequences downloaded from public databases, as FASTA and GenBank, and it applies a set of statistical and visualization methods in different ways, to reveal information about codon context, codon usage, nucleotide repeats within open reading frames (ORFeome) and others.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Statistical inference',
#    'Nucleic acid sequence analysis',
#    'Coding region prediction'],
#   'edam_topics': ['DNA', 'Gene expression']},
#  {'id': 'anndata',
#   'description': 'From https://anndata.readthedocs.io/en/latest/\n"Python package for handling annotated data matrices in memory and on disk, positioned between pandas and xarray."',
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'annotatemyids',
#   'description': 'This tool can get annotation for a generic set of IDs, using the Bioconductor annotation data packages. Supported organisms are human, mouse, rat, fruit fly and zebrafish. The org.db packages that are used here are primarily based on mapping using Entrez Gene identifiers. More information on the annotation packages can be found at the Bioconductor website, for example, information on the human annotation package (org.Hs.eg.db) can be found here.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Annotation'],
#   'edam_topics': None},
#  {'id': 'antismash',
#   'description': 'Rapid genome-wide identification, annotation and analysis of secondary metabolite biosynthesis gene clusters in bacterial and fungal genomes. It integrates and cross-links with a large number of in silico secondary metabolite analysis tools that have been published earlier.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Sequence clustering',
#    'Gene prediction',
#    'Differential gene expression analysis'],
#   'edam_topics': ['Molecular interactions, pathways and networks',
#    'Gene and protein families']},
#  {'id': 'any2fasta',
#   'description': 'Convert various sequence formats to FASTA',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Formatting', 'Sequence conversion'],
#   'edam_topics': ['Data quality management', 'Genomics']},
#  {'id': 'apollo',
#   'description': 'Apollo is a genome annotation viewer and editor. Apollo allows researchers to explore genomic annotations at many levels of detail, and to perform expert annotation curation, all in a graphical environment.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Editing', 'Sequence annotation', 'Genome annotation'],
#   'edam_topics': ['Data submission, annotation and curation',
#    'Gene transcripts',
#    'Genomics',
#    'Mapping',
#    'Molecular interactions, pathways and networks']},
#  {'id': 'aragorn',
#   'description': 'ARAGORN detects tRNA, mtRNA info about tmRNA, and tmRNA genes',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Gene prediction'],
#   'edam_topics': ['Functional, regulatory and non-coding RNA', 'Genomics']},
#  {'id': 'aarnet_filesender',
#   'description': 'FileSender is an open source web application for sending files of any size, quickly and securely. FileSender is available to all institutions affiliated with the Australian Access Federation (AAF). You can use your institution login details to access and use FileSender.',
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'arriba',
#   'description': 'Arriba is a command-line tool to detect gene fusions from RNA-Seq data based on the STAR aligner. In addition to fusions, it can detect exon duplications/inversions and truncations of genes (i.e., breakpoints in introns and intergenic regions). Arriba is the winner of the DREAM SMC-RNA Challenge.',
#   'edam_inputs': [{'formats': ['BAM', 'SAM', 'CRAM', 'FASTQ-illumina'],
#     'term': 'FASTQ-illumina'}],
#   'edam_outputs': [{'formats': ['TSV'], 'term': 'TSV'}],
#   'edam_operations': ['Structural variation detection', 'Split read mapping'],
#   'edam_topics': ['Gene transcripts',
#    'RNA splicing',
#    'DNA structural variation']},
#  {'id': 'artic',
#   'description': 'A bioinformatics pipeline for working with virus sequencing data sequenced with nanopore',
#   'edam_inputs': [{'formats': ['FASTQ-like format (text)'],
#     'term': 'FASTQ-like format (text)'},
#    {'formats': ['BED'], 'term': 'BED'}],
#   'edam_outputs': [{'formats': ['BAM'], 'term': 'BAM'},
#    {'formats': ['VCF'], 'term': 'VCF'}],
#   'edam_operations': ['Sequence alignment'],
#   'edam_topics': ['Genomics']},
#  {'id': 'augustus',
#   'description': 'AUGUSTUS is a eukaryotic gene prediction tool. It can integrate evidence, e.g. from RNA-Seq, ESTs, proteomics, but can also predict genes ab initio. The PPX extension to AUGUSTUS can take a protein sequence multiple sequence alignment as input to find new members of the family in a genome. It can be run through a web interface (see https://bio.tools/webaugustus), or downloaded and run locally.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Gene prediction'],
#   'edam_topics': ['Gene transcripts', 'Gene and protein families']},
#  {'id': 'autodock_vina',
#   'description': 'AutoDock Vina is a new open-source program for drug discovery, molecular docking and virtual screening, offering multi-core capability, high performance and enhanced accuracy and ease of use.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Molecular docking'],
#   'edam_topics': ['Drug discovery',
#    'Molecular modelling',
#    'Molecular docking']},
#  {'id': 'b2btools',
#   'description': "The bio2byte tools server (b2btools) offers the following single protein sequence based predictions:\n- Backbone and sidechain dynamics (DynaMine)\n- Helix, sheet, coil and polyproline-II propensity\n- Early folding propensity (EFoldMine)\n- Disorder (DisoMine)\n- Beta-sheet aggregation (Agmata)\n\nIn addition, multiple sequence alignments (MSAs) can be uploaded to scan the 'biophysical limits' of a protein family as defined in the MSA",
#   'edam_inputs': [{'formats': ['FASTA'], 'term': 'FASTA'}],
#   'edam_outputs': [],
#   'edam_operations': ['Protein disorder prediction',
#    'Protein secondary structure prediction',
#    'Protein feature detection'],
#   'edam_topics': None},
#  {'id': 'bakta',
#   'description': 'Rapid & standardized annotation of bacterial genomes, MAGs & plasmids',
#   'edam_inputs': [{'formats': ['FASTA'], 'term': 'FASTA'},
#    {'formats': ['TSV'], 'term': 'TSV'},
#    {'formats': ['GFF3'], 'term': 'GFF3'},
#    {'formats': ['FASTA'], 'term': 'FASTA'},
#    {'formats': ['HMMER3'], 'term': 'HMMER3'}],
#   'edam_outputs': [{'formats': ['GenBank format',
#      'EMBL format',
#      'GFF3',
#      'JSON',
#      'TSV'],
#     'term': 'TSV'},
#    {'formats': ['FASTA'], 'term': 'FASTA'},
#    {'formats': ['FASTA'], 'term': 'FASTA'},
#    {'formats': ['PNG', 'SVG'], 'term': 'SVG'},
#    {'formats': ['TSV'], 'term': 'TSV'}],
#   'edam_operations': ['Genome annotation'],
#   'edam_topics': ['Genomics', 'Sequence analysis', 'Bioinformatics']},
#  {'id': 'bamtools',
#   'description': 'BamTools provides a fast, flexible C++ API & toolkit for reading, writing, and managing BAM files.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Data handling', 'Sequence alignment analysis'],
#   'edam_topics': ['Sequencing', 'Data management', 'Sequence analysis']},
#  {'id': 'bamutil_diff',
#   'description': 'Bamutil provides a serie of programs to work on SAM/BAM files.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Data handling'],
#   'edam_topics': ['Data management']},
#  {'id': 'bandage',
#   'description': 'GUI program that allows users to interact with the assembly graphs made by de novo assemblers such as Velvet, SPAdes, MEGAHIT and others. It visualises assembly graphs, with connections, using graph layout algorithms.',
#   'edam_inputs': [{'formats': [], 'term': 'Sequence assembly'}],
#   'edam_outputs': [],
#   'edam_operations': ['Sequence assembly visualisation'],
#   'edam_topics': ['Genomics', 'Sequence assembly']},
#  {'id': 'baredsc',
#   'description': 'The baredSC (Bayesian Approach to Retreive Expression Distribution of Single Cell) is a tool that uses a Monte-Carlo Markov Chain to estimate a confidence interval on the probability density function (PDF) of expression of one or two genes from single-cell RNA-seq data.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Data retrieval',
#    'Expression correlation analysis',
#    'Differential gene expression profiling'],
#   'edam_topics': ['RNA-Seq',
#    'Cytometry',
#    'Transcriptomics',
#    'Gene transcripts',
#    'Statistics and probability']},
#  {'id': 'barrnap',
#   'description': 'Predict the location of ribosomal RNA genes in genomes. It supports bacteria (5S,23S,16S), archaea (5S,5.8S,23S,16S), mitochondria (12S,16S) and eukaryotes (5S,5.8S,28S,18S).',
#   'edam_inputs': [{'formats': ['FASTA'], 'term': 'FASTA'}],
#   'edam_outputs': [{'formats': ['GFF3'], 'term': 'GFF3'}],
#   'edam_operations': ['Gene prediction'],
#   'edam_topics': ['Genomics', 'Model organisms', 'Model organisms']},
#  {'id': 'basespace',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'bbmap',
#   'description': 'BBMap is a fast splice-aware aligner for RNA and DNA.  It is faster than almost all short-read aligners, yet retains unrivaled sensitivity and specificity, particularly for reads with many errors and indels.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['RNA-Seq analysis',
#    'Sequence trimming',
#    'Read mapping',
#    'Sequence contamination filtering',
#    'Read binning',
#    'Sequence alignment'],
#   'edam_topics': ['Sequencing',
#    'RNA splicing',
#    'Whole genome sequencing',
#    'Phylogenetics',
#    'Metagenomics',
#    'RNA-Seq']},
#  {'id': 'bbtools',
#   'description': 'BBTools is a suite of fast, multithreaded bioinformatics tools designed for analysis of DNA and RNA sequence data. BBTools can handle common sequencing file formats such as fastq, fasta, sam, scarf, fasta+qual, compressed or raw, with autodetection of quality encoding and interleaving. It is written in Java and works on any platform supporting Java, including Linux, MacOS, and Microsoft Windows and Linux; there are no dependencies other than Java (version 7 or higher). Program descriptions and options are shown when running the shell scripts with no parameters.\n\nBBTools is open source and free for unlimited use, and is used regularly by DOE JGI and other institutions around the world.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Sequence analysis'],
#   'edam_topics': ['Sequence analysis']},
#  {'id': 'bcbiogff',
#   'description': 'A tool for filling the gap created by genomic data processing/analysis by rebasing some analysis results against the parent features which were originally analysed.',
#   'edam_inputs': [{'formats': [], 'term': 'Identifier (by type of data)'}],
#   'edam_outputs': [],
#   'edam_operations': ['Data handling', 'Formatting'],
#   'edam_topics': None},
#  {'id': 'bcftools',
#   'description': 'BCFtools is a set of utilities that manipulate variant calls in the Variant Call Format (VCF) and its binary counterpart BCF. All commands work transparently with both VCFs and BCFs, both uncompressed and BGZF-compressed.',
#   'edam_inputs': [{'formats': ['BCF', 'VCF'], 'term': 'VCF'}],
#   'edam_outputs': [{'formats': ['BCF', 'VCF'], 'term': 'VCF'}],
#   'edam_operations': ['Variant calling', 'Data handling'],
#   'edam_topics': ['Genetic variation',
#    'DNA polymorphism',
#    'GWAS study',
#    'Genotyping experiment']},
#  {'id': 'bcl2fastq2',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'beacon2',
#   'description': 'A global search engine for genetic mutations.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Service discovery',
#    'Database search',
#    'Genetic variation analysis'],
#   'edam_topics': ['Genetic variation',
#    'Population genetics',
#    'Data security',
#    'Rare diseases']},
#  {'id': 'beagle',
#   'description': 'Beagle is a software package that performs genotype calling, genotype phasing, imputation of ungenotyped markers, and identity-by-descent segment detection.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Phasing', 'Imputation'],
#   'edam_topics': ['Population genetics']},
#  {'id': 'beagle-lib',
#   'description': 'BEAGLE is a high-performance library that can perform the core calculations at the heart of most Bayesian and Maximum Likelihood phylogenetics packages.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Phylogenetic inference',
#    'Standardisation and normalisation'],
#   'edam_topics': ['Phylogenetics',
#    'Statistics and probability',
#    'Computer science']},
#  {'id': 'beast',
#   'description': 'The Bayesian Evolutionary Analysis Sampling Trees is a cross-platform program for Bayesian analysis of molecular sequences using MCMC (Markov chain Monte Carlo). It is entirely orientated towards rooted, time-measured phylogenies inferred using strict or relaxed molecular clock models. It can be used as a method of reconstructing phylogenies but is also a framework for testing evolutionary hypotheses without conditioning on a single tree topology.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Multiple sequence alignment',
#    'Phylogenetic tree generation (from molecular sequences)',
#    'Phylogenetic tree generation (maximum likelihood and Bayesian methods)'],
#   'edam_topics': ['Phylogenetics', 'Sequence analysis']},
#  {'id': 'beast2',
#   'description': 'Bayesian phylogenetic analysis of molecular sequences. It estimates rooted, time-measured phylogenies using strict or relaxed molecular clock models. It can be used as a method of reconstructing phylogenies but is also a framework for testing evolutionary hypotheses without conditioning on a single tree topology. It uses Markov chain Monte Carlo (MCMC) to average over tree space, so that each tree is weighted proportional to its posterior probability. It includes a graphical user-interface for setting up standard analyses and a suit of programs for analysing the results.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Phylogenetic tree reconstruction',
#    'Phylogenetic tree analysis (shape)'],
#   'edam_topics': ['Phylogenetics', 'Phylogenomics']},
#  {'id': 'bed_to_protein_map',
#   'description': 'Convert a BED format file of the proteins from a proteomics search database into a tabular format for the Multiomics Visualization Platform (MVP).',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Conversion'],
#   'edam_topics': ['Literature and language']},
#  {'id': 'bedtools',
#   'description': 'BEDTools is an extensive suite of utilities for comparing genomic features in BED format.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Mapping'],
#   'edam_topics': ['Genomics']},
#  {'id': 'bellerophon',
#   'description': 'The Bellerophon pipeline, improving de novo transcriptomes and removing chimeras.\n\nBellerophon is a pipeline created to remove falsely assembled chimeric transcripts in de novo transcriptome assemblies.\n\nThe pipeline can be downloaded as a vragrant virtual machine (https://app.vagrantup.com/bellerophon/boxes/bellerophon). This is recommended, as it avoids backwards compatibility problems with TransRate',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['De-novo assembly',
#    'Validation',
#    'de Novo sequencing',
#    'Transcriptome assembly',
#    'Chimera detection'],
#   'edam_topics': ['Transcriptomics',
#    'Sequence assembly',
#    'RNA-Seq',
#    'Workflows']},
#  {'id': 'berokka',
#   'description': 'Trim, circularise, orient and filter long read bacterial genome assemblies',
#   'edam_inputs': [{'formats': ['FASTA'], 'term': 'FASTA'}],
#   'edam_outputs': [],
#   'edam_operations': ['Filtering', 'Sequence trimming'],
#   'edam_topics': ['Computer science']},
#  {'id': 'bftools',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'binchicken',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'bindcraft',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'binette',
#   'description': 'Binette is a fast and accurate binning refinement tool to constructs high quality MAGs from the output of multiple binning tools.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Read binning'],
#   'edam_topics': ['Metagenomics']},
#  {'id': 'bio-searchio-hmmer',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'bio3d',
#   'description': 'Bio3D is an R package containing utilities for the analysis of protein structure, sequence and trajectory data.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Essential dynamics',
#    'Molecular dynamics',
#    'Protein structure analysis',
#    'Principal component visualisation',
#    'Sequence trimming'],
#   'edam_topics': ['Structure analysis',
#    'Gene and protein families',
#    'Bioinformatics']},
#  {'id': 'biobakery_workflows',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'bio-db-hts',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'bioformats2raw',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'biom-format',
#   'description': 'This package includes basic tools for reading biom-format files, accessing and subsetting data tables from a biom object, as well as limited support for writing a biom-object back to a biom-format file. The design of this API is intended to match the python API and other tools included with the biom-format project, but with a decidedly "R flavor" that should be familiar to R users. This includes S4 classes and methods, as well as extensions of common core functions/methods.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Formatting'],
#   'edam_topics': ['Laboratory information management', 'Sequence analysis']},
#  {'id': 'bionano_solve',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'bioperl',
#   'description': 'A collection of Perl modules that facilitate the development of Perl scripts for bioinformatics applications.  It provides software modules for many of the typical tasks of bioinformatics programming.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Data handling', 'Service invocation'],
#   'edam_topics': ['Genomics', 'Software engineering', 'Data management']},
#  {'id': 'biopython',
#   'description': 'Biopython is a set of freely available tools for biological computation written in Python by an international team of developers.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Deposition',
#    'Service invocation',
#    'Query and retrieval',
#    'Aggregation'],
#   'edam_topics': ['Bioinformatics',
#    'Data management',
#    'Software engineering',
#    'Computational biology']},
#  {'id': 'biotransformer',
#   'description': 'BioTransformer is a freely available web server that supports accurate, rapid and comprehensive in silico metabolism prediction.',
#   'edam_inputs': [{'formats': ['SMILES'], 'term': 'SMILES'}],
#   'edam_outputs': [{'formats': ['SMILES'], 'term': 'SMILES'}],
#   'edam_operations': ['Metabolic pathway prediction',
#    'PTM site prediction',
#    'Natural product identification'],
#   'edam_topics': ['Small molecules',
#    'Endocrinology and metabolism',
#    'Metabolomics',
#    'Carbohydrates',
#    'NMR']},
#  {'id': 'bismark',
#   'description': 'Bismark is a tool to map bisulfite treated sequencing reads and perform methylation calling in a quick and easy-to-use fashion.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Methylation analysis',
#    'Read mapping',
#    'Bisulfite mapping'],
#   'edam_topics': ['Epigenomics', 'Genomics', 'Epigenetics']},
#  {'id': 'blast',
#   'description': 'A tool that finds regions of similarity between biological sequences. The program compares nucleotide or protein sequences to sequence databases and calculates the statistical significance.',
#   'edam_inputs': [{'formats': ['FASTA'], 'term': 'FASTA'}],
#   'edam_outputs': [{'formats': ['BLAST XML results format',
#      'BLAST XML v2 results format',
#      'TSV',
#      'CSV',
#      'ASN.1 sequence format',
#      'JSON',
#      'Binary format',
#      'Textual format'],
#     'term': 'Textual format'}],
#   'edam_operations': ['Sequence similarity search', 'Sequence alignment'],
#   'edam_topics': ['Sequence analysis', 'Bioinformatics']},
#  {'id': 'blast+',
#   'description': 'A tool that finds regions of similarity between biological sequences. The program compares nucleotide or protein sequences to sequence databases and calculates the statistical significance.',
#   'edam_inputs': [{'formats': ['FASTA'], 'term': 'FASTA'}],
#   'edam_outputs': [{'formats': ['BLAST XML results format',
#      'BLAST XML v2 results format',
#      'TSV',
#      'CSV',
#      'ASN.1 sequence format',
#      'JSON',
#      'Binary format',
#      'Textual format'],
#     'term': 'Textual format'}],
#   'edam_operations': ['Sequence similarity search', 'Sequence alignment'],
#   'edam_topics': ['Sequence analysis', 'Bioinformatics']},
#  {'id': 'blat',
#   'description': 'Fast, accurate spliced alignment of DNA sequences.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Sequence alignment'],
#   'edam_topics': ['Sequence analysis']},
#  {'id': 'Blockbuster',
#   'description': 'detect blocks of overlapping reads using a gaussian-distribution approach',
#   'edam_inputs': [{'formats': ['BED'], 'term': 'BED'}],
#   'edam_outputs': [{'formats': ['Textual format'], 'term': 'Textual format'}],
#   'edam_operations': ['RNA-Seq analysis'],
#   'edam_topics': ['Genomics']},
#  {'id': 'BlockClust',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'blue-crab',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'bolt-lmm',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'boltz',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'boost',
#   'description': 'Boost is a set of libraries for the C++ programming language that provides support for tasks and structures such as linear algebra, pseudorandom number generation, multithreading, image processing, regular expressions, and unit testing.',
#   'edam_inputs': [{'formats': ['Workflow format'], 'term': 'Workflow format'},
#    {'formats': [], 'term': 'Image'}],
#   'edam_outputs': [],
#   'edam_operations': ['Image analysis'],
#   'edam_topics': ['Pure mathematics', 'Imaging', 'Software engineering']},
#  {'id': 'bowtie',
#   'description': 'Bowtie is an ultrafast, memory-efficient short read aligner.',
#   'edam_inputs': [{'formats': ['HTML', 'FASTA'], 'term': 'FASTA'},
#    {'formats': ['FASTQ-solexa', 'FASTQ-sanger', 'FASTQ-illumina'],
#     'term': 'FASTQ-illumina'}],
#   'edam_outputs': [{'formats': ['SAM'], 'term': 'SAM'},
#    {'formats': ['Textual format'], 'term': 'Textual format'},
#    {'formats': ['FASTQ'], 'term': 'FASTQ'}],
#   'edam_operations': ['Sequence alignment'],
#   'edam_topics': ['Mapping', 'Genomics', 'Sequencing', 'Sequence assembly']},
#  {'id': 'bowtie2',
#   'description': 'Bowtie 2 is an ultrafast and memory-efficient tool for aligning sequencing reads to long reference sequences. It is particularly good at aligning reads of about 50 up to 100s or 1,000s of characters, and particularly good at aligning to relatively long (e.g. mammalian) genomes. Bowtie 2 indexes the genome with an FM Index to keep its memory footprint small: for the human genome, its memory footprint is typically around 3.2 GB. Bowtie 2 supports gapped, local, and paired-end alignment modes.',
#   'edam_inputs': [{'formats': ['FASTQ'], 'term': 'FASTQ'}],
#   'edam_outputs': [{'formats': ['BAM', 'SAM'], 'term': 'SAM'}],
#   'edam_operations': ['Read mapping'],
#   'edam_topics': ['Mapping', 'Genomics', 'Mapping']},
#  {'id': 'bracken',
#   'description': 'Bracken is a companion program to Kraken 1, KrakenUniq, or Kraken 2 While Kraken classifies reads to multiple levels in the taxonomic tree, Bracken allows estimation of abundance at a single level using those classifications (e.g. Bracken can estimate abundance of species within a sample).',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Statistical calculation'],
#   'edam_topics': ['Metagenomics', 'Microbial ecology']},
#  {'id': 'braker',
#   'description': 'Pipeline for unsupervised RNA-Seq-based genome annotation with GeneMark-ET and AUGUSTUS.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Genome annotation'],
#   'edam_topics': ['RNA-Seq', 'RNA', 'Workflows']},
#  {'id': 'breseq',
#   'description': 'Runs Breseq software on a set of fastq files.',
#   'edam_inputs': [{'formats': ['FASTQ'], 'term': 'FASTQ'},
#    {'formats': ['SAM'], 'term': 'SAM'},
#    {'formats': ['TSV'], 'term': 'TSV'}],
#   'edam_outputs': [{'formats': ['Textual format'], 'term': 'Textual format'}],
#   'edam_operations': ['Polymorphism detection'],
#   'edam_topics': ['Sequencing', 'Sequence analysis', 'DNA mutation']},
#  {'id': 'busco',
#   'description': 'Provides measures for quantitative assessment of genome assembly, gene set, and transcriptome completeness based on evolutionarily informed expectations of gene content from near-universal single-copy orthologs.',
#   'edam_inputs': [{'formats': ['FASTA'], 'term': 'FASTA'}],
#   'edam_outputs': [{'formats': [], 'term': 'Sequence report'}],
#   'edam_operations': ['Sequence assembly validation'],
#   'edam_topics': ['Sequence assembly',
#    'Genomics',
#    'Transcriptomics',
#    'Sequence analysis']},
#  {'id': 'buttery-eel',
#   'description': 'Accelerated nanopore basecalling with SLOW5 data format.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Base-calling', 'Formatting', 'Splitting'],
#   'edam_topics': ['Computer science',
#    'Protein expression',
#    'Workflows',
#    'Transcription factors and regulatory sites']},
#  {'id': 'bwa',
#   'description': 'Fast, accurate, memory-efficient aligner for short and long sequencing reads',
#   'edam_inputs': [{'formats': ['FASTA'], 'term': 'FASTA'}],
#   'edam_outputs': [{'formats': [], 'term': 'Genome index'}],
#   'edam_operations': ['Genome indexing'],
#   'edam_topics': ['Mapping']},
#  {'id': 'bwa-mem2',
#   'description': 'Bwa-mem2 is the next version of the bwa-mem algorithm in bwa. It produces alignment identical to bwa and is ~1.3-3.1x faster depending on the use-case,  dataset and the running machine.',
#   'edam_inputs': [{'formats': ['FASTA'], 'term': 'FASTA'}],
#   'edam_outputs': [],
#   'edam_operations': ['Sequence alignment'],
#   'edam_topics': ['Mapping']},
#  {'id': 'BWA-meth',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'bwakit',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'bx-python',
#   'description': 'Tools for manipulating biological data, particularly multiple sequence alignments.',
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': ['Sequence analysis']},
#  {'id': 'c3s',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'cactus',
#   'description': 'Cactus is a reference-free whole-genome multiple alignment program.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Multiple sequence alignment', 'Genome alignment'],
#   'edam_topics': ['Genomics',
#    'Sequence analysis',
#    'Phylogeny',
#    'Sequence assembly',
#    'Mapping',
#    'Phylogenetics']},
#  {'id': 'camera',
#   'description': 'Annotation of peaklists generated by xcms, rule based annotation of isotopes and adducts, isotope validation, EIC correlation based tagging of unknown adducts and fragments.',
#   'edam_inputs': [{'formats': ['Binary format'], 'term': 'Binary format'}],
#   'edam_outputs': [{'formats': ['DSV'], 'term': 'DSV'}],
#   'edam_operations': ['Annotation', 'Spectral analysis'],
#   'edam_topics': ['Metabolomics']},
#  {'id': 'cami-amber',
#   'description': 'AMBER is an evaluation package for the comparative assessment of genome reconstructions and taxonomic assignments from metagenome benchmark datasets. It provides performance metrics, results rankings, and comparative visualizations for assessing multiple programs or parameter effects. The provided metrics were used in the first community benchmarking challenge of the initiative for the Critical Assessment of Metagenomic Interpretation.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Read binning'],
#   'edam_topics': ['Metagenomics']},
#  {'id': 'canu',
#   'description': 'De-novo assembly tool for long read chemistry like Nanopore data and PacBio data.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['De-novo assembly'],
#   'edam_topics': ['Genomics']},
#  {'id': 'cap3',
#   'description': 'Web-based contig assembly.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Genome assembly',
#    'Mapping assembly',
#    'Sequence assembly',
#    'Scaffolding'],
#   'edam_topics': ['Sequence assembly',
#    'Sequencing',
#    'Sequence analysis',
#    'Genetic variation']},
#  {'id': 'cardinal',
#   'description': 'Implements statistical and computational tools for analyzing mass spectrometry imaging datasets, including methods for efficient pre-processing, spatial segmentation, and classification.',
#   'edam_inputs': [{'formats': ['imzML metadata file', 'ibd'], 'term': 'ibd'}],
#   'edam_outputs': [{'formats': ['imzML metadata file', 'ibd'], 'term': 'ibd'}],
#   'edam_operations': ['Spectral analysis',
#    'Standardisation and normalisation',
#    'Mass spectra calibration'],
#   'edam_topics': ['Proteomics', 'Data visualisation']},
#  {'id': 'cat_bins',
#   'description': 'Contig Annotation Tool (CAT) and Bin Annotation Tool (BAT) are pipelines for the taxonomic classification of long DNA sequences and metagenome assembled genomes (MAGs/bins) of both known and (highly) unknown microorganisms, as generated by contemporary metagenomics studies. The core algorithm of both programs involves gene calling, mapping of predicted ORFs against the nr protein database, and voting-based classification of the entire contig / MAG based on classification of the individual ORFs.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Taxonomic classification',
#    'Sequence assembly',
#    'Coding region prediction'],
#   'edam_topics': ['Metagenomics',
#    'Metagenomic sequencing',
#    'Taxonomy',
#    'Sequence assembly']},
#  {'id': 'cd-hit',
#   'description': 'Cluster a nucleotide dataset into representative sequences.',
#   'edam_inputs': [{'formats': ['FASTA'], 'term': 'FASTA'}],
#   'edam_outputs': [{'formats': ['Textual format'], 'term': 'Textual format'},
#    {'formats': ['Textual format'], 'term': 'Textual format'},
#    {'formats': ['FASTA'], 'term': 'FASTA'}],
#   'edam_operations': ['Sequence clustering'],
#   'edam_topics': ['Sequencing']},
#  {'id': 'cebraem',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'celseq2',
#   'description': 'celseq2 is a Python framework for generating the UMI count matrix from CEL-Seq2 sequencing data.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Demultiplexing', 'RNA-Seq analysis'],
#   'edam_topics': ['RNA-Seq', 'Transcriptomics']},
#  {'id': 'cellbender',
#   'description': 'a deep generative model for unsupervised removal of background noise from scRNA-seq datasets.\n\nCellBender is a software package for eliminating technical artifacts from high-throughput single-cell RNA sequencing (scRNA-seq) data.\n\nWelcome to CellBender’s documentation! — CellBender documentation.\n\nFree document hosting provided by Read the Docs.\n\nStephen J Fleming, John C Marioni, and Mehrtash Babadi. CellBender remove-background: a deep generative model for unsupervised removal of background noise from scRNA-seq datasets. bioRxiv 791699; doi: https://doi.org/10.1101/791699.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Quantification',
#    'Data retrieval',
#    'Expression analysis'],
#   'edam_topics': ['Gene expression', 'RNA', 'RNA-Seq']},
#  {'id': 'cellpose',
#   'description': 'Cellpose is a generalist algorithm for cellular segmentation.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Neurite measurement',
#    'Microscope image visualisation',
#    'Standardisation and normalisation'],
#   'edam_topics': ['Imaging',
#    'Cell biology',
#    'Machine learning',
#    'Transcription factors and regulatory sites']},
#  {'id': 'CellProfiler',
#   'description': 'Tool for quantifying data from biological images, particularly in high-throughput experiments.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Quantification', 'Image analysis', 'Parsing'],
#   'edam_topics': ['Imaging',
#    'Microarray experiment',
#    'Genotype and phenotype']},
#  {'id': 'cellranger',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'cellsnp-lite',
#   'description': 'cellsnp-lite is an efficient tool for genotyping single cells. cellsnp-lite was initially designed to pileup the expressed alleles in single-cell or bulk RNA-seq data, which can be directly used for donor deconvolution in multiplexed single-cell RNA-seq data, particularly with vireo, which assigns cells to donors and detects doublets, even without genotyping reference. Now besides RNA-seq data, cellsnp-lite could also be applied on DNA-seq and ATAC-seq data, either in bulk or single-cell.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Genotyping', 'SNP detection'],
#   'edam_topics': ['Genotype and phenotype', 'DNA polymorphism']},
#  {'id': 'cellxgene',
#   'description': 'cellxgene (pronounced "cell-by-gene") is an interactive data explorer for single-cell transcriptomics datasets, such as those coming from the Human Cell Atlas.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Visualisation', 'Essential dynamics'],
#   'edam_topics': ['Transcriptomics', 'Cell biology']},
#  {'id': 'cemitool',
#   'description': 'It unifies the discovery and the analysis of coexpression gene modules in a fully automatic manner, while providing a user-friendly html report with high quality graphs. Our tool evaluates if modules contain genes that are over-represented by specific pathways or that are altered in a specific sample group. Additionally, CEMiTool is able to integrate transcriptomic data with interactome information, identifying the potential hubs on each network.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Enrichment analysis'],
#   'edam_topics': ['Gene expression',
#    'Transcriptomics',
#    'Microarray experiment']},
#  {'id': 'chai-1',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'checkm',
#   'description': 'CheckM provides a set of tools for assessing the quality of genomes recovered from isolates, single cells, or metagenomes.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Sequence assembly validation',
#    'Validation',
#    'Sequence composition calculation',
#    'Sequencing quality control',
#    'Statistical calculation'],
#   'edam_topics': ['Genomics',
#    'Phylogenomics',
#    'Phylogenetics',
#    'Taxonomy',
#    'Metagenomics',
#    'Data quality management']},
#  {'id': 'checkm-database',
#   'description': 'CheckM provides a set of tools for assessing the quality of genomes recovered from isolates, single cells, or metagenomes.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Sequence assembly validation',
#    'Validation',
#    'Sequence composition calculation',
#    'Sequencing quality control',
#    'Statistical calculation'],
#   'edam_topics': ['Genomics',
#    'Phylogenomics',
#    'Phylogenetics',
#    'Taxonomy',
#    'Metagenomics',
#    'Data quality management']},
#  {'id': 'chembl',
#   'description': 'Database of bioactive compounds, their quantitative properties and bioactivities (binding constants, pharmacology and ADMET, etc). The data is abstracted and curated from the primary scientific literature.',
#   'edam_inputs': [{'formats': [], 'term': 'Compound ID (ChEMBL)'}],
#   'edam_outputs': [{'formats': ['HTML'], 'term': 'HTML'}],
#   'edam_operations': ['Data retrieval'],
#   'edam_topics': ['Small molecules', 'Chemical biology', 'Cheminformatics']},
#  {'id': 'chemfp',
#   'description': 'Fast cheminformatics fingerprint search, at your fingertips.\n\nChemfp is a set of command-line tools and a Python library for fingerprint generation and high-performance similarity search.\n\nThere are two ways to try out chemfp. From the download page page you can request an evaluation copy of the most recent version of chemfp, or you can download an earlier version for no cost under the MIT license',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Database search',
#    'Standardisation and normalisation',
#    'Formatting'],
#   'edam_topics': ['Cheminformatics',
#    'Chemistry',
#    'Transcription factors and regulatory sites',
#    'Literature and language']},
#  {'id': 'chemicaltoolbox',
#   'description': 'ChemicalToolbox is a publicly available web server for performing cheminformatics analysis. The ChemicalToolbox provides an intuitive, graphical interface for common tools for downloading, filtering, visualizing and simulating small molecules and proteins. The ChemicalToolbox is based on Galaxy, an open-source web-based platform which enables accessible and reproducible data analysis. There is already an active Galaxy cheminformatics community using and developing tools. Based on their work, we provide four example workflows which illustrate the capabilities of the ChemicalToolbox, covering assembly of a compound library, hole filling, protein-ligand docking, and construction of a quantitative structure-activity relationship (QSAR) model.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Protein-ligand docking',
#    'Molecular dynamics',
#    'Sequence assembly'],
#   'edam_topics': ['Cheminformatics',
#    'Molecular modelling',
#    'Compound libraries and screening',
#    'Workflows',
#    'Small molecules']},
#  {'id': 'chipseeker',
#   'description': 'This package implements functions to retrieve the nearest genes around the peak, annotate the genomic region of the peak, statistical methods for estimating the significance of overlap among ChIP peak data sets, and incorporate GEO database to compare the own dataset with those deposited in database. The comparison can be used to infer cooperative regulation and thus can be used to generate hypotheses.',
#   'edam_inputs': [{'formats': ['BED', 'Sequence range format'],
#     'term': 'Sequence range format'}],
#   'edam_outputs': [{'formats': ['Textual format'], 'term': 'Textual format'},
#    {'formats': ['Textual format'], 'term': 'Textual format'}],
#   'edam_operations': ['Sequence annotation',
#    'Visualisation',
#    'Gene-set enrichment analysis',
#    'Sequence feature comparison'],
#   'edam_topics': ['ChIP-seq', 'Data visualisation', 'Data mining']},
#  {'id': 'chira',
#   'description': 'ChiRA is a tool suite to analyze RNA-RNA interactome experimental data such as CLASH, CLEAR-CLIP, PARIS, SPLASH, etc.',
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': ['RNA',
#    'Molecular interactions, pathways and networks',
#    'Functional, regulatory and non-coding RNA']},
#  {'id': 'chrombpnet',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'chromeister',
#   'description': 'An ultra fast, heuristic approach to detect conserved signals in extremely large pairwise genome comparisons (dotplot).',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Dot plot plotting'],
#   'edam_topics': ['Comparative genomics', 'Sequence analysis']},
#  {'id': 'circexplorer',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'circlator',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'circos',
#   'description': 'Circos is tool for visualizing data in a circular format. It was developed for genomic data but can work for many other kinds of data as well.',
#   'edam_inputs': [{'formats': ['TSV'], 'term': 'TSV'}],
#   'edam_outputs': [{'formats': ['Textual format'], 'term': 'Textual format'},
#    {'formats': ['Image format'], 'term': 'Image format'}],
#   'edam_operations': ['Visualisation'],
#   'edam_topics': ['Comparative genomics', 'Data visualisation']},
#  {'id': 'CITE-seq-Count',
#   'description': 'Tool for counting antibody TAGS from a CITE-seq and/or cell hashing experiment.',
#   'edam_inputs': [{'formats': ['FASTQ'], 'term': 'FASTQ'},
#    {'formats': ['CSV'], 'term': 'CSV'}],
#   'edam_outputs': [{'formats': ['Matrix format'], 'term': 'Matrix format'},
#    {'formats': ['YAML'], 'term': 'YAML'}],
#   'edam_operations': ['RNA-Seq quantification'],
#   'edam_topics': ['Transcriptomics', 'Immunoproteins and antigens']},
#  {'id': 'clair3',
#   'description': 'Clair3 is a germline small variant caller for long-reads. Clair3 makes the best of two major method categories: pileup calling handles most variant candidates with speed, and full-alignment tackles complicated candidates to maximize precision and recall. Clair3 runs fast and has superior performance, especially at lower coverage. Clair3 is simple and modular for easy deployment and integration.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Variant calling'],
#   'edam_topics': ['Molecular genetics']},
#  {'id': 'clifinder',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'climate_stripes',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'clinker',
#   'description': 'Automatic generation of gene cluster comparison figures.\n\nGene cluster comparison figure generator.\n\nA d3 chart for generating gene cluster comparison figures.\n\nclinker is a pipeline for easily generating publication-quality gene cluster comparison figures.\n\nGiven a set of GenBank files, clinker will automatically extract protein translations, perform global alignments between sequences in each cluster, determine the optimal display order based on cluster similarity, and generate an interactive visualisation (using clustermap.js) that can be extensively tweaked before being exported as an SVG file.\n\nclustermap.js is an interactive, reusable d3 chart designed to visualise homology between multiple gene clusters.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Sequence clustering',
#    'Sequence cluster visualisation',
#    'Dendrogram visualisation'],
#   'edam_topics': ['Molecular interactions, pathways and networks',
#    'Sequence analysis',
#    'Workflows',
#    'Imaging']},
#  {'id': 'clipkit',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'clustalo',
# ...
#      'FASTQ'],
#     'term': 'FASTQ'},
#    {'formats': ['FASTA'], 'term': 'FASTA'}],
#   'edam_outputs': [{'formats': ['TSV'], 'term': 'TSV'},
#    {'formats': ['FASTQ'], 'term': 'FASTQ'}],
#   'edam_operations': ['Sequence trimming'],
#   'edam_topics': ['Sequencing',
#    'Sequence analysis',
#    'Data quality management']},
#  {'id': 'trinity',
#   'description': 'Trinity is a transcriptome assembler which relies on three different tools, inchworm an assembler, chrysalis which pools contigs and butterfly which amongst others compacts a graph resulting from butterfly with reads.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Transcriptome assembly'],
#   'edam_topics': ['Transcriptomics', 'Gene expression', 'Gene transcripts']},
#  {'id': 'trinotate',
#   'description': 'Comprehensive annotation suite designed for automatic functional annotation of transcriptomes, particularly de novo assembled transcriptomes, from model or non-model organisms.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Gene functional annotation'],
#   'edam_topics': ['Gene expression', 'Transcriptomics']},
#  {'id': 'trnascan-se',
#   'description': 'A program for improved detection of transfer RNA genes in genomic sequence.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['tRNA gene prediction', 'Sequence feature detection'],
#   'edam_topics': ['RNA', 'Genomics', 'Sequence analysis']},
#  {'id': 'trycycler',
#   'description': 'Trycycler: consensus long-read assemblies for bacterial genomes',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Genome assembly',
#    'Sequence trimming',
#    'Scaffold gap completion',
#    'Sequence assembly validation'],
#   'edam_topics': ['Sequence assembly',
#    'DNA',
#    'Human biology',
#    'Whole genome sequencing',
#    'Genomics']},
#  {'id': 'ucsc',
#   'description': 'Utilities for handling sequences and assemblies from the UCSC Genome Browser project.',
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': ['Sequence analysis']},
#  {'id': 'umi_tools',
#   'description': 'Tools for handling Unique Molecular Identifiers in NGS data sets.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Sequencing quality control'],
#   'edam_topics': ['NGS',
#    'Sequence sites, features and motifs',
#    'Quality affairs']},
#  {'id': 'unicycler',
#   'description': 'A tool for assembling bacterial genomes from a combination of short (2nd generation) and long (3rd generation) sequencing reads.',
#   'edam_inputs': [{'formats': ['Raw sequence format'],
#     'term': 'Raw sequence format'}],
#   'edam_outputs': [{'formats': ['Graph format', 'FASTA'], 'term': 'FASTA'}],
#   'edam_operations': ['Genome assembly', 'Aggregation'],
#   'edam_topics': ['Microbiology',
#    'Genomics',
#    'Sequencing',
#    'Sequence assembly']},
#  {'id': 'unipept',
#   'description': 'Metaproteomics data analysis with a focus on interactive data visualizations.',
#   'edam_inputs': [{'formats': [], 'term': 'Protein sequence'}],
#   'edam_outputs': [{'formats': [], 'term': 'Sequence set'},
#    {'formats': [], 'term': 'Phylogenetic tree'}],
#   'edam_operations': ['Prediction and recognition', 'Visualisation'],
#   'edam_topics': ['Proteomics',
#    'Proteogenomics',
#    'Biodiversity',
#    'Workflows']},
#  {'id': 'UniProt_Downloader',
#   'description': 'The universal protein knowledgebase in 2021.\n\nYou are using a version of browser that may not display all the features of this website.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Text annotation',
#    'Data retrieval',
#    'Database search',
#    'Deposition'],
#   'edam_topics': ['Proteomics',
#    'Sequence analysis',
#    'Literature and language',
#    'Model organisms',
#    'Proteomics experiment']},
#  {'id': 'uniprot_rest_interface',
#   'description': 'The universal protein knowledgebase in 2021.\n\nYou are using a version of browser that may not display all the features of this website.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Text annotation',
#    'Data retrieval',
#    'Database search',
#    'Deposition'],
#   'edam_topics': ['Proteomics',
#    'Sequence analysis',
#    'Literature and language',
#    'Model organisms',
#    'Proteomics experiment']},
#  {'id': 'unzip',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'vep',
#   'description': 'Tool for predicting effects of variants for any genome in Ensembl or with genome annotation (via GFF). This includes vertebrates and also plants, fungi, protists, metazoa and bacteria.  There is a web and a REST API version but the most powerful is the Perl script version. See McLaren et al., 2016, Genome Biology',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['SNP annotation', 'Genetic variation analysis'],
#   'edam_topics': ['Genetic variation', 'Genomics']},
#  {'id': 'validate_fasta_database',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'vapor',
#   'description': 'VAPOR is a tool for classification of Influenza samples from raw short read sequence data for downstream bioinformatics analysis. VAPOR is provided with a fasta file of full-length sequences (> 20,000) for a given segment, a set of reads, and attempts to retrieve a reference that is closest to the sample strain.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Data retrieval', 'De-novo assembly', 'Read mapping'],
#   'edam_topics': ['Whole genome sequencing', 'Mapping', 'Sequence assembly']},
#  {'id': 'varscan',
#   'description': 'VarScan, an open source tool for variant detection that is compatible with several short read align-ers.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Variant calling'],
#   'edam_topics': ['Sequencing', 'DNA polymorphism']},
#  {'id': 'vcflib',
#   'description': 'API and command line utilities for the manipulation of VCF files.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Data handling'],
#   'edam_topics': ['Genomics', 'Data management']},
#  {'id': 'vcftools',
#   'description': 'Provide easily accessible methods for working with complex genetic variation data in the form of VCF files.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Data handling',
#    'Variant filtering',
#    'Genetic variation analysis'],
#   'edam_topics': ['Genetic variation']},
#  {'id': 'velocyto',
#   'description': 'Estimating RNA velocity in single cell RNA sequencing datasets',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['RNA-Seq analysis', 'Splicing analysis'],
#   'edam_topics': None},
#  {'id': 'velvet',
#   'description': 'A de novo genomic assembler specially designed for short read sequencing technologies, such as Solexa or 454 or SOLiD.',
#   'edam_inputs': [{'formats': ['BAM', 'SAM', 'FASTQ', 'FASTA'],
#     'term': 'FASTA'}],
#   'edam_outputs': [{'formats': [], 'term': 'Sequence'},
#    {'formats': [], 'term': 'Resource metadata'}],
#   'edam_operations': ['Formatting'],
#   'edam_topics': ['Sequence assembly']},
#  {'id': 'verkko',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'vitessce',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'vsearch',
#   'description': 'High-throughput search and clustering sequence analysis tool. It supports de novo and reference based chimera detection, clustering, full-length and prefix dereplication, reverse complementation, masking, all-vs-all pairwise global alignment, exact and global alignment searching, shuffling, subsampling and sorting. It also supports FASTQ file analysis, filtering and conversion.',
#   'edam_inputs': [{'formats': [], 'term': 'Nucleic acid sequence'}],
#   'edam_outputs': [{'formats': [], 'term': 'Sequence similarity score'},
#    {'formats': [], 'term': 'Sequence alignment'}],
#   'edam_operations': ['DNA mapping', 'Chimera detection'],
#   'edam_topics': ['Metagenomics', 'Sequence analysis']},
#  {'id': 'waveica',
#   'description': 'Removal of batch effects for large-scale untargeted metabolomics data based on wavelet transform.',
#   'edam_inputs': [{'formats': ['CSV', 'TSV', 'Binary format'],
#     'term': 'Binary format'},
#    {'formats': ['CSV', 'TSV', 'Binary format'], 'term': 'Binary format'}],
#   'edam_outputs': [{'formats': ['CSV', 'DSV', 'Binary format'],
#     'term': 'Binary format'}],
#   'edam_operations': ['Standardisation and normalisation'],
#   'edam_topics': ['Metabolomics']},
#  {'id': 'weblogo3',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'whatshap',
#   'description': 'Software for phasing genomic variants using DNA sequencing reads, also called haplotype assembly. It is especially suitable for long reads, but works also well with short reads.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Genotyping'],
#   'edam_topics': ['DNA polymorphism', 'Sequence assembly']},
#  {'id': 'windowmasker',
#   'description': 'windowmasker identifies and masks highly repetitive DNA sequences in a genome, using only the sequence of the genome itself.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Repeat sequence detection', 'Repeat sequence analysis'],
#   'edam_topics': ['Sequencing']},
#  {'id': 'winnowmap',
#   'description': 'Winnowmap is a long-read mapping algorithm optimized for mapping ONT and PacBio reads to repetitive reference sequences. Winnowmap development began on top of minimap2 codebase, and since then we have incorporated the following two ideas to improve mapping accuracy within repeats',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Sequence alignment'],
#   'edam_topics': ['Mapping']},
#  {'id': 'workflow4metabolomics',
#   'description': 'First fully open-source and collaborative online platform for computational metabolomics. It includes preprocessing, normalization, quality control, statistical analysis of LC/MS, FIA-MS, GC/MS and NMR data.',
#   'edam_inputs': [{'formats': [], 'term': 'NMR spectrum'},
#    {'formats': ['mzData', 'mzML', 'NetCDF', 'mzXML'], 'term': 'mzXML'}],
#   'edam_outputs': [{'formats': ['Chemical formula format'],
#     'term': 'Chemical formula format'},
#    {'formats': [], 'term': 'Distance matrix'}],
#   'edam_operations': ['Annotation',
#    'Spectral analysis',
#    'Enrichment analysis',
#    'Statistical calculation',
#    'Visualisation'],
#   'edam_topics': ['Systems biology', 'Metabolomics', 'Computational biology']},
#  {'id': 'wormbase',
#   'description': 'Caenorhabditis elegans genome database. International consortium of biologists and computer scientists dedicated to providing the research community with accurate, current, accessible information concerning the genetics, genomics and biology of C. elegans and related nematodes. Founded in 2000, the Consortium is led by Paul Sternberg of CalTech, Paul Kersey of the EBI, Matt Berriman of the Wellcome Trust Sanger Institute, and Lincoln Stein of the Ontario Institute for Cancer Research.',
#   'edam_inputs': [{'formats': [], 'term': 'Gene symbol'}],
#   'edam_outputs': [{'formats': ['HTML'], 'term': 'HTML'}],
#   'edam_operations': ['Query and retrieval'],
#   'edam_topics': ['Model organisms']},
#  {'id': 'xarray',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'xcms',
#   'description': 'Framework for processing and visualization of chromatographically separated and single-spectra mass spectral data.  The packages enables imports from AIA/ANDI NetCDF, mzXML, mzData and mzML files and preprocesses data for high-throughput, untargeted analyte profiling.',
#   'edam_inputs': [{'formats': ['mzML', 'NetCDF', 'mzXML'], 'term': 'mzXML'},
#    {'formats': ['mzML', 'NetCDF', 'mzXML'], 'term': 'mzXML'}],
#   'edam_outputs': [{'formats': ['mzQuantML', 'NetCDF'], 'term': 'NetCDF'}],
#   'edam_operations': ['Mass spectrum visualisation',
#    'Chromatographic alignment',
#    'Label-free quantification',
#    'Validation',
#    'Data filtering',
#    'Peak detection'],
#   'edam_topics': ['Data visualisation', 'Metabolomics']},
#  {'id': 'xml4ena',
#   'description': None,
#   'edam_inputs': None,
#   'edam_outputs': None,
#   'edam_operations': None,
#   'edam_topics': None},
#  {'id': 'xpore',
#   'description': 'Detection of differential RNA modifications from direct RNA sequencing of human cell lines.\n\nPython package for detection of differential RNA modifications from direct RNA sequencing.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Quantification',
#    'Expression analysis',
#    'DMR identification'],
#   'edam_topics': ['RNA-Seq',
#    'RNA',
#    'Gene expression',
#    'Genotype and phenotype',
#    'Molecular interactions, pathways and networks']},
#  {'id': 'xtandem',
#   'description': 'Matches tandem mass spectra with peptide sequences.',
#   'edam_inputs': [{'formats': ['dta',
#      'pkl',
#      'mzXML',
#      'mzData',
#      'MGF',
#      'X!Tandem XML',
#      'mzML'],
#     'term': 'mzML'},
#    {'formats': ['FASTA'], 'term': 'FASTA'}],
#   'edam_outputs': [{'formats': ['X!Tandem XML', 'mzIdentML'],
#     'term': 'mzIdentML'}],
#   'edam_operations': ['Blind peptide database search',
#    'PTM identification',
#    'Peptide identification',
#    'Peptide database search',
#    'Protein identification'],
#   'edam_topics': ['Proteomics', 'Proteomics experiment']},
#  {'id': 'xtb',
#   'description': 'The xTB molecular optimization tool, based on the Semiempirical Tight Binding method (GFNn-xTB), is implemented in the xtb (extended tight binding) program package. This tool handles molecular .XYZ input format and provides various levels of optimization to suit different computational needs. The xTB method offers an efficient approach for molecular structure optimization, making it valuable for large-scale quantum chemical simulations.',
#   'edam_inputs': [{'formats': ['XYZ'], 'term': 'XYZ'}],
#   'edam_outputs': [{'formats': ['XYZ'], 'term': 'XYZ'}],
#   'edam_operations': ['3D profile generation'],
#   'edam_topics': ['Computational chemistry']},
#  {'id': 'yahs',
#   'description': 'YaHS is scaffolding tool using Hi-C data. It relies on a new algorithm for contig joining detection which considers the topological distribution of Hi-C signals aiming to distinguish real interaction signals from mapping noises.',
#   'edam_inputs': [],
#   'edam_outputs': [],
#   'edam_operations': ['Scaffolding', 'Genome assembly', 'De-novo assembly'],
#   'edam_topics': ['Sequence assembly', 'DNA binding sites']},
#  {'id': 'yeastmine',
#   'description': 'Search and retrieve S. cerevisiae data, populated by SGD and powered by InterMine',
#   'edam_inputs': [{'formats': [], 'term': 'Sequence features'},
#    {'formats': [], 'term': 'Ontology data'}],
#   'edam_outputs': [{'formats': [], 'term': 'Over-representation data'},
#    {'formats': [], 'term': 'Query script'},
#    {'formats': [], 'term': 'Sequence features'}],
#   'edam_operations': ['Data retrieval',
#    'Visualisation',
#    'Gene-set enrichment analysis',
#    'Query and retrieval'],
#   'edam_topics': ['Data management', 'Genomics', 'Proteomics']},
#  {'id': 'zebrafishmine',
#   'description': 'ZebrafishMine is powered by the InterMIne data warehouse system, and integrates biological data sets from multiple sources.\r\nIt currently includes updates of data from ZFIN, the zebrafish model organism database. There is also data from the Panther database.',
#   'edam_inputs': [{'formats': [], 'term': 'Sequence features'},
#    {'formats': [], 'term': 'Ontology data'}],
#   'edam_outputs': [{'formats': [], 'term': 'Over-representation data'},
#    {'formats': [], 'term': 'Query script'},
#    {'formats': [], 'term': 'Sequence features'}],
#   'edam_operations': ['Data retrieval',
#    'Visualisation',
#    'Gene-set enrichment analysis',
#    'Query and retrieval'],
#   'edam_topics': ['Data management', 'Genomics', 'Proteomics']}]

# %%
# Generate set of unique edam operations
x = { op
        for tool in collected_data
        for op in (tool.get("edam_operations") or [])
}
x

# %%
from pronto import Ontology
from bio_mcp.cache.embeddings import load_edam_obo

# %%
obo = load_edam_obo()

# %%
obo

# %%
# Test concept extract
from bio_mcp.cache.embeddings import extract_concepts_from_biotools_yaml

# %%
concepts = extract_concepts_from_biotools_yaml(yaml_path=Path("/home/ubuntu/cache/johan.yaml"))

# %%
concepts
# Out:
# {'3d de novo assembly 3d dna is a pipeline for de novo assembly using hic': {'3d-dna'},
#  'mass screening of contigs for antimicrobial resistance or virulence genes': {'abricate'},
#  'an amr gene detection pipeline that runs amrfinderplus on a single or list of given isolates and collates the results into a table separating genes identified into functionally relevant groups': {'abritamr'},
#  'de novo genome sequence assembler using short reads': {'abyss'},
#  'another gff analysis toolkit agat suite of tools to handle gene annotations in any gtf gff format': {'agat'},
#  'ai guided 3d structure prediction of novel proteins alphafold uses neural networks to predict the tertiary 3d structure of proteins alphafold accepts an amino acid sequence as an input which it will then will fold into a 3d model': {'alphafold_2'},
#  'the assisted model building with energy refinement tool refers to two things a set of molecular mechanical force fields for the simulation of biomolecules which are in the public domain and are used in a variety of simulation programs and a package of molecular simulation programs which includes source code and demos': {'amber'},
#  'consists of several independently developed packages that work well by themselves and with amber assisted model building with energy refinement itself the suite can also be used to carry out complete non periodic molecular dynamics simulations using nab with generalized born solvent models': {'ambertools'},
#  'software package specially developed for the study of genes primary structure it uses gene sequences downloaded from public databases as fasta and genbank and it applies a set of statistical and visualization methods in different ways to reveal information about codon context codon usage nucleotide repeats within open reading frames orfeome and others': {'anaconda'},
#  'from https anndata readthedocs io en latest python package for handling annotated data matrices in memory and on disk positioned between pandas and xarray': {'anndata'},
#  'this tool can get annotation for a generic set of ids using the bioconductor annotation data packages supported organisms are human mouse rat fruit fly and zebrafish the org db packages that are used here are primarily based on mapping using entrez gene identifiers more information on the annotation packages can be found at the bioconductor website for example information on the human annotation package org hs eg db can be found here': {'annotatemyids'},
#  'rapid genome wide identification annotation and analysis of secondary metabolite biosynthesis gene clusters in bacterial and fungal genomes it integrates and cross links with a large number of in silico secondary metabolite analysis tools that have been published earlier': {'antismash'},
#  'convert various sequence formats to fasta': {'any2fasta'},
#  'apollo is a genome annotation viewer and editor apollo allows researchers to explore genomic annotations at many levels of detail and to perform expert annotation curation all in a graphical environment': {'apollo'},
#  'aragorn detects trna mtrna info about tmrna and tmrna genes': {'aragorn'},
#  'filesender is an open source web application for sending files of any size quickly and securely filesender is available to all institutions affiliated with the australian access federation aaf you can use your institution login details to access and use filesender': {'aarnet_filesender'},
#  'arriba is a command line tool to detect gene fusions from rna seq data based on the star aligner in addition to fusions it can detect exon duplications inversions and truncations of genes i e breakpoints in introns and intergenic regions arriba is the winner of the dream smc rna challenge': {'arriba'},
#  'a bioinformatics pipeline for working with virus sequencing data sequenced with nanopore': {'artic'},
#  'augustus is a eukaryotic gene prediction tool it can integrate evidence e g from rna seq ests proteomics but can also predict genes ab initio the ppx extension to augustus can take a protein sequence multiple sequence alignment as input to find new members of the family in a genome it can be run through a web interface see https bio tools webaugustus or downloaded and run locally': {'augustus'},
#  'autodock vina is a new open source program for drug discovery molecular docking and virtual screening offering multi core capability high performance and enhanced accuracy and ease of use': {'autodock_vina'},
#  'the bio2byte tools server b2btools offers the following single protein sequence based predictions backbone and sidechain dynamics dynamine helix sheet coil and polyproline ii propensity early folding propensity efoldmine disorder disomine beta sheet aggregation agmata in addition multiple sequence alignments msas can be uploaded to scan the biophysical limits of a protein family as defined in the msa': {'b2btools'},
#  'rapid standardized annotation of bacterial genomes mags plasmids': {'bakta'},
#  'bamtools provides a fast flexible c api toolkit for reading writing and managing bam files': {'bamtools'},
#  'bamutil provides a serie of programs to work on sam bam files': {'bamutil_diff'},
#  'gui program that allows users to interact with the assembly graphs made by de novo assemblers such as velvet spades megahit and others it visualises assembly graphs with connections using graph layout algorithms': {'bandage'},
#  'the baredsc bayesian approach to retreive expression distribution of single cell is a tool that uses a monte carlo markov chain to estimate a confidence interval on the probability density function pdf of expression of one or two genes from single cell rna seq data': {'baredsc'},
#  'predict the location of ribosomal rna genes in genomes it supports bacteria 5s 23s 16s archaea 5s 5 8s 23s 16s mitochondria 12s 16s and eukaryotes 5s 5 8s 28s 18s': {'barrnap'},
#  'bbmap is a fast splice aware aligner for rna and dna it is faster than almost all short read aligners yet retains unrivaled sensitivity and specificity particularly for reads with many errors and indels': {'bbmap'},
#  'bbtools is a suite of fast multithreaded bioinformatics tools designed for analysis of dna and rna sequence data bbtools can handle common sequencing file formats such as fastq fasta sam scarf fasta qual compressed or raw with autodetection of quality encoding and interleaving it is written in java and works on any platform supporting java including linux macos and microsoft windows and linux there are no dependencies other than java version 7 or higher program descriptions and options are shown when running the shell scripts with no parameters bbtools is open source and free for unlimited use and is used regularly by doe jgi and other institutions around the world': {'bbtools'},
#  'a tool for filling the gap created by genomic data processing analysis by rebasing some analysis results against the parent features which were originally analysed': {'bcbiogff'},
#  'bcftools is a set of utilities that manipulate variant calls in the variant call format vcf and its binary counterpart bcf all commands work transparently with both vcfs and bcfs both uncompressed and bgzf compressed': {'bcftools'},
#  'a global search engine for genetic mutations': {'beacon2'},
#  'beagle is a software package that performs genotype calling genotype phasing imputation of ungenotyped markers and identity by descent segment detection': {'beagle'},
#  'beagle is a high performance library that can perform the core calculations at the heart of most bayesian and maximum likelihood phylogenetics packages': {'beagle-lib'},
#  'the bayesian evolutionary analysis sampling trees is a cross platform program for bayesian analysis of molecular sequences using mcmc markov chain monte carlo it is entirely orientated towards rooted time measured phylogenies inferred using strict or relaxed molecular clock models it can be used as a method of reconstructing phylogenies but is also a framework for testing evolutionary hypotheses without conditioning on a single tree topology': {'beast'},
#  'bayesian phylogenetic analysis of molecular sequences it estimates rooted time measured phylogenies using strict or relaxed molecular clock models it can be used as a method of reconstructing phylogenies but is also a framework for testing evolutionary hypotheses without conditioning on a single tree topology it uses markov chain monte carlo mcmc to average over tree space so that each tree is weighted proportional to its posterior probability it includes a graphical user interface for setting up standard analyses and a suit of programs for analysing the results': {'beast2'},
#  'convert a bed format file of the proteins from a proteomics search database into a tabular format for the multiomics visualization platform mvp': {'bed_to_protein_map'},
#  'bedtools is an extensive suite of utilities for comparing genomic features in bed format': {'bedtools'},
#  'the bellerophon pipeline improving de novo transcriptomes and removing chimeras bellerophon is a pipeline created to remove falsely assembled chimeric transcripts in de novo transcriptome assemblies the pipeline can be downloaded as a vragrant virtual machine https app vagrantup com bellerophon boxes bellerophon this is recommended as it avoids backwards compatibility problems with transrate': {'bellerophon'},
#  'trim circularise orient and filter long read bacterial genome assemblies': {'berokka'},
#  'binette is a fast and accurate binning refinement tool to constructs high quality mags from the output of multiple binning tools': {'binette'},
#  'bio3d is an r package containing utilities for the analysis of protein structure sequence and trajectory data': {'bio3d'},
#  'this package includes basic tools for reading biom format files accessing and subsetting data tables from a biom object as well as limited support for writing a biom object back to a biom format file the design of this api is intended to match the python api and other tools included with the biom format project but with a decidedly r flavor that should be familiar to r users this includes s4 classes and methods as well as extensions of common core functions methods': {'biom-format'},
#  'a collection of perl modules that facilitate the development of perl scripts for bioinformatics applications it provides software modules for many of the typical tasks of bioinformatics programming': {'bioperl'},
#  'biopython is a set of freely available tools for biological computation written in python by an international team of developers': {'biopython'},
#  'biotransformer is a freely available web server that supports accurate rapid and comprehensive in silico metabolism prediction': {'biotransformer'},
#  'bismark is a tool to map bisulfite treated sequencing reads and perform methylation calling in a quick and easy to use fashion': {'bismark'},
#  'a tool that finds regions of similarity between biological sequences the program compares nucleotide or protein sequences to sequence databases and calculates the statistical significance': {'blast',
#   'blast+'},
#  'fast accurate spliced alignment of dna sequences': {'blat'},
#  'detect blocks of overlapping reads using a gaussian distribution approach': {'Blockbuster'},
#  'boost is a set of libraries for the c programming language that provides support for tasks and structures such as linear algebra pseudorandom number generation multithreading image processing regular expressions and unit testing': {'boost'},
#  'bowtie is an ultrafast memory efficient short read aligner': {'bowtie'},
#  'bowtie 2 is an ultrafast and memory efficient tool for aligning sequencing reads to long reference sequences it is particularly good at aligning reads of about 50 up to 100s or 1 000s of characters and particularly good at aligning to relatively long e g mammalian genomes bowtie 2 indexes the genome with an fm index to keep its memory footprint small for the human genome its memory footprint is typically around 3 2 gb bowtie 2 supports gapped local and paired end alignment modes': {'bowtie2'},
#  'bracken is a companion program to kraken 1 krakenuniq or kraken 2 while kraken classifies reads to multiple levels in the taxonomic tree bracken allows estimation of abundance at a single level using those classifications e g bracken can estimate abundance of species within a sample': {'bracken'},
#  'pipeline for unsupervised rna seq based genome annotation with genemark et and augustus': {'braker'},
#  'runs breseq software on a set of fastq files': {'breseq'},
#  'provides measures for quantitative assessment of genome assembly gene set and transcriptome completeness based on evolutionarily informed expectations of gene content from near universal single copy orthologs': {'busco'},
#  'accelerated nanopore basecalling with slow5 data format': {'buttery-eel'},
#  'fast accurate memory efficient aligner for short and long sequencing reads': {'bwa'},
#  'bwa mem2 is the next version of the bwa mem algorithm in bwa it produces alignment identical to bwa and is 1 3 3 1x faster depending on the use case dataset and the running machine': {'bwa-mem2'},
#  'tools for manipulating biological data particularly multiple sequence alignments': {'bx-python'},
#  'cactus is a reference free whole genome multiple alignment program': {'cactus'},
#  'annotation of peaklists generated by xcms rule based annotation of isotopes and adducts isotope validation eic correlation based tagging of unknown adducts and fragments': {'camera'},
#  'amber is an evaluation package for the comparative assessment of genome reconstructions and taxonomic assignments from metagenome benchmark datasets it provides performance metrics results rankings and comparative visualizations for assessing multiple programs or parameter effects the provided metrics were used in the first community benchmarking challenge of the initiative for the critical assessment of metagenomic interpretation': {'cami-amber'},
#  'de novo assembly tool for long read chemistry like nanopore data and pacbio data': {'canu'},
#  'web based contig assembly': {'cap3'},
#  'implements statistical and computational tools for analyzing mass spectrometry imaging datasets including methods for efficient pre processing spatial segmentation and classification': {'cardinal'},
#  'contig annotation tool cat and bin annotation tool bat are pipelines for the taxonomic classification of long dna sequences and metagenome assembled genomes mags bins of both known and highly unknown microorganisms as generated by contemporary metagenomics studies the core algorithm of both programs involves gene calling mapping of predicted orfs against the nr protein database and voting based classification of the entire contig mag based on classification of the individual orfs': {'cat_bins'},
#  'cluster a nucleotide dataset into representative sequences': {'cd-hit'},
#  'celseq2 is a python framework for generating the umi count matrix from cel seq2 sequencing data': {'celseq2'},
#  'a deep generative model for unsupervised removal of background noise from scrna seq datasets cellbender is a software package for eliminating technical artifacts from high throughput single cell rna sequencing scrna seq data welcome to cellbender s documentation cellbender documentation free document hosting provided by read the docs stephen j fleming john c marioni and mehrtash babadi cellbender remove background a deep generative model for unsupervised removal of background noise from scrna seq datasets biorxiv 791699 doi https doi org 10 1101 791699': {'cellbender'},
#  'cellpose is a generalist algorithm for cellular segmentation': {'cellpose'},
#  'tool for quantifying data from biological images particularly in high throughput experiments': {'CellProfiler'},
#  'cellsnp lite is an efficient tool for genotyping single cells cellsnp lite was initially designed to pileup the expressed alleles in single cell or bulk rna seq data which can be directly used for donor deconvolution in multiplexed single cell rna seq data particularly with vireo which assigns cells to donors and detects doublets even without genotyping reference now besides rna seq data cellsnp lite could also be applied on dna seq and atac seq data either in bulk or single cell': {'cellsnp-lite'},
#  'cellxgene pronounced cell by gene is an interactive data explorer for single cell transcriptomics datasets such as those coming from the human cell atlas': {'cellxgene'},
#  'it unifies the discovery and the analysis of coexpression gene modules in a fully automatic manner while providing a user friendly html report with high quality graphs our tool evaluates if modules contain genes that are over represented by specific pathways or that are altered in a specific sample group additionally cemitool is able to integrate transcriptomic data with interactome information identifying the potential hubs on each network': {'cemitool'},
#  'checkm provides a set of tools for assessing the quality of genomes recovered from isolates single cells or metagenomes': {'checkm',
#   'checkm-database'},
#  'database of bioactive compounds their quantitative properties and bioactivities binding constants pharmacology and admet etc the data is abstracted and curated from the primary scientific literature': {'chembl'},
#  'fast cheminformatics fingerprint search at your fingertips chemfp is a set of command line tools and a python library for fingerprint generation and high performance similarity search there are two ways to try out chemfp from the download page page you can request an evaluation copy of the most recent version of chemfp or you can download an earlier version for no cost under the mit license': {'chemfp'},
#  'chemicaltoolbox is a publicly available web server for performing cheminformatics analysis the chemicaltoolbox provides an intuitive graphical interface for common tools for downloading filtering visualizing and simulating small molecules and proteins the chemicaltoolbox is based on galaxy an open source web based platform which enables accessible and reproducible data analysis there is already an active galaxy cheminformatics community using and developing tools based on their work we provide four example workflows which illustrate the capabilities of the chemicaltoolbox covering assembly of a compound library hole filling protein ligand docking and construction of a quantitative structure activity relationship qsar model': {'chemicaltoolbox'},
#  'this package implements functions to retrieve the nearest genes around the peak annotate the genomic region of the peak statistical methods for estimating the significance of overlap among chip peak data sets and incorporate geo database to compare the own dataset with those deposited in database the comparison can be used to infer cooperative regulation and thus can be used to generate hypotheses': {'chipseeker'},
#  'chira is a tool suite to analyze rna rna interactome experimental data such as clash clear clip paris splash etc': {'chira'},
#  'an ultra fast heuristic approach to detect conserved signals in extremely large pairwise genome comparisons dotplot': {'chromeister'},
#  'circos is tool for visualizing data in a circular format it was developed for genomic data but can work for many other kinds of data as well': {'circos'},
#  'tool for counting antibody tags from a cite seq and or cell hashing experiment': {'CITE-seq-Count'},
#  'clair3 is a germline small variant caller for long reads clair3 makes the best of two major method categories pileup calling handles most variant candidates with speed and full alignment tackles complicated candidates to maximize precision and recall clair3 runs fast and has superior performance especially at lower coverage clair3 is simple and modular for easy deployment and integration': {'clair3'},
#  'automatic generation of gene cluster comparison figures gene cluster comparison figure generator a d3 chart for generating gene cluster comparison figures clinker is a pipeline for easily generating publication quality gene cluster comparison figures given a set of genbank files clinker will automatically extract protein translations perform global alignments between sequences in each cluster determine the optimal display order based on cluster similarity and generate an interactive visualisation using clustermap js that can be extensively tweaked before being exported as an svg file clustermap js is an interactive reusable d3 chart designed to visualise homology between multiple gene clusters': {'clinker'},
#  'multiple sequence alignment software the name is occassionally spelled as clustalomega clustal clustal clustal o clustalo': {'clustalo'},
#  'multiple sequence alignment software old deprecated versions even older versions were clustal and clustal v clustalv': {'clustalw'},
#  'cnvkit is a software toolkit to infer and visualize copy number from targeted dna sequencing data': {'cnvkit'},
#  'constraints based reconstruction and analysis for python': {'cobrapy'},
#  'colabfold databases are mmseqs2 expandable profile databases to generate diverse multiple sequence alignments to predict protein structures': {'colabfold',
#   'colabfold_batch'},
#  'compleasm a faster and more accurate reimplementation of busco it provides measures for quantitative assessment of genome assembly gene set and transcriptome completeness based on evolutionarily informed expectations of gene content from near universal single copy orthologs': {'compleasm'},
#  'a program for unsupervised binning of metagenomic contigs by using nucleotide composition coverage data in multiple samples and linkage data from paired end reads': {'concoct'},
#  'constava calculates conformational states probability and conformational state variability from protein structure ensembles': {'constava'},
#  'read coverage calculator for metagenomics': {'coverm'},
#  'cpat coding potential assessment tool is a logistic regression model based classifier that can accurately and quickly distinguish protein coding and noncoding rnas using pure linguistic features calculated from the rna sequences cpat takes as input the nucleotides sequences or genomic coordinates of rnas and outputs the probabilities p 0 p 1 which measure the likelihood of protein coding': {'cpat'},
#  'software to generate crispr guide rnas against genomes annotated with individual variation': {'crisflash'},
#  'cryodrgn is a neural network based algorithm for heterogeneous cryo em reconstruction': {'cryodrgn'},
#  'cufflinks assembles transcripts and estimates their abundances in rna seq samples it accepts aligned rna seq reads and assembles the alignments into a parsimonious set of transcripts cufflinks then estimates the relative abundances of these transcripts based on how many reads support each one': {'cufflinks'},
#  'allows for persistent storage access exploration and manipulation of cufflinks high throughput sequencing data in addition provides numerous plotting functions for commonly used visualizations': {'cummeRbund'},
#  'generate customized protein sequence database from rna seq data for proteomics search': {'customprodb'},
#  'find and remove adapter sequences primers poly a tails and other types of unwanted sequence from your high throughput sequencing reads': {'cutadapt'},
#  'long read based human genomic structural variation detection with cutesv long read sequencing technologies enable to comprehensively discover structural variations svs however it is still non trivial for state of the art approaches to detect svs with high sensitivity or high performance or both herein we propose cutesv a sensitive fast and lightweight sv detection approach cutesv uses tailored methods to comprehensively collect various types of sv signatures and a clustering and refinement method to implement a stepwise sv detection which enables to achieve high sensitivity without loss of accuracy benchmark results demonstrate that cutesv has better yields on real datasets further its speed and scalability are outstanding and promising to large scale data analysis': {'cutesv'},
#  'this package infers exact sequence variants svs from amplicon data replacing the commonly used and coarser otu clustering approach this pipeline inputs demultiplexed fastq files and outputs the sequence variants and their sample wise abundances after removing substitution and chimera errors taxonomic classification is available via a native implementation of the rdp naive bayesian classifier': {'dada2'},
#  'das tool is an automated method that integrates the results of a flexible number of binning algorithms to calculate an optimized non redundant set of bins from a single assembly': {'dastool'},
#  'ensemble of computational methods to infer biological activities from omics data': {'decoupler'},
#  'deeplabcut is a toolbox for state of the art markerless pose estimation of animals performing various behaviors': {'deeplabcut'},
#  'user friendly tools for the normalization and visualization of deep sequencing data': {'deeptools'},
#  'dendropy is a python library for phylogenetic computing it provides classes and functions for the simulation processing and manipulation of phylogenetic trees and character matrices and supports the reading and writing of phylogenetic data in a range of formats': {'dendropy'},
#  'r bioconductor package for differential gene expression analysis based on the negative binomial distribution estimate variance mean dependence in count data from high throughput sequencing assays and test for differential expression based on a model using the negative binomial distribution': {'deseq2'},
#  'the package is focused on finding differential exon usage using rna seq exon counts between samples with different experimental designs it provides functions that allows the user to make the necessary statistical tests based on a model that uses the negative binomial distribution to estimate the variance between biological replicates and generalized linear models for testing the package also provides functions for the visualization and exploration of the results': {'DEXSeq'},
#  'the dfam database is a open collection of transposable element dna sequence alignments hidden markov models hmms consensus sequences and genome annotations': {'dfam'},
#  'neural networks and interference correction enable deep proteome coverage in high throughput dia nn a fast and easy to use tool for processing data independent acquisition dia proteomics data none required for raw mzml and dia processing two executables are provided diann exe a command line tool and dia nn exe a gui implemented as a wrapper for diann exe': {'diann'},
#  'dia umpire is an open source java program for computational analysis of data independent acquisition dia mass spectrometry based proteomics data it enables untargeted peptide and protein identification and quantitation using dia data and also incorporates targeted extraction to reduce the number of cases of missing quantitation': {'diaumpire'},
#  'sequence aligner for protein and translated dna searches and functions as a drop in replacement for the ncbi blast software tools it is suitable for protein protein search as well as dna protein search on short reads and longer sequences including contigs and assemblies providing a speedup of blast ranging up to x20 000': {'diamond'},
#  'diapasef is an appproch for parallel accumulation serial fragmentation combined with data independent acquisition': {'diapysef'},
#  'compute differentially bound sites from multiple chip seq experiments using affinity quantitative data also enables occupancy overlap analysis and plotting functions': {'diffbind'},
#  'dorado is a high performance easy to use open source basecaller for oxford nanopore reads': {'dorado'},
#  'distilled and refined annotation of metabolism a tool for the annotation and curation of function for microbial and viral genomes': {'dram'},
#  'fast and accurate genomic comparisons that enables improved genome recovery from metagenomes through de replication': {'drep'},
#  'provides a number of utility functions for handling single cell rna seq data from droplet technologies such as 10x genomics this includes data loading identification of cells from empty droplets removal of barcode swapped pseudo cells and downsampling of the count matrix': {'dropletutils'},
#  'fast and accurate genome wide phasing and imputation in a single tool': {'eagleimp'},
#  'easybuild is a software build and installation framework that allows you to manage scientific software on high performance computing hpc systems in an efficient way': {'easybuild'},
#  'ectyper is a standalone serotyping module for escherichia coli it supports fasta and fastq file formats galaxy version 1 0 0': {'ectyper'},
#  'differential expression analysis of rna seq expression profiles with biological replication implements a range of statistical methodology based on the negative binomial distributions including empirical bayes estimation exact tests generalized linear models and quasi likelihood tests as well as rna seq it be applied to differential signal analysis of other types of genomic data that produce counts including chip seq sage and cage': {'edger',
#   'edger-repenrich'},
#  'entrez direct edirect is a command line tool for entrez databases edirect connects to entrez through the entrez programming utilities interface it supports searching by indexed terms looking up precomputed neighbors or links filtering results by date or category and downloading record summaries or reports': {'edirect'},
#  'the edta package was designed to filter out false discoveries in raw te candidates and generate a high quality non redundant te library for whole genome te annotations selection of initial search programs were based on benckmarkings on the annotation performance using a manually curated te library in the rice genome': {'edta'},
#  'for fast functional annotation of novel sequences it uses precomputed orthologous groups and phylogenies from the eggnog database to transfer functional information from fine grained orthologs only its common uses include the annotation of novel genomes transcriptomes or even metagenomic gene catalogs the use of orthology predictions for functional annotation permits a higher precision than traditional homology searches as it avoids transferring annotations from close paralogs': {'eggnog-mapper'},
#  'this package implements the ensemble of gene set enrichment analyses method for gene set testing': {'egsea'},
#  'evaluation of an open source registration package for automatic contour propagation in online adaptive intensity modulated proton therapy of prostate cancer home about faq wiki download news legal stuff documentation welcome to elastix a toolbox for rigid and nonrigid registration of images elastix is open source software based on the well known insight segmentation and registration toolkit itk the software consists of a collection of algorithms that are commonly used to solve medical image registration problems the modular design of elastix allows the user to quickly configure test and compare different registration methods for a specific application a command line interface enables automated processing of large numbers of data sets by means of scripting nowadays elastix is accompanied by simpleelastix making it available in languages like c python java r ruby c and lua': {'elastix'},
#  'diverse suite of tools for sequence analysis many programs analagous to gcg context sensitive help for each tool': {'emboss'},
#  'emmtyper is a command line tool for emm typing of streptococcus pyogenes using a de novo or complete assembly by default we use the u s centers for disease control and prevention trimmed emm subtype database which can be found here https www2a cdc gov ncidod biotech strepblast asp the database is curated by dr velusamy srinivasan inner workings the difficulty in performing m typing is that there is a single gene of interest emm but two other homologue genes enn and mrp often referred to as emm like the homologue genes may or may not occur in the isolate of interest when performing emm typing from an assembly we can distinguish betweeen one or more clusters of matches on the contigs the best match for each of the clusters identified is then parsed from the blast results where possible we try to distinguish between matches to the emm gene and matches to one of the emm like genes': {'emmtyper'},
#  'a globally comprehensive data resource for nucleotide sequence spanning raw data alignments and assemblies functional and taxonomic annotation and rich contextual data relating to sequenced samples and experimental design serving both as the database of record for the output of the world s sequencing activity and as a platform for the management sharing and publication of sequence data': {'ena_upload'},
#  'encyclopedia is library search engine comprised of several algorithms for dia data analysis and can search for peptides using either dda based spectrum libraries or dia based chromatogram libraries': {'encyclopedia'},
#  'epigenomics single cell analysis in python': {'epiScanpy'},
#  'the environment for tree exploration ete is a computational framework that simplifies the reconstruction analysis and visualization of phylogenetic trees and multiple sequence alignments here we present ete v3 featuring numerous improvements in the underlying library of methods and providing a novel set of standalone tools to perform common tasks in comparative genomics and phylogenetics the new features include i building gene based and supermatrix based phylogenies using a single command ii testing and visualizing evolutionary models iii calculating distances between trees of different size or including duplications and iv providing seamless integration with the ncbi taxonomy database ete is freely available at http etetoolkit org': {'ete3'},
#  'integrated database covering the eukaryotic pathogens of the genera cryptosporidium giardia leishmania neospora plasmodium toxoplasma trichomonas and trypanosoma the database portal offers an entry point to all these resources and the opportunity to leverage orthology for searches across genera': {'eupathdb'},
#  'exabayes is a software package for bayesian phylogenetic tree inference it is particularly suitable for large scale analyses on computer clusters': {'exabayes'},
#  'tool for phylogenomic analyses on supercomputers': {'examl'},
#  'a tool for pairwise sequence alignment it enables alignment for dna dna and dna protein pairs and also gapped and ungapped alignment': {'exonerate'},
#  'export2graphlan is a conversion software tool for producing both annotation and tree file for graphlan in particular the annotation file tries to highlight specific sub trees deriving automatically from input file what nodes are important': {'export2graphlan'},
#  'streaming tool for quantifying the abundances of a set of target sequences from sampled subsequences example applications include transcript level rna seq quantification allele specific haplotype expression analysis from rna seq transcription factor binding quantification in chip seq and analysis of metagenomic data it can be used to resolve ambiguous mappings in other high throughput sequencing based applications': {'eXpress'},
#  'gpu accelerated adaptive banded event alignment for rapid comparative nanopore signal analysis re engineered and optimised nanopolish call methylation module supports cuda acceleration an optimised re implementation of the call methylation module in nanopolish given a set of basecalled nanopore reads and the raw signals f5c detects the methylated cytosine bases f5c can optionally utilise nvidia graphics cards for acceleration': {'f5c'},
#  'a high speed fastqc emulation for quality control of sequencing data': {'falco'},
#  'experimental pacbio diploid assembler': {'pb-assembly'},
#  'add length of sequence to fasta header': {'fasta_compute_length'},
#  'fastani is developed for fast alignment free computation of whole genome average nucleotide identity ani ani is defined as mean nucleotide identity of orthologous gene pairs shared between two microbial genomes fastani supports pairwise comparison of both complete and draft genome assemblies': {'fastani'},
#  'read huge fastq and fasta files both normal and gzipped an demanipulate them': {'fastool'},
#  'a tool designed to provide fast all in one preprocessing for fastq files this tool is developed in c with multithreading supported to afford high performance': {'fastp'},
#  'this tool aims to provide a qc report which can spot problems or biases which originate either in the sequencer or in the starting library material it can be run in one of two modes it can either run as a stand alone interactive application for the immediate analysis of small numbers of fastq files or it can be run in a non interactive mode where it would be suitable for integrating into a larger analysis pipeline for the systematic processing of large numbers of files': {'fastqc'},
#  'compute quality stats for fastq files and print those stats as emoji for some reason': {'fastqe'},
#  'infers approximately maximum likelihood phylogenetic trees from alignments of nucleotide or protein sequences': {'fasttree'},
#  'collection of command line tools for short reads fasta fastq files preprocessing': {'fastx',
#   'fastx_toolkit'},
#  'a tool to annotate long non coding rnas from rna seq assembled transcripts': {'feelnc'},
#  'featurecounts is a very efficient read quantifier it can be used to summarize rna seq reads and gdna seq reads to a variety of genomic features such as genes exons promoters gene bodies and genomic bins it is included in the bioconductor rsubread package and also in the sourceforge subread package': {'featurecounts'},
#  'hmm based gene structure prediction multiple genes both chains program for predicting multiple genes in genomic dna sequences': {'fgenesh'},
#  'the package implements an algorithm for fast gene set enrichment analysis using the fast algorithm allows to make more permutations and get more fine grained p values which allows to use accurate stantard approaches to multiple hypothesis correction': {'fgsea'},
#  'filtlong is a tool for filtering long reads by quality it can take a set of long reads and produce a smaller better subset it uses both read length longer is better and read identity higher is better when choosing which reads pass the filter': {'filtlong'},
#  'flashlfq is an ultrafast label free quantification algorithm for mass spectrometry proteomics': {'flashlfq'},
#  'flye is a de novo assembler for single molecule sequencing reads such as those produced by pacbio and oxford nanopore technologies it is designed for a wide range of datasets from small bacterial projects to large mammalian scale assemblies the package represents a complete pipeline it takes raw pb ont reads as input and outputs polished contigs': {'flye'},
#  'an integrated database for drosophila and anopheles genomics': {'flymine'},
#  'foldseek enables fast and sensitive comparisons of large structure sets it reaches sensitivities similar to state of the art structural aligners while being at least 20 000 times faster': {'foldseek'},
#  'web server which detects small molecule pockets by relying on the geometric alpha sphere theory it also tracks pockets during molecular dynamics so to provide insight on pocket dynamics mdpocket and transposes mdpocket to the combined analysis of homologous structures hpocket': {'fpocket'},
#  'application for finding fragmented genes in short reads': {'fraggenescan'},
#  'bayesian genetic variant detector designed to find small polymorphisms specifically snps indels multi nucleotide polymorphisms and complex events composite insertion and substitution events smaller than the length of a short read sequencing alignment': {'freebayes'},
#  'a tool for control free copy number alteration cna and allelic imbalances loh detection using deep sequencing data particularly useful for cancer studies': {'freec'},
#  'wrapper functions that interface with freesurfer a powerful and commonly used neuroimaging software using system commands the goal is to be able to interface with freesurfer completely in r where you pass r objects of class nifti implemented by package oro nifti and the function executes an freesurfer command and returns an r object of class nifti or necessary output': {'freesurfer'},
#  'funannotate is a pipeline for genome annotation built specifically for fungi but will also work with higher eukaryotes': {'funannotate'},
#  'gene annotation evaluation': {'gaeval'},
#  'galaxy image analysis is mainly developed by the biomedical computer vision bmcv group at heidelberg university its dedication is to provide tools for image analysis and image processing for the galaxy platform': {'galaxy_image_analysis'},
#  'the genome analysis toolkit gatk is a set of bioinformatic tools for analyzing high throughput sequencing hts and variant call format vcf data the toolkit is well established for germline short variant discovery from whole genome and exome sequencing data gatk4 expands functionality into copy number and somatic analyses and offers pipeline scripts for workflows version 4 gatk4 is open source at https github com broadinstitute gatk': {'gatk'},
#  'cleaning aligned sequences': {'gblock'},
#  'genome wide complex trait analysis estimate the proportion of phenotypic variance explained by genome or chromosome wide snps for complex traits the greml method and has subsequently extended for many other analyses to better understand the genetic architecture of complex traits': {'gcta'},
#  'software aimed at pairwise sequence comparison generating high quality results equivalent to mummer with controlled memory consumption and comparable or faster execution times particularly with long sequences': {'gecko'},
#  'gemini genome mining is a flexible framework for exploring genetic variation in the context of the wealth of genome annotations available for the human genome by placing genetic variants sample phenotypes and genotypes as well as genome annotations into an integrated database framework gemini provides a simple flexible and powerful system for exploring genetic variation for disease and population genetics': {'gemini'},
#  'gene model mapper is a homology based gene prediction program gemoma uses the annotation of protein coding genes in a reference genome to infer the annotation of protein coding genes in a target genome thereby it utilizes amino acid sequence and intron position conservation in addition it allows to incorporate rna seq evidence for splice site prediction': {'gemoma'},
#  'an interactive web tool for versatile clinically driven variant interrogation and prioritization iobio is a suite of web apps for visually driven real time analysis of genomic data visually driven real time analysis of genomic data': {'geneiobio'},
#  'reference free profiling of polyploid genomes we have developed genomescope 2 0 which applies classical insights from combinatorial theory to establish a detailed mathematical model of how k mer frequencies will be distributed in heterozygous and polyploid genomes average k mer coverage for polyploid genome upload results from running jellyfish or kmc': {'genomescope'},
#  'free collection of bioinformatics tools for genome informatics': {'genometools'},
#  'a fast and versatile toolkit for accurate de novo assembly of organelle genomes this toolkit assemblies organelle genome from genomic skimming data': {'getorganelle'},
#  'gfastats is a single fast and exhaustive tool for summary statistics and simultaneous genome assembly file manipulation gfastats also allows seamless fasta fastq gfa conversion': {'gfastats'},
#  'program for comparing annotating merging and tracking transcripts in gff files': {'gffcompare'},
#  'program for filtering converting and manipulating gff files': {'gffread'},
#  'plotting system for r based on the grammar of graphics': {'ggplot2'},
#  'command line tool for the visualization of splicing events across multiple samples': {'ggsashimi'},
#  'genomic mapping and alignment program for mrna and est sequences': {'gmap',
#   'gmap-gsnap'},
#  'gnu parallel is a shell tool for executing jobs in parallel using one or more computers a job can be a single command or a small script that has to be run for each of the lines in the input the typical input is a list of files a list of hosts a list of users a list of urls or a list of tables a job can also be a command that reads from a pipe gnu parallel can then split the input and pipe it into commands in parallel': {'parallel'},
#  'the gnu scientific library gsl is a numerical library for c and c programmers': {'gsl'},
#  'goenrichment is a tool for performing go enrichment analysis of gene sets such as those obtained from rna seq or microarray experiments to help characterize them at the functional level it is available in galaxy europe and as a stand alone tool goenrichment is flexible in that it allows the user to use any version of the gene ontology and any go annotation file they desire to enable the use of go slims it is accompanied by a sister tool goslimmer which can convert annotation files from full go to any specified go slim the tool features an optional graph clustering algorithm to reduce the redundancy in the set of enriched go terms and simplify its output it was developed by the biodata pt elixir pt team at the instituto gulbenkian de ci ncia': {'goenrichment'},
#  'detect gene ontology and or other user defined categories which are over under represented in rna seq data': {'goseq'},
#  'graphlan is a software tool for producing high quality circular representations of taxonomic and phylogenetic trees graphlan focuses on concise integrative informative and publication ready representations of phylogenetically and taxonomically driven investigation': {'graphlan'},
#  'versatile package to perform molecular dynamics i e simulate the newtonian equations of motion for systems with hundreds to millions of particles it is primarily designed for biochemical molecules like proteins lipids and nucleic acids that have a lot of complicated bonded interactions but since it is extremely fast at calculating the nonbonded interactions that usually dominate simulations many groups are also using it for research on non biological systems e g polymers': {'gromacs'},
#  'tool with multiple functions main functions are to create a diamond database from the gtdb taxonomy data or create a ncbi taxdump format out of this data this tool can also create a mapping between the taxonomy classification between gtdb and ncbi': {'gtdb_to_taxdump'},
#  'a toolkit to classify genomes with the genome taxonomy database gtdb tk a toolkit for assigning objective taxonomic classifications to bacterial and archaeal genomes gtdb tk is a software toolkit for assigning objective taxonomic classifications to bacterial and archaeal genomes based on the genome database taxonomy gtdb it is designed to work with recent advances that allow hundreds or thousands of metagenome assembled genomes mags to be obtained directly from environmental samples it can also be applied to isolate and single cell genomes the gtdb tk is open source and released under the gnu general public license version 3': {'gtdb-tk'},
#  'gubbins is a tool for rapid phylogenetic analysis of large samples of recombinant bacterial whole genome sequences': {'gubbins'},
#  'hapcut2 is a maximum likelihood based tool for assembling haplotypes from dna sequence reads designed to just work with excellent speed and accuracy across a range of long and short read sequencing technologies the output is in haplotype block format described here https github com vibansal hapcut2 blob master outputformat md': {'hapcut2'},
#  'software for the detection of selection signatures based on multiple population genotyping data': {'hapflk'},
#  'hapo g is a tool that aims to improve the quality of genome assemblies by polishing the consensus with accurate reads it capable of incorporating phasing information from high quality reads short or long reads to polish genome assemblies and in particular assemblies of diploid and heterozygous genomes': {'hapog'},
# ...
#  'workflow engine and language it aims to reduce the complexity of creating workflows by providing a fast and comfortable execution environment together with a clean and modern domain specific specification language dsl in python style': {'snakemake'},
#  'the semi hmm based nucleic acid parser is a gene prediction tool': {'snap'},
#  'snapatac single nucleus analysis pipeline for atac seq is a fast accurate and comprehensive method for analyzing single cell atac seq datasets': {'snapatac'},
#  'a snakemake pipeline for scalable hiv 1 subtyping by phylogenetic pairing snappy is a snakemake pipeline for hiv 1 subtyping by phylogenetic pairing this is the repository for snappy a snakemake pipeline for hiv 1 subtyping by phylogenetic pairing snappy allows high throughput hiv 1 subtyping locally while being resource efficient and scalable this pipeline was constructed using snakemake and it uses mafft and for multiple sequence alignment blast for similarirty querys iq tree for phylogenetic inference and several biopython modules for data parsing an analysis for in depth information on how the tool works please visit the documentation page snappy was design for linux based operative systems welcome to snappy s documentation snappy hiv1 subtyping 1 0 0 documentation free document hosting provided by read the docs': {'snappy'},
#  'an algorithm for structural variation detection from third generation sequencing alignment': {'sniffles'},
#  'rapid haploid variant calling and core snp phylogeny generation': {'snippy'},
#  'variant annotation and effect prediction tool it annotates and predicts the effects of variants on genes and proteins such as amino acid changes': {'snpeff'},
#  'toolbox that allows you to filter and manipulate annotated vcf files': {'snpsift'},
#  'sequence analysis tool for filtering mapping and otu picking ngs reads': {'sortmerna'},
#  'st petersburg genome assembler is intended for both standard isolates and single cell mda bacteria assemblies spades 3 9 works with illumina or iontorrent reads and is capable of providing hybrid assemblies using pacbio oxford nanopore and sanger reads additional contigs can be provided and can be used as long reads': {'spades'},
#  'improved mass spectral similarity scoring through learning of structural relationships spec2vec is a novel spectral similarity score inspired by a natural language processing algorithm word2vec where word2vec learns relationships between words in sentences spec2vec does so for mass fragments and neutral losses in ms ms spectra the spectral similarity score is based on spectral embeddings learnt from the fragmental relationships within a large set of spectral data analysis and benchmarking of mass spectra similarity measures using gnps data set': {'spec2vec'},
#  'spectral repeat finder srf is a program to find repeats through an analysis of the power spectrum of a given dna sequence': {'srf'},
#  'squidpy spatial single cell analysis in python squidpy is a tool for the analysis and visualization of spatial molecular data it builds on top of scanpy and anndata from which it inherits modularity and scalability it provides analysis tools that leverages the spatial coordinates of the data as well as tissue images if available': {'squidpy'},
#  'some quick reconstruction to resolve evolutionary links squirrel provides a rapid way of producing reliable alignments for mpxv and also enable maximum likelihood phylogenetics pipeline tree estimation': {'squirrel'},
#  'the sra toolkit and sdk from ncbi is a collection of tools and libraries for using data in the insdc sequence read archives': {'sra-tools'},
#  'a fast implementation of the smith waterman algorithm whose api that can be flexibly used by programs written in c c and other languages': {'ssw'},
#  'developed to work with restriction enzyme based sequence data such as radseq for building genetic maps and conducting population genomics and phylogeography analysis': {'stacks'},
#  'ultrafast universal rna seq data aligner': {'star'},
#  'staramr amr scans bacterial genome contigs against the resfinder pointfinder and plasmidfinder databases used by the resfinder webservice and other webservices offered by the center for genomic epidemiology and compiles a summary report of detected antimicrobial resistance genes the star in staramr indicates that it can handle all of the resfinder pointfinder and plasmidfinder databases': {'staramr'},
#  'star fusion a method that is both fast and accurate in identifying fusion transcripts from rna seq data': {'star_fusion'},
#  'fast and highly efficient assembler of rna seq alignments into potential transcripts it uses a novel network flow algorithm as well as an optional de novo assembly step to assemble and quantitate full length transcripts representing multiple splice variants for each gene locus': {'stringtie'},
#  'subread is a general purpose read aligner which can be used to map both genomic dna seq reads and rna seq reads it uses a new mapping paradigm called seed and vote to achieve fast accurate and scalable read mapping it automatically determines if a read should be globally or locally aligned therefore particularly powerful in mapping rna seq reads it supports indel detection and can map reads with both fixed and variable lengths': {'subread'},
#  'an agile homology based approach using a reduced seed database to report the subsystems present in metagenomic samples and profile their abundances': {'superfocus'},
#  'this tool generates alternative splicing as events from an annotation and calculates the psi percentage spliced in value for each event exploiting fast quantification of transcript abundances from multiple samples': {'suppa'},
#  'structural variant detection from haploid and diploid genome assemblies svim asm structural variant identification method assembly edition svim asm pronounced swim assem is a structural variant caller for haploid or diploid genome genome alignments it analyzes a given sorted bam file preferably from minimap2 and detects five different variant classes between the query assembly and the reference deletions insertions tandem and interspersed duplications and inversions': {'svim-asm'},
#  'syri is tool for finding genomic rearrangements and local sequence differences from whole genome assemblies genomic differences range from single nucleotide differences to complex structural variations current methods typically annotate sequence differences ranging from snps to large indels accurately but do not unravel the full complexity of structural rearrangements including inversions translocations and duplications where highly similar sequence changes in location orientation or copy number here we present syri a pairwise whole genome comparison tool for chromosome level assemblies syri starts by finding rearranged regions and then searches for differences in the sequences which are distinguished for residing in syntenic or rearranged regions this distinction is important as rearranged regions are inherited differently compared to syntenic regions': {'syri'},
#  'targetfinder org provides a web based resource that allows users to find genes that have a similar expression to a query gene signature': {'targetfinder'},
#  'taxonkit is a practical and efficient ncbi taxonomy toolkit': {'taxonkit'},
#  'tbl2asn is a command line program that automates the creation of sequence records for submission to genbank it uses many of the same functions as genome workbench but is driven generally by data files tbl2asn generates sqn files for submission to genbank': {'tbl2asn'},
#  'a tool for drug resistance prediction from m tuberculosis genomic data sequencing reads alignments or variants': {'tbprofiler'},
#  'the combat tb workbench is an irida based module workbench for m tuberculosis bioinformatics it is designed to be easily deployed on a single server': {'tbvcfreport'},
#  'lineage level classification of transposable elements using conserved protein domains note do not move or hard link tesorter py alone to anywhere else as it rely on database and bin you can add the directory to path or soft link tesorter py to path': {'tesorter'},
#  'open source crossplatform tool that converts thermo raw files into open file formats such as mgf and to the hupo psi standard file format mzml': {'ThermoRawFileParser'},
#  'program that aligns rna seq reads to a genome in order to identify exon exon splice junctions it is built on the ultrafast short read mapping program bowtie a stable samtools version is now packaged with the program': {'tophat'},
#  'transdecoder identifies candidate coding regions within transcript sequences such as those generated by de novo rna seq transcript assembly using trinity or constructed based on rna seq alignments to the genome using tophat and cufflinks': {'transdecoder'},
#  'a tool for the analysis of tn seq data it provides an easy to use graphical interface and access to three different analysis methods that allow the user to determine essentiality in a single condition as well as between conditions': {'transit'},
#  'institute for systems biology trans proteomic pipeline': {'tpp'},
#  'tandem repeats finder find tandem repeats in dna sequences without the need to specify either the pattern or pattern size it uses the method of k tuple matching to avoid the need for full scale alignment matrix computations it requires no a priori knowledge of the pattern pattern size or number of copies there are no restrictions on the size of the repeats that can be detected it determines a consensus pattern for the smallest repetitive unit in the tandem repeat': {'trf'},
#  'tool for the automated removal of spurious sequences or poorly aligned regions from a multiple sequence alignment': {'trimal'},
#  'a wrapper tool around cutadapt and fastqc to consistently apply quality and adapter trimming to fastq files with some extra functionality for mspi digested rrbs type reduced representation bisufite seq libraries': {'trim_galore'},
#  'a flexible read trimming tool for illumina ngs data': {'trimmomatic'},
#  'trinity is a transcriptome assembler which relies on three different tools inchworm an assembler chrysalis which pools contigs and butterfly which amongst others compacts a graph resulting from butterfly with reads': {'trinity'},
#  'comprehensive annotation suite designed for automatic functional annotation of transcriptomes particularly de novo assembled transcriptomes from model or non model organisms': {'trinotate'},
#  'a program for improved detection of transfer rna genes in genomic sequence': {'trnascan-se'},
#  'trycycler consensus long read assemblies for bacterial genomes': {'trycycler'},
#  'utilities for handling sequences and assemblies from the ucsc genome browser project': {'ucsc'},
#  'tools for handling unique molecular identifiers in ngs data sets': {'umi_tools'},
#  'a tool for assembling bacterial genomes from a combination of short 2nd generation and long 3rd generation sequencing reads': {'unicycler'},
#  'metaproteomics data analysis with a focus on interactive data visualizations': {'unipept'},
#  'the universal protein knowledgebase in 2021 you are using a version of browser that may not display all the features of this website': {'UniProt_Downloader',
#   'uniprot_rest_interface'},
#  'tool for predicting effects of variants for any genome in ensembl or with genome annotation via gff this includes vertebrates and also plants fungi protists metazoa and bacteria there is a web and a rest api version but the most powerful is the perl script version see mclaren et al 2016 genome biology': {'vep'},
#  'vapor is a tool for classification of influenza samples from raw short read sequence data for downstream bioinformatics analysis vapor is provided with a fasta file of full length sequences 20 000 for a given segment a set of reads and attempts to retrieve a reference that is closest to the sample strain': {'vapor'},
#  'varscan an open source tool for variant detection that is compatible with several short read align ers': {'varscan'},
#  'api and command line utilities for the manipulation of vcf files': {'vcflib'},
#  'provide easily accessible methods for working with complex genetic variation data in the form of vcf files': {'vcftools'},
#  'estimating rna velocity in single cell rna sequencing datasets': {'velocyto'},
#  'a de novo genomic assembler specially designed for short read sequencing technologies such as solexa or 454 or solid': {'velvet'},
#  'high throughput search and clustering sequence analysis tool it supports de novo and reference based chimera detection clustering full length and prefix dereplication reverse complementation masking all vs all pairwise global alignment exact and global alignment searching shuffling subsampling and sorting it also supports fastq file analysis filtering and conversion': {'vsearch'},
#  'removal of batch effects for large scale untargeted metabolomics data based on wavelet transform': {'waveica'},
#  'software for phasing genomic variants using dna sequencing reads also called haplotype assembly it is especially suitable for long reads but works also well with short reads': {'whatshap'},
#  'windowmasker identifies and masks highly repetitive dna sequences in a genome using only the sequence of the genome itself': {'windowmasker'},
#  'winnowmap is a long read mapping algorithm optimized for mapping ont and pacbio reads to repetitive reference sequences winnowmap development began on top of minimap2 codebase and since then we have incorporated the following two ideas to improve mapping accuracy within repeats': {'winnowmap'},
#  'first fully open source and collaborative online platform for computational metabolomics it includes preprocessing normalization quality control statistical analysis of lc ms fia ms gc ms and nmr data': {'workflow4metabolomics'},
#  'caenorhabditis elegans genome database international consortium of biologists and computer scientists dedicated to providing the research community with accurate current accessible information concerning the genetics genomics and biology of c elegans and related nematodes founded in 2000 the consortium is led by paul sternberg of caltech paul kersey of the ebi matt berriman of the wellcome trust sanger institute and lincoln stein of the ontario institute for cancer research': {'wormbase'},
#  'framework for processing and visualization of chromatographically separated and single spectra mass spectral data the packages enables imports from aia andi netcdf mzxml mzdata and mzml files and preprocesses data for high throughput untargeted analyte profiling': {'xcms'},
#  'detection of differential rna modifications from direct rna sequencing of human cell lines python package for detection of differential rna modifications from direct rna sequencing': {'xpore'},
#  'matches tandem mass spectra with peptide sequences': {'xtandem'},
#  'the xtb molecular optimization tool based on the semiempirical tight binding method gfnn xtb is implemented in the xtb extended tight binding program package this tool handles molecular xyz input format and provides various levels of optimization to suit different computational needs the xtb method offers an efficient approach for molecular structure optimization making it valuable for large scale quantum chemical simulations': {'xtb'},
#  'yahs is scaffolding tool using hi c data it relies on a new algorithm for contig joining detection which considers the topological distribution of hi c signals aiming to distinguish real interaction signals from mapping noises': {'yahs'},
#  'search and retrieve s cerevisiae data populated by sgd and powered by intermine': {'yeastmine'},
#  'zebrafishmine is powered by the intermine data warehouse system and integrates biological data sets from multiple sources it currently includes updates of data from zfin the zebrafish model organism database there is also data from the panther database': {'zebrafishmine'}}
